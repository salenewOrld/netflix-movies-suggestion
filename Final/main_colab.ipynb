# %% [markdown]
# # Check whether this thing is working

# %%
"Hello World"
# Out:
# 'Hello World'

# %% [markdown]
# # DNA Framework

# %% [markdown]
# ![1.jpg](data:image/jpeg;base64,...)![](img/1.jpg)

# %% [markdown]
# ![2.jpg](data:image/jpeg;base64,...)![](img/2.jpg)

# %% [markdown]
# # Import libraries

# %%
import seaborn as sns
import matplotlib as plt
import re
import pandas as pd

# %% [markdown]
# # Import Dataset

# %%
movies = pd.read_csv('movies_metadata.csv')
# Out:
# C:\Users\MagicPC\AppData\Local\Programs\Python\Python36\lib\site-packages\IPython\core\interactiveshell.py:3072: DtypeWarning: Columns (10) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %% [markdown]
# # Data pre-processing
#     - Clear null rows
#     - Clean columns
#     - Clear dropulicated rows
#     - Binning data
#     - Preparing data for modeling

# %%
movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45466 entries, 0 to 45465
# Data columns (total 24 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   adult                  45466 non-null  object
#  1   belongs_to_collection  4494 non-null   object
#  2   budget                 45466 non-null  object
#  3   genres                 45466 non-null  object
#  4   homepage               7782 non-null   object
#  5   id                     45466 non-null  object
#  6   imdb_id                45449 non-null  object
#  7   original_language      45455 non-null  object
#  8   original_title         45466 non-null  object
#  9   overview               44512 non-null  object
#  10  popularity             45461 non-null  object
#  11  poster_path            45080 non-null  object
#  12  production_companies   45463 non-null  object
#  13  production_countries   45463 non-null  object
#  14  release_date           45379 non-null  object
#  15  revenue                45460 non-null  float64
#  16  runtime                45203 non-null  float64
#  17  spoken_languages       45460 non-null  object
#  18  status                 45379 non-null  object
#  19  tagline                20412 non-null  object
#  20  title                  45460 non-null  object
#  21  video                  45460 non-null  object
#  22  vote_average           45460 non-null  float64
#  23  vote_count             45460 non-null  float64
# dtypes: float64(4), object(20)
# memory usage: 8.3+ MB

# %%
movies.isna().sum()
# Out:
# adult                        0
# belongs_to_collection    40972
# budget                       0
# genres                       0
# homepage                 37684
# id                           0
# imdb_id                     17
# original_language           11
# original_title               0
# overview                   954
# popularity                   5
# poster_path                386
# production_companies         3
# production_countries         3
# release_date                87
# revenue                      6
# runtime                    263
# spoken_languages             6
# status                      87
# tagline                  25054
# title                        6
# video                        6
# vote_average                 6
# vote_count                   6
# dtype: int64

# %%
movies.columns
# Out:
# Index(['adult', 'belongs_to_collection', 'budget', 'genres', 'homepage', 'id',
#        'imdb_id', 'original_language', 'original_title', 'overview',
#        'popularity', 'poster_path', 'production_companies',
#        'production_countries', 'release_date', 'revenue', 'runtime',
#        'spoken_languages', 'status', 'tagline', 'title', 'video',
#        'vote_average', 'vote_count'],
#       dtype='object')

# %%
movies.shape
# Out:
# (45466, 24)

# %% [markdown]
# ## To see that how much are the NA columns

# %%
movies.isna().sum()
# Out:
# adult                        0
# belongs_to_collection    40972
# budget                       0
# genres                       0
# homepage                 37684
# id                           0
# imdb_id                     17
# original_language           11
# original_title               0
# overview                   954
# popularity                   5
# poster_path                386
# production_companies         3
# production_countries         3
# release_date                87
# revenue                      6
# runtime                    263
# spoken_languages             6
# status                      87
# tagline                  25054
# title                        6
# video                        6
# vote_average                 6
# vote_count                   6
# dtype: int64

# %%
# we have to copy the dataset into another pandas dataframe so we can be able to manage it with high risk.
df = movies.copy()

# %%
# checking information of each column, so we can decide what columns to be kept or dropped
df.head(5)
# Out:
#    adult                              belongs_to_collection    budget  \
# 0  False  {'id': 10194, 'name': 'Toy Story Collection', ...  30000000
# 1  False                                                NaN  65000000
# 2  False  {'id': 119050, 'name': 'Grumpy Old Men Collect...         0
# 3  False                                                NaN  16000000
# 4  False  {'id': 96871, 'name': 'Father of the Bride Col...         0
#
#                                               genres  \
# 0  [{'id': 16, 'name': 'Animation'}, {'id': 35, '...
# 1  [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...
# 2  [{'id': 10749, 'name': 'Romance'}, {'id': 35, ...
# 3  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 4                     [{'id': 35, 'name': 'Comedy'}]
#
#                                homepage     id    imdb_id original_language  \
# 0  http://toystory.disney.com/toy-story    862  tt0114709                en
# 1                                   NaN   8844  tt0113497                en
# 2                                   NaN  15602  tt0113228                en
# 3                                   NaN  31357  tt0114885                en
# 4                                   NaN  11862  tt0113041                en
#
#                 original_title  \
# 0                    Toy Story
# 1                      Jumanji
# 2             Grumpier Old Men
# 3            Waiting to Exhale
# 4  Father of the Bride Part II
#
#                                             overview  ... release_date  \
# 0  Led by Woody, Andy's toys live happily in his ...  ...   1995-10-30
# 1  When siblings Judy and Peter discover an encha...  ...   1995-12-15
# 2  A family wedding reignites the ancient feud be...  ...   1995-12-22
# 3  Cheated on, mistreated and stepped on, the wom...  ...   1995-12-22
# 4  Just when George Banks has recovered from his ...  ...   1995-02-10
#
#        revenue runtime                                   spoken_languages  \
# 0  373554033.0    81.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 1  262797249.0   104.0  [{'iso_639_1': 'en', 'name': 'English'}, {'iso...
# 2          0.0   101.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 3   81452156.0   127.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 4   76578911.0   106.0           [{'iso_639_1': 'en', 'name': 'English'}]
#
#      status                                            tagline  \
# 0  Released                                                NaN
# 1  Released          Roll the dice and unleash the excitement!
# 2  Released  Still Yelling. Still Fighting. Still Ready for...
# 3  Released  Friends are the people who let you be yourself...
# 4  Released  Just When His World Is Back To Normal... He's ...
#
#                          title  video vote_average vote_count
# 0                    Toy Story  False          7.7     5415.0
# 1                      Jumanji  False          6.9     2413.0
# 2             Grumpier Old Men  False          6.5       92.0
# 3            Waiting to Exhale  False          6.1       34.0
# 4  Father of the Bride Part II  False          5.7      173.0
#
# [5 rows x 24 columns]

# %%
# #dropping unused columns
# it doesn't seem to be close to the reason to choose those columns because it's not even related 
# to our business objective and some of those are similar to columns
df.drop(columns=['belongs_to_collection', 'budget', 'id', 'imdb_id', 'poster_path', 'production_countries','release_date', 'revenue', 'status','tagline', 'title', 'video', 'homepage', 'spoken_languages'], axis='columns', inplace=True)

# %%
#check if it's dropped
df.columns
# Out:
# Index(['adult', 'genres', 'original_language', 'original_title', 'overview',
#        'popularity', 'production_companies', 'runtime', 'vote_average',
#        'vote_count'],
#       dtype='object')

# %%
# check whether there's null columns in each row or not
df.isna().sum()
# Out:
# adult                     0
# genres                    0
# original_language        11
# original_title            0
# overview                954
# popularity                5
# production_companies      3
# runtime                 263
# vote_average              6
# vote_count                6
# dtype: int64

# %%
#it's almost 100% holy s***
#so I wonder how about another null columns?
(df.isna().sum() * 100 / df.shape[0]).round(2)
# Out:
# adult                   0.00
# genres                  0.00
# original_language       0.02
# original_title          0.00
# overview                2.10
# popularity              0.01
# production_companies    0.01
# runtime                 0.58
# vote_average            0.01
# vote_count              0.01
# dtype: float64

# %%
#check
df.columns
# Out:
# Index(['adult', 'genres', 'original_language', 'original_title', 'overview',
#        'popularity', 'production_companies', 'runtime', 'vote_average',
#        'vote_count'],
#       dtype='object')

# %%
#let's move to the next one
#overview
df.loc[df['overview'].isnull()]
# Out:
#        adult                                             genres  \
# 32     False  [{'id': 10749, 'name': 'Romance'}, {'id': 12, ...
# 300    False  [{'id': 18, 'name': 'Drama'}, {'id': 35, 'name...
# 634    False                     [{'id': 35, 'name': 'Comedy'}]
# 635    False                     [{'id': 35, 'name': 'Comedy'}]
# 641    False                     [{'id': 35, 'name': 'Comedy'}]
# ...      ...                                                ...
# 45342  False                      [{'id': 18, 'name': 'Drama'}]
# 45377  False                  [{'id': 12, 'name': 'Adventure'}]
# 45398  False  [{'id': 10749, 'name': 'Romance'}, {'id': 35, ...
# 45399  False  [{'id': 80, 'name': 'Crime'}, {'id': 35, 'name...
# 45410  False  [{'id': 18, 'name': 'Drama'}, {'id': 80, 'name...
#
#       original_language                    original_title overview popularity  \
# 32                   fr  Guillaumet, les ailes du courage      NaN   0.745542
# 300                  sv                         Roommates      NaN    3.39587
# 634                  de    Peanuts – Die Bank zahlt alles      NaN   0.066123
# 635                  de                     Happy Weekend      NaN   0.002229
# 641                  de                     Das Superweib      NaN   0.821299
# ...                 ...                               ...      ...        ...
# 45342                en                        Over/Under      NaN   0.704642
# 45377                es     Simbad e il califfo di Bagdad      NaN   0.006352
# 45398                fi  Lauri Mäntyvaaran tuuheet ripset      NaN   0.347806
# 45399                ru                       Все и сразу      NaN   0.201582
# 45410                ru                             Aprel      NaN   0.008903
#
#                                     production_companies  runtime  \
# 32       [{'name': 'Iwerks Entertainment', 'id': 70801}]     50.0
# 300    [{'name': 'Hollywood Pictures', 'id': 915}, {'...    108.0
# 634    [{'name': 'Westdeutscher Rundfunk (WDR)', 'id'...      NaN
# 635     [{'name': 'Senator Film Produktion', 'id': 191}]      NaN
# 641              [{'name': 'Constantin Film', 'id': 47}]     86.0
# ...                                                  ...      ...
# 45342  [{'name': 'Fox Television Studios', 'id': 6529...     87.0
# 45377  [{'name': 'Roas Produzioni', 'id': 21137}, {'n...      NaN
# 45398    [{'name': 'Elokuvayhtiö Oy Aamu', 'id': 84883}]     90.0
# 45399  [{'name': 'Кинокомпания «Lunapark»', 'id': 420...      0.0
# 45410                                                 []      NaN
#
#        vote_average  vote_count
# 32              6.8         4.0
# 300             6.4         7.0
# 634             4.0         1.0
# 635             0.0         0.0
# 641             5.3         7.0
# ...             ...         ...
# 45342           4.0         2.0
# 45377           0.0         0.0
# 45398           8.0         1.0
# 45399           6.0         4.0
# 45410           6.0         1.0
#
# [954 rows x 10 columns]

# %%
#it's neccesary to have overview, it represents as a short version of the movie
#so I decided to drop the NaN rows
df.dropna(axis='rows', inplace=True)

# %%
df.shape[0]
# Out:
# 44496

# %%
df.isna().sum()
# Out:
# adult                   0
# genres                  0
# original_language       0
# original_title          0
# overview                0
# popularity              0
# production_companies    0
# runtime                 0
# vote_average            0
# vote_count              0
# dtype: int64

# %%
df.head()
# Out:
#    adult                                             genres original_language  \
# 0  False  [{'id': 16, 'name': 'Animation'}, {'id': 35, '...                en
# 1  False  [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...                en
# 2  False  [{'id': 10749, 'name': 'Romance'}, {'id': 35, ...                en
# 3  False  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...                en
# 4  False                     [{'id': 35, 'name': 'Comedy'}]                en
#
#                 original_title  \
# 0                    Toy Story
# 1                      Jumanji
# 2             Grumpier Old Men
# 3            Waiting to Exhale
# 4  Father of the Bride Part II
#
#                                             overview popularity  \
# 0  Led by Woody, Andy's toys live happily in his ...    21.9469
# 1  When siblings Judy and Peter discover an encha...    17.0155
# 2  A family wedding reignites the ancient feud be...    11.7129
# 3  Cheated on, mistreated and stepped on, the wom...    3.85949
# 4  Just when George Banks has recovered from his ...    8.38752
#
#                                 production_companies  runtime  vote_average  \
# 0     [{'name': 'Pixar Animation Studios', 'id': 3}]     81.0           7.7
# 1  [{'name': 'TriStar Pictures', 'id': 559}, {'na...    104.0           6.9
# 2  [{'name': 'Warner Bros.', 'id': 6194}, {'name'...    101.0           6.5
# 3  [{'name': 'Twentieth Century Fox Film Corporat...    127.0           6.1
# 4  [{'name': 'Sandollar Productions', 'id': 5842}...    106.0           5.7
#
#    vote_count
# 0      5415.0
# 1      2413.0
# 2        92.0
# 3        34.0
# 4       173.0

# %%
#rename genres of each movies
regex = re.compile(r": '(.*?)'")
df['genres'] = df['genres'].apply(lambda x: ", ".join(regex.findall(x)))
df
# Out:
#        adult                      genres original_language  \
# 0      False   Animation, Comedy, Family                en
# 1      False  Adventure, Fantasy, Family                en
# 2      False             Romance, Comedy                en
# 3      False      Comedy, Drama, Romance                en
# 4      False                      Comedy                en
# ...      ...                         ...               ...
# 45461  False               Drama, Family                fa
# 45462  False                       Drama                tl
# 45463  False     Action, Drama, Thriller                en
# 45464  False                                            en
# 45465  False                                            en
#
#                     original_title  \
# 0                        Toy Story
# 1                          Jumanji
# 2                 Grumpier Old Men
# 3                Waiting to Exhale
# 4      Father of the Bride Part II
# ...                            ...
# 45461                      رگ خواب
# 45462          Siglo ng Pagluluwal
# 45463                     Betrayal
# 45464          Satana likuyushchiy
# 45465                     Queerama
#
#                                                 overview popularity  \
# 0      Led by Woody, Andy's toys live happily in his ...    21.9469
# 1      When siblings Judy and Peter discover an encha...    17.0155
# 2      A family wedding reignites the ancient feud be...    11.7129
# 3      Cheated on, mistreated and stepped on, the wom...    3.85949
# 4      Just when George Banks has recovered from his ...    8.38752
# ...                                                  ...        ...
# 45461        Rising and falling between a man and woman.   0.072051
# 45462  An artist struggles to finish his work while a...   0.178241
# 45463  When one of her hits goes wrong, a professiona...   0.903007
# 45464  In a small town live two brothers, one a minis...   0.003503
# 45465  50 years after decriminalisation of homosexual...   0.163015
#
#                                     production_companies  runtime  \
# 0         [{'name': 'Pixar Animation Studios', 'id': 3}]     81.0
# 1      [{'name': 'TriStar Pictures', 'id': 559}, {'na...    104.0
# 2      [{'name': 'Warner Bros.', 'id': 6194}, {'name'...    101.0
# 3      [{'name': 'Twentieth Century Fox Film Corporat...    127.0
# 4      [{'name': 'Sandollar Productions', 'id': 5842}...    106.0
# ...                                                  ...      ...
# 45461                                                 []     90.0
# 45462             [{'name': 'Sine Olivia', 'id': 19653}]    360.0
# 45463  [{'name': 'American World Pictures', 'id': 6165}]     90.0
# 45464               [{'name': 'Yermoliev', 'id': 88753}]     87.0
# 45465                                                 []     75.0
#
#        vote_average  vote_count
# 0               7.7      5415.0
# 1               6.9      2413.0
# 2               6.5        92.0
# 3               6.1        34.0
# 4               5.7       173.0
# ...             ...         ...
# 45461           4.0         1.0
# 45462           9.0         3.0
# 45463           3.8         6.0
# 45464           0.0         0.0
# 45465           0.0         0.0
#
# [44496 rows x 10 columns]

# %%
#reset index
df.reset_index(drop=True)
# Out:
#        adult                      genres original_language  \
# 0      False   Animation, Comedy, Family                en
# 1      False  Adventure, Fantasy, Family                en
# 2      False             Romance, Comedy                en
# 3      False      Comedy, Drama, Romance                en
# 4      False                      Comedy                en
# ...      ...                         ...               ...
# 44491  False               Drama, Family                fa
# 44492  False                       Drama                tl
# 44493  False     Action, Drama, Thriller                en
# 44494  False                                            en
# 44495  False                                            en
#
#                     original_title  \
# 0                        Toy Story
# 1                          Jumanji
# 2                 Grumpier Old Men
# 3                Waiting to Exhale
# 4      Father of the Bride Part II
# ...                            ...
# 44491                      رگ خواب
# 44492          Siglo ng Pagluluwal
# 44493                     Betrayal
# 44494          Satana likuyushchiy
# 44495                     Queerama
#
#                                                 overview popularity  \
# 0      Led by Woody, Andy's toys live happily in his ...    21.9469
# 1      When siblings Judy and Peter discover an encha...    17.0155
# 2      A family wedding reignites the ancient feud be...    11.7129
# 3      Cheated on, mistreated and stepped on, the wom...    3.85949
# 4      Just when George Banks has recovered from his ...    8.38752
# ...                                                  ...        ...
# 44491        Rising and falling between a man and woman.   0.072051
# 44492  An artist struggles to finish his work while a...   0.178241
# 44493  When one of her hits goes wrong, a professiona...   0.903007
# 44494  In a small town live two brothers, one a minis...   0.003503
# 44495  50 years after decriminalisation of homosexual...   0.163015
#
#                                     production_companies  runtime  \
# 0         [{'name': 'Pixar Animation Studios', 'id': 3}]     81.0
# 1      [{'name': 'TriStar Pictures', 'id': 559}, {'na...    104.0
# 2      [{'name': 'Warner Bros.', 'id': 6194}, {'name'...    101.0
# 3      [{'name': 'Twentieth Century Fox Film Corporat...    127.0
# 4      [{'name': 'Sandollar Productions', 'id': 5842}...    106.0
# ...                                                  ...      ...
# 44491                                                 []     90.0
# 44492             [{'name': 'Sine Olivia', 'id': 19653}]    360.0
# 44493  [{'name': 'American World Pictures', 'id': 6165}]     90.0
# 44494               [{'name': 'Yermoliev', 'id': 88753}]     87.0
# 44495                                                 []     75.0
#
#        vote_average  vote_count
# 0               7.7      5415.0
# 1               6.9      2413.0
# 2               6.5        92.0
# 3               6.1        34.0
# 4               5.7       173.0
# ...             ...         ...
# 44491           4.0         1.0
# 44492           9.0         3.0
# 44493           3.8         6.0
# 44494           0.0         0.0
# 44495           0.0         0.0
#
# [44496 rows x 10 columns]

# %%
#rename production names and production countries
df['production_companies'] = df['production_companies'].apply(lambda x: ', '.join(regex.findall(x)))

# %%
#check
df
# Out:
#        adult                      genres original_language  \
# 0      False   Animation, Comedy, Family                en
# 1      False  Adventure, Fantasy, Family                en
# 2      False             Romance, Comedy                en
# 3      False      Comedy, Drama, Romance                en
# 4      False                      Comedy                en
# ...      ...                         ...               ...
# 45461  False               Drama, Family                fa
# 45462  False                       Drama                tl
# 45463  False     Action, Drama, Thriller                en
# 45464  False                                            en
# 45465  False                                            en
#
#                     original_title  \
# 0                        Toy Story
# 1                          Jumanji
# 2                 Grumpier Old Men
# 3                Waiting to Exhale
# 4      Father of the Bride Part II
# ...                            ...
# 45461                      رگ خواب
# 45462          Siglo ng Pagluluwal
# 45463                     Betrayal
# 45464          Satana likuyushchiy
# 45465                     Queerama
#
#                                                 overview popularity  \
# 0      Led by Woody, Andy's toys live happily in his ...    21.9469
# 1      When siblings Judy and Peter discover an encha...    17.0155
# 2      A family wedding reignites the ancient feud be...    11.7129
# 3      Cheated on, mistreated and stepped on, the wom...    3.85949
# 4      Just when George Banks has recovered from his ...    8.38752
# ...                                                  ...        ...
# 45461        Rising and falling between a man and woman.   0.072051
# 45462  An artist struggles to finish his work while a...   0.178241
# 45463  When one of her hits goes wrong, a professiona...   0.903007
# 45464  In a small town live two brothers, one a minis...   0.003503
# 45465  50 years after decriminalisation of homosexual...   0.163015
#
#                                     production_companies  runtime  \
# 0                                Pixar Animation Studios     81.0
# 1      TriStar Pictures, Teitler Film, Interscope Com...    104.0
# 2                           Warner Bros., Lancaster Gate    101.0
# 3                 Twentieth Century Fox Film Corporation    127.0
# 4             Sandollar Productions, Touchstone Pictures    106.0
# ...                                                  ...      ...
# 45461                                                        90.0
# 45462                                        Sine Olivia    360.0
# 45463                            American World Pictures     90.0
# 45464                                          Yermoliev     87.0
# 45465                                                        75.0
#
#        vote_average  vote_count
# 0               7.7      5415.0
# 1               6.9      2413.0
# 2               6.5        92.0
# 3               6.1        34.0
# 4               5.7       173.0
# ...             ...         ...
# 45461           4.0         1.0
# 45462           9.0         3.0
# 45463           3.8         6.0
# 45464           0.0         0.0
# 45465           0.0         0.0
#
# [44496 rows x 10 columns]

# %%
#check whether renamed columns are null or not
df.isna().sum()
# Out:
# adult                   0
# genres                  0
# original_language       0
# original_title          0
# overview                0
# popularity              0
# production_companies    0
# runtime                 0
# vote_average            0
# vote_count              0
# dtype: int64

# %%
#check whether there's really NO null in genres column
df.loc[df['genres'] == '']
# Out:
#        adult genres original_language                     original_title  \
# 55     False                       en            Kids of the Round Table
# 83     False                       en        Last Summer in the Hamptons
# 126    False                       en                     Jupiter's Wife
# 137    False                       en                             Target
# 390    False                       en                       Desert Winds
# ...      ...    ...               ...                                ...
# 45447  False                       fr               Le Roi du maquillage
# 45448  False                       fr  Les Transmutations imperceptibles
# 45455  False                       it         San Michele aveva un gallo
# 45464  False                       en                Satana likuyushchiy
# 45465  False                       en                           Queerama
#
#                                                 overview popularity  \
# 55     Set in modern times, Alex finds King Arthur's ...   0.307075
# 83     Filmed entirely on location in East Hampton, L...   0.531159
# 126    Michel Negroponte, a documentary filmmaker, me...   0.001178
# 137     A subtle yet violent commentary on feudal lords.   0.001205
# 390    Jackie and Eugene are joined by a mystical win...   0.251223
# ...                                                  ...        ...
# 45447  The background of this picture represents a sc...   0.213973
# 45448  This shows a prince entering upon the stage of...   0.071782
# 45455  Sentenced to life imprisonment for illegal act...   0.225051
# 45464  In a small town live two brothers, one a minis...   0.003503
# 45465  50 years after decriminalisation of homosexual...   0.163015
#
#                        production_companies  runtime  vote_average  vote_count
# 55     Telefilm Canada, Melenny Productions     89.0           3.0         1.0
# 83                                             108.0           0.0         0.0
# 126                                             87.0           0.0         0.0
# 137                                            122.0           0.0         0.0
# 390                                             97.0           0.0         0.0
# ...                                     ...      ...           ...         ...
# 45447                     Star Film Company      3.0           6.0         6.0
# 45448                     Star Film Company      2.0           5.0         2.0
# 45455                                           90.0           6.0         3.0
# 45464                             Yermoliev     87.0           0.0         0.0
# 45465                                           75.0           0.0         0.0
#
# [2184 rows x 10 columns]

# %%
#Dropping rows that don't contain type
df.drop(df.loc[df['genres'] == ""].index, inplace=True)

# %%
#check how is non-en movies like
df.loc[df['original_language'] != 'en']
# Out:
#        adult                               genres original_language  \
# 28     False  Fantasy, Science Fiction, Adventure                fr
# 29     False                         Drama, Crime                zh
# 52     False                       Drama, Foreign                it
# 57     False               Comedy, Drama, Romance                it
# 58     False             Thriller, Drama, Mystery                fr
# ...      ...                                  ...               ...
# 45450  False            Fantasy, Action, Thriller                fr
# 45451  False                      Comedy, Fantasy                fr
# 45453  False               Crime, Drama, Thriller                hi
# 45461  False                        Drama, Family                fa
# 45462  False                                Drama                tl
#
#                        original_title  \
# 28         La Cité des Enfants Perdus
# 29                          摇啊摇，摇到外婆桥
# 52                           Lamerica
# 57                         Il postino
# 58                   Le confessionnal
# ...                               ...
# 45450               L'Homme orchestre
# 45451  Nouvelles luttes extravagantes
# 45453                             Maa
# 45461                         رگ خواب
# 45462             Siglo ng Pagluluwal
#
#                                                 overview popularity  \
# 28     A scientist in a surrealist society kidnaps ch...    9.82242
# 29     A provincial boy related to a Shanghai crime f...    1.10091
# 52     Fiore, an Italian conman, arrives in post Comm...    1.36129
# 57     Simple Italian postman learns to love poetry w...    10.1684
# 58     The year is 1952, in Quebec City. Rachel (16),...   0.120789
# ...                                                  ...        ...
# 45450  A band-leader has arranged seven chairs for th...   1.109068
# 45451         A series of fantastical wrestling matches.   0.225432
# 45453  The bliss of a biology teacher’s family life i...   1.559596
# 45461        Rising and falling between a man and woman.   0.072051
# 45462  An artist struggles to finish his work while a...   0.178241
#
#                                     production_companies  runtime  \
# 28     Procirep, Constellation Productions, France 3 ...    108.0
# 29     Ministère des Affaires Étrangères, Alpha Films...    108.0
# 52                                                          116.0
# 57                                                          108.0
# 58                                                          100.0
# ...                                                  ...      ...
# 45450                                  Star Film Company      1.0
# 45451                                          Star-Film      2.0
# 45453                      Mad Films, Third Eye Pictures    146.0
# 45461                                                        90.0
# 45462                                        Sine Olivia    360.0
#
#        vote_average  vote_count
# 28              7.6       308.0
# 29              6.5        17.0
# 52              7.7        11.0
# 57              7.6       181.0
# 58              6.5         2.0
# ...             ...         ...
# 45450           6.5        22.0
# 45451           6.5         6.0
# 45453           6.6        14.0
# 45461           4.0         1.0
# 45462           9.0         3.0
#
# [11778 rows x 10 columns]

# %%
# we only be able to use EN language so, we decided to drop out the movies those are not en in original language column
df.drop(df.loc[df['original_language'] != 'en'].index, inplace=True)

# %%
df
# Out:
#        adult                      genres original_language  \
# 0      False   Animation, Comedy, Family                en
# 1      False  Adventure, Fantasy, Family                en
# 2      False             Romance, Comedy                en
# 3      False      Comedy, Drama, Romance                en
# 4      False                      Comedy                en
# ...      ...                         ...               ...
# 45457  False             Mystery, Horror                en
# 45458  False                      Horror                en
# 45459  False             Science Fiction                en
# 45460  False      Drama, Action, Romance                en
# 45463  False     Action, Drama, Thriller                en
#
#                     original_title  \
# 0                        Toy Story
# 1                          Jumanji
# 2                 Grumpier Old Men
# 3                Waiting to Exhale
# 4      Father of the Bride Part II
# ...                            ...
# 45457    Shadow of the Blair Witch
# 45458          The Burkittsville 7
# 45459              Caged Heat 3000
# 45460                   Robin Hood
# 45463                     Betrayal
#
#                                                 overview popularity  \
# 0      Led by Woody, Andy's toys live happily in his ...    21.9469
# 1      When siblings Judy and Peter discover an encha...    17.0155
# 2      A family wedding reignites the ancient feud be...    11.7129
# 3      Cheated on, mistreated and stepped on, the wom...    3.85949
# 4      Just when George Banks has recovered from his ...    8.38752
# ...                                                  ...        ...
# 45457  In this true-crime documentary, we delve into ...   0.076061
# 45458  A film archivist revisits the story of Rustin ...    0.38645
# 45459  It's the year 3000 AD. The world's most danger...   0.661558
# 45460  Yet another version of the classic epic, with ...   5.683753
# 45463  When one of her hits goes wrong, a professiona...   0.903007
#
#                                     production_companies  runtime  \
# 0                                Pixar Animation Studios     81.0
# 1      TriStar Pictures, Teitler Film, Interscope Com...    104.0
# 2                           Warner Bros., Lancaster Gate    101.0
# 3                 Twentieth Century Fox Film Corporation    127.0
# 4             Sandollar Productions, Touchstone Pictures    106.0
# ...                                                  ...      ...
# 45457                                                        45.0
# 45458     Neptune Salad Entertainment, Pirie Productions     30.0
# 45459                              Concorde-New Horizons     85.0
# 45460  Westdeutscher Rundfunk (WDR), Working Title Fi...    104.0
# 45463                            American World Pictures     90.0
#
#        vote_average  vote_count
# 0               7.7      5415.0
# 1               6.9      2413.0
# 2               6.5        92.0
# 3               6.1        34.0
# 4               5.7       173.0
# ...             ...         ...
# 45457           7.0         2.0
# 45458           7.0         1.0
# 45459           3.5         1.0
# 45460           5.7        26.0
# 45463           3.8         6.0
#
# [30534 rows x 10 columns]

# %%
#check if there's NO more null in production_companies column
df['production_companies'] = df['production_companies'].astype('string')

# %%
df.loc[df['production_companies'] == '']
# Out:
#        adult                       genres original_language  \
# 50     False      Action, Thriller, Drama                en
# 106    False                  Documentary                en
# 107    False                        Crime                en
# 114    False  Documentary, Drama, Foreign                en
# 119    False                        Drama                en
# ...      ...                          ...               ...
# 45431  False                  Documentary                en
# 45432  False                  Documentary                en
# 45440  False      Drama, Family, TV Movie                en
# 45452  False                  Documentary                en
# 45457  False              Mystery, Horror                en
#
#                      original_title  \
# 50                   Guardian Angel
# 106                         Catwalk
# 107    Headless Body in Topless Bar
# 114           Anne Frank Remembered
# 119         The Boys of St. Vincent
# ...                             ...
# 45431                Rivers of Sand
# 45432                 Altar of Fire
# 45440             To Be Fat Like Me
# 45452                   Deep Hearts
# 45457     Shadow of the Blair Witch
#
#                                                 overview popularity  \
# 50     Detective - turned - bodyguard Cynthia McKay (...   0.595949
# 106    A documentary following Christy Turlington and...   0.976707
# 107    An ex-con holds a group of people hostage in a...   0.001346
# 114    Using previously unreleased archival material ...   0.243986
# 119    The true story of boys being sexually abused a...    0.86539
# ...                                                  ...        ...
# 45431  The people portrayed in this film are called H...     0.0375
# 45432  This film records a 12 day ritual performed by...        0.0
# 45440  Pretty, popular, and slim high-schooler Aly Sc...   0.767762
# 45452  Deep Hearts is a film about the Bororo Fulani,...   0.011025
# 45457  In this true-crime documentary, we delve into ...   0.076061
#
#       production_companies  runtime  vote_average  vote_count
# 50                             93.0           6.3         3.0
# 106                            95.0           7.0         2.0
# 107                           110.0           0.0         0.0
# 114                           117.0           7.3         4.0
# 119                            90.0           7.0         7.0
# ...                    ...      ...           ...         ...
# 45431                          83.0           0.0         0.0
# 45432                          45.0           0.0         0.0
# 45440                          89.0           5.0        12.0
# 45452                          58.0           0.0         0.0
# 45457                          45.0           7.0         2.0
#
# [7118 rows x 10 columns]

# %%
df.drop(df.loc[df['production_companies'] == ''].index, inplace=True)

# %%
df.loc[df['production_companies'] == '']
# Out:
# Empty DataFrame
# Columns: [adult, genres, original_language, original_title, overview, popularity, production_companies, runtime, vote_average, vote_count]
# Index: []

# %%
df.shape
# Out:
# (23416, 10)

# %%
#check whether there's duplicated data in a form of original_title or not
df['original_title'] = df['original_title'].astype('string')
df.loc[df['original_title'].duplicated()]
# Out:
#        adult                   genres original_language      original_title  \
# 888    False   Comedy, Drama, Romance                en             Sabrina
# 930    False                    Drama                en  The Scarlet Letter
# 1296   False          Drama, Thriller                en           Cape Fear
# 1832   False                    Drama                en              Hamlet
# 1950   False    Comedy, Drama, Family                en     The Parent Trap
# ...      ...                      ...               ...                 ...
# 45415  False              Documentary                en         The Hunters
# 45420  False   Drama, Family, Fantasy                en      Arabian Nights
# 45454  False            Comedy, Drama                en   The Morning After
# 45460  False   Drama, Action, Romance                en          Robin Hood
# 45463  False  Action, Drama, Thriller                en            Betrayal
#
#                                                 overview popularity  \
# 888    Linus and David Larrabee are the two sons of a...    7.35974
# 930    In Puritan Boston, seamstress Hester Prynne is...   0.284522
# 1296   Sam Bowden witnesses a rape committed by Max C...    7.58319
# 1832   Winner of four Academy Awards, including Best ...    3.18807
# 1950   Hallie Parker and Annie James are identical tw...    7.76883
# ...                                                  ...        ...
# 45415  An ethnographic film that documents the effort...   0.141547
# 45420  Scheherezade puts herself in danger to save Su...   2.266456
# 45454  The Morning After is a feature film that consi...   0.139936
# 45460  Yet another version of the classic epic, with ...   5.683753
# 45463  When one of her hits goes wrong, a professiona...   0.903007
#
#                                     production_companies  runtime  \
# 888                                   Paramount Pictures    113.0
# 930                            Metro-Goldwyn-Mayer (MGM)    115.0
# 1296                         Melville-Talbot Productions    105.0
# 1832                                    Two Cities Films    155.0
# 1950                                Walt Disney Pictures    127.0
# ...                                                  ...      ...
# 45415  Harvard University, Peabody Museum, Film Study...     72.0
# 45420  Studio Babelsberg, International Traders, Hall...    175.0
# 45454       Oops Doughnuts Productions, He and She Films     79.0
# 45460  Westdeutscher Rundfunk (WDR), Working Title Fi...    104.0
# 45463                            American World Pictures     90.0
#
#        vote_average  vote_count
# 888             7.4       284.0
# 930             8.3         4.0
# 1296            7.2       125.0
# 1832            7.1        48.0
# 1950            6.8       768.0
# ...             ...         ...
# 45415           5.0         1.0
# 45420           6.9        21.0
# 45454           4.0         2.0
# 45460           5.7        26.0
# 45463           3.8         6.0
#
# [1195 rows x 10 columns]

# %%
#dropping
df.drop(df.loc[df['original_title'].duplicated()].index, inplace=True)

# %%
df
# Out:
#        adult                      genres original_language  \
# 0      False   Animation, Comedy, Family                en
# 1      False  Adventure, Fantasy, Family                en
# 2      False             Romance, Comedy                en
# 3      False      Comedy, Drama, Romance                en
# 4      False                      Comedy                en
# ...      ...                         ...               ...
# 45446  False             Fantasy, Comedy                en
# 45449  False           Animation, Family                en
# 45456  False   Horror, Mystery, Thriller                en
# 45458  False                      Horror                en
# 45459  False             Science Fiction                en
#
#                          original_title  \
# 0                             Toy Story
# 1                               Jumanji
# 2                      Grumpier Old Men
# 3                     Waiting to Exhale
# 4           Father of the Bride Part II
# ...                                 ...
# 45446           Le locataire diabolique
# 45449  Pooh's Heffalump Halloween Movie
# 45456                  House of Horrors
# 45458               The Burkittsville 7
# 45459                   Caged Heat 3000
#
#                                                 overview popularity  \
# 0      Led by Woody, Andy's toys live happily in his ...    21.9469
# 1      When siblings Judy and Peter discover an encha...    17.0155
# 2      A family wedding reignites the ancient feud be...    11.7129
# 3      Cheated on, mistreated and stepped on, the wom...    3.85949
# 4      Just when George Banks has recovered from his ...    8.38752
# ...                                                  ...        ...
# 45446  A man rents an apartment and furnishes it in r...   0.725084
# 45449  It's Halloween in the 100 Acre Wood, and Roo's...   2.568495
# 45456  An unsuccessful sculptor saves a madman named ...   0.222814
# 45458  A film archivist revisits the story of Rustin ...    0.38645
# 45459  It's the year 3000 AD. The world's most danger...   0.661558
#
#                                     production_companies  runtime  \
# 0                                Pixar Animation Studios     81.0
# 1      TriStar Pictures, Teitler Film, Interscope Com...    104.0
# 2                           Warner Bros., Lancaster Gate    101.0
# 3                 Twentieth Century Fox Film Corporation    127.0
# 4             Sandollar Productions, Touchstone Pictures    106.0
# ...                                                  ...      ...
# 45446                                  Star Film Company      6.0
# 45449                               Walt Disney Pictures     67.0
# 45456                                 Universal Pictures     65.0
# 45458     Neptune Salad Entertainment, Pirie Productions     30.0
# 45459                              Concorde-New Horizons     85.0
#
#        vote_average  vote_count
# 0               7.7      5415.0
# 1               6.9      2413.0
# 2               6.5        92.0
# 3               6.1        34.0
# 4               5.7       173.0
# ...             ...         ...
# 45446           6.7        12.0
# 45449           5.4         7.0
# 45456           6.3         8.0
# 45458           7.0         1.0
# 45459           3.5         1.0
#
# [22221 rows x 10 columns]

# %%
df.shape
# Out:
# (22221, 10)

# %%
df.loc[df['runtime'] ==  0.000000]
# Out:
#        adult                             genres original_language  \
# 222    False                           Thriller                en
# 667    False                     Drama, Romance                en
# 5188   False                              Drama                en
# 5399   False            Comedy, Family, Romance                en
# 5652   False            Drama, Romance, Foreign                en
# ...      ...                                ...               ...
# 45191  False  Action, Science Fiction, Thriller                en
# 45328  False                              Drama                en
# 45371  False                          Animation                en
# 45416  False                             Comedy                en
# 45430  False          Thriller, Science Fiction                en
#
#                               original_title  \
# 222                                Dream Man
# 667                   The Run of the Country
# 5188                          World Traveler
# 5399             Children on Their Birthdays
# 5652                          Manjar de amor
# ...                                      ...
# 45191                             Drone Wars
# 45328                        Purgatory House
# 45371  LEGO DC Super Hero Girls: Brain Drain
# 45416                Rigadin peintre cubiste
# 45430                           Starquest II
#
#                                                 overview popularity  \
# 222    Kris is a homicide cop with psychic abilities....   0.155859
# 667    An Irish lad (Matt Keeslar) who fled from his ...   0.117662
# 5188   After hitting the road a man encounters charac...    1.25122
# 5399   Havoc is created in a small Southern community...   0.885044
# 5652   Young aspiring pianist attracts attention of f...   0.508711
# ...                                                  ...        ...
# 45191  When drones arrive in a flash, slaughtering hu...   1.451207
# 45328  An inside glimpse of how it feels to be a teen...   0.056262
# 45371  When Supergirl, Wonder Woman, Batgirl, Bumbleb...   8.413734
# 45416  After visiting the first Cubist exposition in ...   0.003732
# 45430            Sci-fi thriller directed by Fred Gallo.   1.188052
#
#                                     production_companies  runtime  \
# 222         Keystone Pictures, Dream Man Productions Inc      0.0
# 667    Castle Rock Entertainment, Columbia Pictures C...      0.0
# 5188                    Eureka Pictures, IFC Productions      0.0
# 5399                              Crusader Entertainment      0.0
# 5652                                       TLA Releasing      0.0
# ...                                                  ...      ...
# 45191                                      Cinetel Films      0.0
# 45328                                Free Dream Pictures      0.0
# 45371                             Warner Bros. Animation      0.0
# 45416                                       Pathé Frères      0.0
# 45430                                  The Pacific Trust      0.0
#
#        vote_average  vote_count
# 222             2.5         1.0
# 667             8.0         2.0
# 5188            5.0         3.0
# 5399            7.0         1.0
# 5652            3.6         4.0
# ...             ...         ...
# 45191           3.0         7.0
# 45328           6.0         1.0
# 45371          10.0         2.0
# 45416           0.0         0.0
# 45430           2.0         1.0
#
# [160 rows x 10 columns]

# %%
df.drop(df.loc[df['runtime'] == 0.00].index, inplace=True)

# %%
df.loc[df['vote_average'] == 0]
# Out:
#        adult                          genres original_language  \
# 164    False                    Drama, Crime                en
# 280    False  Action, Thriller, Crime, Drama                en
# 395    False                 Thriller, Drama                en
# 397    False                          Comedy                en
# 726    False                   Comedy, Drama                en
# ...      ...                             ...               ...
# 44998  False                           Drama                en
# 45006  False                     Documentary                en
# 45013  False                           Drama                en
# 45367  False                 Science Fiction                en
# 45393  False                  Drama, Romance                en
#
#                           original_title  \
# 164                        Feast of July
# 280                         New York Cop
# 395                               Homage
# 397                          Open Season
# 726                  Brothers in Trouble
# ...                                  ...
# 44998                          Losing It
# 45006                              78/52
# 45013               Do You Take This Man
# 45367  The Stranger: Summoned by Shadows
# 45393              Il frullo del passero
#
#                                                 overview popularity  \
# 164    After an abandoned young woman in late 19th Ce...   0.523575
# 280    Allegedly based on a true story, this film fol...   0.004537
# 395    The young caretaker at the estate of a reclusi...   0.014925
# 397    When the television ratings machines suddenly ...   0.012456
# 726    Amir is an illegal Pakistani immigrant smuggle...   0.594716
# ...                                                  ...        ...
# 44998  Comedy-drama about an advertising executive wh...   0.039211
# 45006   78 shots. 52 cuts. The shower scene from PSYCHO.   2.488539
# 45013  When a gay couple's impending wedding hits a s...   0.814903
# 45367  Wearied by his travels through time and space ...    3.5e-05
# 45393  A woman, who has been the mistress of a man wh...   0.138621
#
#                                     production_companies  runtime  \
# 164      Touchstone Pictures, Merchant Ivory Productions    116.0
# 280                  TOEI, Distant Justice Joint Venture     93.0
# 395                Skyline Entertainment Partners, Arrow     97.0
# 397    Home Box Office (HBO), Frozen Rope Productions...     97.0
# 726                                       Renegade Films    102.0
# ...                                                  ...      ...
# 44998                                  Clerkenwell Films     90.0
# 45006                                 Exhibit A Pictures     91.0
# 45013                                        Modern Love     92.0
# 45367                                    BBV Productions     34.0
# 45393                                         Reteitalia     95.0
#
#        vote_average  vote_count
# 164             0.0         0.0
# 280             0.0         0.0
# 395             0.0         0.0
# 397             0.0         0.0
# 726             0.0         0.0
# ...             ...         ...
# 44998           0.0         0.0
# 45006           0.0         4.0
# 45013           0.0         0.0
# 45367           0.0         0.0
# 45393           0.0         0.0
#
# [820 rows x 10 columns]

# %%
df.drop(df.loc[df['vote_average'] == 0.00].index, inplace=True)

# %%
df_eda = df.copy()

# %%
def runtime_bin(x):
    if x['runtime'] < 120:
        if x['runtime'] <= 30:
            return 'Short'
        else :
            return 'Medium'
    else :
        return 'Long'

# %%
df['runtime'] = df.apply(lambda x: runtime_bin(x), axis=1)

# %%
df['popularity'] = df['popularity'].astype('float64')

# %%
df['popularity'] = pd.cut(df['popularity'], bins=3, labels=['Low', 'Medium', 'High'])

# %%
df['vote_average'] = pd.cut(df['vote_average'], bins=3, labels=['Low', 'Medium', 'High'])
df['vote_count'] = pd.cut(df['vote_count'], bins=3, labels=['Low', "Medium", 'High'])

# %%
# mapping adult movies
df['adult'] = df['adult'].astype('string')
df['adult'] = df['adult'].map({"True" : "Adult", "False":"Non-Adult"})

# %%
df.reset_index(inplace=True)

# %% [markdown]
# # EDA

# %%
###Visualization
import matplotlib.pyplot as plt

#selecting jumanji movie to compare which movies are similar?
# similar_jumanji = df_eda.loc[df_eda['original_title'] == 'Jumanji']
# s = similar_jumanji['genres'][0].split(', ')
# print(s)

# %%
#count amount of total genres
def countgenre(data):
  dicts = {}
  # runtimeDict = {}
  i = 0
  for x in data:
    for y in x:
      if y not in dicts.keys():
        dicts[y] = 0
        # runtimeDict[y] = 0
      dicts[y] = int(dicts[y])+1
      # runtimeDict[y] = int(runtimeDict[y])+runtime[i]
    # i += 1
  return dicts

# %%
GENRE = df_eda['genres'].str.split(", ")
# RUNTIME = df_eda['runtime'].values
GENRES = countgenre(GENRE)
GENRES
# Out:
# {'Animation': 977,
#  'Comedy': 6825,
#  'Family': 1713,
#  'Adventure': 2167,
#  'Fantasy': 1273,
#  'Romance': 3612,
#  'Drama': 9636,
#  'Action': 3718,
#  'Crime': 2553,
#  'Thriller': 4612,
#  'Horror': 2862,
#  'History': 660,
#  'Science Fiction': 1930,
#  'Mystery': 1540,
#  'War': 725,
#  'Music': 933,
#  'Documentary': 1244,
#  'Foreign': 261,
#  'Western': 670,
#  'TV Movie': 429}

# %%
colGenre = pd.DataFrame(data=GENRES.keys(),columns=['genres'])
rowGenre = pd.DataFrame(data=GENRES.values(),columns=['count_genre'])
colGenre.reset_index(inplace=True)
rowGenre.reset_index(inplace=True)
Genre = pd.merge(colGenre,rowGenre,on=['index','index'])
Genre
# create count genres dataframe for checking value count each genres
# Out:
#     index           genres  count_genre
# 0       0        Animation          977
# 1       1           Comedy         6825
# 2       2           Family         1713
# 3       3        Adventure         2167
# 4       4          Fantasy         1273
# 5       5          Romance         3612
# 6       6            Drama         9636
# 7       7           Action         3718
# 8       8            Crime         2553
# 9       9         Thriller         4612
# 10     10           Horror         2862
# 11     11          History          660
# 12     12  Science Fiction         1930
# 13     13          Mystery         1540
# 14     14              War          725
# 15     15            Music          933
# 16     16      Documentary         1244
# 17     17          Foreign          261
# 18     18          Western          670
# 19     19         TV Movie          429

# %%
### mostly movies genre
plt.figure(figsize=(30, 10))
ax = sns.barplot(data=Genre.nlargest(32,'count_genre'), x='genres', y='count_genre' )
ax.set_xticklabels(ax.get_xticklabels(), fontsize=20, rotation=40, ha="right")
ax.set_ylabel('Count Genres', fontsize=20)
# Out:
# Text(0, 0.5, 'Count Genres')

# %%
#check the voting, popularity period
f,ax=plt.subplots(1,3,figsize=(20,10))
sns.distplot(df_eda['vote_average'],ax=ax[0])
ax[0].set_title('Vote Average')

sns.distplot(df_eda['popularity'],ax=ax[1])
ax[1].set_title('Popularity')

sns.distplot(df_eda['vote_count'],ax=ax[2])
ax[2].set_title('Vote Count')
plt.show()
# Out:
# C:\Users\MagicPC\AppData\Local\Programs\Python\Python36\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\MagicPC\AppData\Local\Programs\Python\Python36\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\MagicPC\AppData\Local\Programs\Python\Python36\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
plt.figure(figsize=(20,10))
sns.histplot(df_eda['runtime'])
# Out:
# <AxesSubplot:xlabel='runtime', ylabel='Count'>

# %%
listGenre = []
listRuntime = []
for genre, run in zip(df_eda['genres'].str.split(', '), df_eda['runtime']):
    listGenre = listGenre+genre
    listRuntime = listRuntime+[run for i in range(len(genre))]

# %%
new_runtime_genre = pd.DataFrame({
    'genres': listGenre,
    'runtime': listRuntime
})

# %%
new_runtime_genre
# Out:
#                 genres  runtime
# 0            Animation     81.0
# 1               Comedy     81.0
# 2               Family     81.0
# 3            Adventure    104.0
# 4              Fantasy    104.0
# ...                ...      ...
# 48335           Horror     65.0
# 48336          Mystery     65.0
# 48337         Thriller     65.0
# 48338           Horror     30.0
# 48339  Science Fiction     85.0
#
# [48340 rows x 2 columns]

# %%
plt.figure(figsize=(20,14))
sns.boxplot(x='genres', y='runtime', data=new_runtime_genre)
# Out:
# <AxesSubplot:xlabel='genres', ylabel='runtime'>

# %%
#create new dataframe for checking whether how many adult in column adult
check_adult = df.adult.value_counts()
adult_df = pd.DataFrame({"adult" : check_adult.index, "adult_count" : check_adult}).reset_index(drop = True)
adult_df
# Out:
#        adult  adult_count
# 0  Non-Adult        21240
# 1      Adult            1

# %%
plt.figure(figsize = (5, 5))
sns.barplot(data=adult_df, x='adult', y='adult_count',color="#222")
plt.ylabel("Adult and Non-Adult Count")
plt.xlabel("<3")
plt.title("Adult & Non-Adult");

# %% [markdown]
# # Feature Engineering
# ## What feature should I decide to give the model to train itself to be predicting a similarity movie?
#     1. Genre
#     2. Overview
#     4. imdb score

# %%
from sklearn.feature_extraction.text import TfidfVectorizer, CountVectorizer
from sklearn.metrics.pairwise import cosine_similarity, linear_kernel

# %% [markdown]
# ## Drop unnecessary columns

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21241 entries, 0 to 21240
# Data columns (total 11 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   index                 21241 non-null  int64
#  1   adult                 21241 non-null  object
#  2   genres                21241 non-null  object
#  3   original_language     21241 non-null  object
#  4   original_title        21241 non-null  string
#  5   overview              21241 non-null  object
#  6   popularity            21241 non-null  category
#  7   production_companies  21241 non-null  string
#  8   runtime               21241 non-null  object
#  9   vote_average          21241 non-null  category
#  10  vote_count            21241 non-null  category
# dtypes: category(3), int64(1), object(5), string(2)
# memory usage: 1.4+ MB

# %% [markdown]
# ### Combining features
#     - Using 9 features to be combined to create a new columns
#         - Genres
#         - Original_title
#         - Original_language
#         - Overview
#         - Popularity
#         - Production_Companies
#         - Runtime
#         - Vote Average
#         - Vote Count

# %%
# df.drop(columns=['index', 'adult', 'imdb_id', 'id', 'poster_path', 'production_countries', 'revenue', 'release_date', 'status', 'title', 'video', 'budget', 'spoken_languages'], axis=1)

# %%
def combining_features(row):
    return row['genres'] + " " + row['original_title'] + " " + row['production_companies'] + " " + row['original_language'] + " " + row['runtime'] + " " + row['overview'] + " " + row['popularity'] + " " + row['vote_average'] + ' ' + row['vote_count']

# %%
df['combining_features'] = df.apply(combining_features, axis=1)

# %% [markdown]
# # Modeling
#     We have got 2 choices to select which are
#         1. CountVectorizer with Cosine_similarity
#         2. TfidfVectorizer with cosine_similarity

# %% [markdown]
# ## Test case for benchmarking

# %%
dummy_data = 'Jumanji'

# %%
def get_index(title):
    return df.loc[df['original_title'] == title].index.values[0]

# %%
dummy_index = get_index(dummy_data)
dummy_index
# Out:
# 1

# %%
vector = CountVectorizer().fit_transform(df['combining_features'])

# %%
def get_title(index):
    return df.loc[df.index == index]['original_title'].values[0]

# %% [markdown]
# ### CountVectorizer With Cosine_Similarity

# %%
item_similarity = cosine_similarity(vector)

# %%
# vector = CountVectorizer().fit_transform(df['genres'])
item_similarity = list(enumerate(item_similarity[dummy_index]))
sorted_similar_movies = sorted(item_similarity, key=lambda x: x[1], reverse=True)
for j in range(5):
    '''row['genres'] + " " + row['original_title'] + " " + row['production_companies'] + " " + row['original_language'] + " " + row['runtime'] + " " + row['overview'] + " " + row['popularity'] + " " + row['vote_average'] + ' ' + row['vote_count']'''
    genre_print = df.loc[df.index == sorted_similar_movies[j][0]]['genres'].values[0]
    popularity_print = df.loc[df.index == sorted_similar_movies[j][0]]['popularity'].values[0]
    pc_print = df.loc[df.index == sorted_similar_movies[j][0]]['production_companies'].values[0]
    ol_print = df.loc[df.index == sorted_similar_movies[j][0]]['original_language'].values[0]
    runtime_print = df.loc[df.index == sorted_similar_movies[j][0]]['runtime'].values[0]
    va_print = df.loc[df.index == sorted_similar_movies[j][0]]['vote_average'].values[0]
    vc_print = df.loc[df.index == sorted_similar_movies[j][0]]['vote_count'].values[0]
    print(f'Movie title = {get_title(sorted_similar_movies[j][0])}\nMatching Score = {sorted_similar_movies[j][1]}\nGenre = {genre_print}\nOriginal language = {ol_print}\nProduction Companies = {pc_print}\nRuntime = {runtime_print}\nVote Average = {va_print}\nVote Count = {vc_print}\n')
#show another column
# Out:
# Movie title = Jumanji
# Matching Score = 0.9999999999999998
# Genre = Adventure, Fantasy, Family
# Original language = en
# Production Companies = TriStar Pictures, Teitler Film, Interscope Communications
# Runtime = Medium
# Vote Average = High
# Vote Count = Low
#
# Movie title = The Long and the Short and the Tall
# Matching Score = 0.4580130646754981
# Genre = War, Drama
# Original language = en
# Production Companies = Michael Balcon Productions
# Runtime = Medium
# Vote Average = High
# Vote Count = Low
#
# Movie title = Stay Alive
# Matching Score = 0.4562696793638886
# Genre = Horror, Thriller
# Original language = en
# Production Companies = Spyglass Entertainment, Hollywood Pictures, Endgame Entertainment, Wonderland Sound and Vision
# Runtime = Medium
# Vote Average = Medium
# Vote Count = Low
#
# Movie title = Make-Out with Violence
# Matching Score = 0.4561411835274055
# Genre = Comedy, Fantasy, Horror, Romance
# Original language = en
# Production Companies = Limerent Pictures
# Runtime = Medium
# Vote Average = Medium
# Vote Count = Low
#
# Movie title = Beta Test
# Matching Score = 0.4537974525115155
# Genre = Thriller, Action, Science Fiction
# Original language = en
# Production Companies = Mirror Images LTD
# Runtime = Medium
# Vote Average = Medium
# Vote Count = Low

# %% [markdown]
# ### TfidfVectorizer with Cosine_similarity

# %%
vector = TfidfVectorizer().fit_transform(df['combining_features'])

# %%
# vector = TfidfVectorizer(stop_words='english').fit_transform(df['genres'])
item_similarity = cosine_similarity(vector)

# %%
item_similarity = list(enumerate(item_similarity[dummy_index]))
sorted_similar_movies = sorted(item_similarity, key=lambda x: x[1], reverse=True)
for j in range(5):
    '''row['genres'] + " " + row['original_title'] + " " + row['production_companies'] + " " + row['original_language'] + " " + row['runtime'] + " " + row['overview'] + " " + row['popularity'] + " " + row['vote_average'] + ' ' + row['vote_count']'''
    genre_print = df.loc[df.index == sorted_similar_movies[j][0]]['genres'].values[0]
    popularity_print = df.loc[df.index == sorted_similar_movies[j][0]]['popularity'].values[0]
    pc_print = df.loc[df.index == sorted_similar_movies[j][0]]['production_companies'].values[0]
    ol_print = df.loc[df.index == sorted_similar_movies[j][0]]['original_language'].values[0]
    runtime_print = df.loc[df.index == sorted_similar_movies[j][0]]['runtime'].values[0]
    va_print = df.loc[df.index == sorted_similar_movies[j][0]]['vote_average'].values[0]
    vc_print = df.loc[df.index == sorted_similar_movies[j][0]]['vote_count'].values[0]
    print(f'Movie title = {get_title(sorted_similar_movies[j][0])}\nMatching Score = {sorted_similar_movies[j][1]}\nGenre = {genre_print}\nOriginal language = {ol_print}\nProduction Companies = {pc_print}\nRuntime = {runtime_print}\nVote Average = {va_print}\nVote Count = {vc_print}\n')
#show another column
# Out:
# Movie title = Jumanji
# Matching Score = 1.0000000000000002
# Genre = Adventure, Fantasy, Family
# Original language = en
# Production Companies = TriStar Pictures, Teitler Film, Interscope Communications
# Runtime = Medium
# Vote Average = High
# Vote Count = Low
#
# Movie title = The Mindscape of Alan Moore
# Matching Score = 0.17451782241997296
# Genre = Documentary
# Original language = en
# Production Companies = Tale Filmproduktion, Shadowsnake Films
# Runtime = Medium
# Vote Average = Medium
# Vote Count = Low
#
# Movie title = Stay Alive
# Matching Score = 0.16973607773448435
# Genre = Horror, Thriller
# Original language = en
# Production Companies = Spyglass Entertainment, Hollywood Pictures, Endgame Entertainment, Wonderland Sound and Vision
# Runtime = Medium
# Vote Average = Medium
# Vote Count = Low
#
# Movie title = Brainscan
# Matching Score = 0.16879930649784783
# Genre = Fantasy, Horror, Science Fiction
# Original language = en
# Production Companies = Admire Productions Ltd., Coral Productions, Triumph Films
# Runtime = Medium
# Vote Average = Medium
# Vote Count = Low
#
# Movie title = Zathura: A Space Adventure
# Matching Score = 0.16792939189781633
# Genre = Family, Fantasy, Science Fiction, Adventure
# Original language = en
# Production Companies = Columbia Pictures Corporation, Teitler Film, Michael De Luca Productions, Radar Pictures
# Runtime = Medium
# Vote Average = Medium
# Vote Count = Low

# %% [markdown]
# ### Summary

# %% [markdown]
# #### CountVectorizer with cosine_similarity algorithm
# The pair of features_engineering algorithm "CountVectorizer" and the "cosine_similarity" item similarity scoring,
# it results with mid range (0.4-0.6) scores of each movies which are the highest scores.
# so we decided to check whether each movie has the similar type(s) to dummy data ('Jumanji')
# and here is the result :
# ![](img/cc_edited.png)![cc_edited.png](data:image/png;base64,...)
# As you can see that there are four movies that has the similar genres to Jumanji.
# This algorithm takes 32.4 seconds to scoring movies similarity scores

# %% [markdown]
# #### TfidfVectorizer with cosine_similarity algorithm
# The pair of features_engineering algorithm "TfidfVectorizer" and the "linear_kernel" item similarity scoring,
# it results with low range (0.1-0.3) scores of each movies
# so we decided to check whether each movie has the similar type(s) to dummy data ('Jumanji')
# and here is the result :
# ![](img/tc_edited.png)![tc_edited.png](data:image/png;base64,...)
# As you can see that there no movie that has the similar genres to Jumanji (if we don't take comedy movies).
# So we decided to cut this out from benchmark list of algorithms

# %% [markdown]
# # Selected Algorithm and model
# So as the benchmark results say pairing with CountVectorizer and Cosine Similarity model and TfidfVectorizer and Cosine Similarity are not resulted the same. One has high score in similar movies matching score and another has a very low matching score.
#
# According to the result, there's only a pair of algorithms that has the results as developer expected, it is
# ## CountVectorizer with Cosine Similarity

# %% [markdown]
# ## Show similar movies

# %%
cv = CountVectorizer()
vector = cv.fit_transform(df['combining_features'])

# %%
item_similarity = cosine_similarity(vector)

# %%
def get_title(index):
    return df.loc[df.index == index]['original_title'].values[0]

# %%
def test_case_movie(dummy_index):
    similar_movies = list(enumerate(item_similarity[dummy_index]))
    sorted_similar_movies = sorted(similar_movies, key=lambda x: x[1], reverse=True)
    similar_movies_arr = []
    score = []
    for j in range(1, 6):
        similar_movies_arr.append(get_title(sorted_similar_movies[j][0]))
        score.append(sorted_similar_movies[j][1])
    return similar_movies_arr, score

# %%
toy_story = get_index("Toy Story")
jumanji = get_index("Jumanji")
deep_hearts = get_index("Grumpier Old Men")

# %%
similar_toy ,score_toy = test_case_movie(toy_story)

# %%
similar_jumanji ,score_jumanji = test_case_movie(jumanji)

# %%
similar_deep ,score_deep = test_case_movie(deep_hearts)

# %%
# test case toy story
for idx, value in enumerate(similar_toy):
    print(f'Movie title : {value}, Movie Matching Score : {score_toy[j].round(2)}')
# Out:
# Movie title : Toy Story 2, Movie Matching Score : 0.4
# Movie title : Toy Story 3, Movie Matching Score : 0.4
# Movie title : Small Fry, Movie Matching Score : 0.4
# Movie title : The Smurfs, Movie Matching Score : 0.4
# Movie title : Andy Hardy's Private Secretary, Movie Matching Score : 0.4

# %%
for idx, value in enumerate(similar_jumanji):
    print(f'Movie title : {value}, Movie Matching Score : {score_jumanji[j].round(2)}')
# Out:
# Movie title : The Long and the Short and the Tall, Movie Matching Score : 0.45
# Movie title : Stay Alive, Movie Matching Score : 0.45
# Movie title : Make-Out with Violence, Movie Matching Score : 0.45
# Movie title : Beta Test, Movie Matching Score : 0.45
# Movie title : 3 Ninjas, Movie Matching Score : 0.45

# %%
for idx, value in enumerate(similar_deep):
    print(f'Movie title : {value}, Movie Matching Score : {score_deep[j].round(2)}')
# Out:
# Movie title : Robin Redbreast, Movie Matching Score : 0.5
# Movie title : Ella Cinders, Movie Matching Score : 0.5
# Movie title : The Snapper, Movie Matching Score : 0.5
# Movie title : Escape in the Fog, Movie Matching Score : 0.5
# Movie title : The Unsinkable Molly Brown, Movie Matching Score : 0.5

# %% [markdown]
# # Pipeline
# ## Pre-Processing
#     - Remove rows which are null
#     - Remove rows which are duplicated
#     - Correcting genres (into string form)
#     - Mapping genres
#     - Preparing data for modeling

# %%
movies_pipe_line = pd.read_csv('movies_metadata.csv')
# Out:
# C:\Users\MagicPC\AppData\Local\Programs\Python\Python36\lib\site-packages\IPython\core\interactiveshell.py:3072: DtypeWarning: Columns (10) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
class PipeLine:
    def __init__(self, data):
        self.df = data.copy()
    def executeDataPrep(self):
        # drop columns
        self.df = self.df.drop(columns=['adult', 'tagline', 'belongs_to_collection', 'homepage', 'imdb_id', 'id', 'poster_path', 'production_countries', 'revenue', 'release_date', 'status', 'title', 'video', 'budget', 'spoken_languages'], axis=1)
        
        # drop null rows
        self.df.dropna(axis=0, inplace=True)

        # drop duplicated rows
        self.df.drop_duplicates(inplace=True)

        #drop none genres movies
        self.df.drop(self.df.loc[self.df['genres'] == '[]'].index, inplace=True)

        #drop non-en languages
        self.df.drop(self.df.loc[self.df['original_language'] != 'en'].index, inplace=True)

        #drop none production companies filled rows
        self.df.drop(self.df.loc[self.df['production_companies'] == '[]'].index, inplace=True)

        #drop rows that contain 0 votes
        self.df.drop(self.df.loc[self.df['vote_count'] == 0].index, inplace=True)

        #drop rows that container 0.0 vote average
        self.df.drop(self.df.loc[self.df['vote_average'] == 0].index, inplace=True)

        #drop none runtime rows
        self.df.drop(self.df.loc[self.df['runtime'] == 0].index, inplace=True)

        #correcting form of group columns
        regex = re.compile(r": '(.*?)'")
        self.df['genres'] = self.df['genres'].apply(lambda x: ",".join(regex.findall(x)))
        self.df['production_companies'] = self.df['production_companies'].apply(lambda x: ",".join(regex.findall(x)))
        
        #mapping adult column
        # self.df['adult'] = self.df['adult'].astype('string')
        # self.df['adult'] = self.df['adult'].map({
        #     'False' : 'Non-Adult',
        #     'True' : 'Adult'
        # })

        #grouping data
        self.df['runtime'] = self.df.apply(lambda x: self.runtimeMap(x), axis=1)
        # self.df['runtime'] = pd.cut(self.df['runtime'], bins=5, labels=['Short', 'Med-Short', 'Med', "Med-Long", 'Long'])
        self.df['popularity'] = self.df['popularity'].astype('float64')
        self.df['popularity'] = pd.cut(self.df['popularity'], bins=3, labels=['Low', 'Medium', 'High'])
        self.df['vote_average'] = pd.cut(self.df['vote_average'], bins=3, labels=['Low', 'Medium', 'High'])
        self.df['vote_count'] = pd.cut(self.df['vote_count'], bins=3, labels=['Low', 'Medium', 'High'])

        #reset indexes
        self.df = self.df.reset_index(drop=True)

        #combining_features
    def combined_features(self, row):
        return row['genres'] + " " + row['original_title'] + " " + row['production_companies'] + " " + row['original_language'] + " " + row['runtime'] + " " + row['overview'] + " " + row['popularity'] + " " + row['vote_average'] + ' ' + row['vote_count']
    def executeCombiningFeatures(self):
        self.df['combined_features'] = self.df.apply(self.combined_features, axis=1)
    def executeFeatureExtracting(self):
        cv = CountVectorizer()
        vector = cv.fit_transform(self.df['combined_features'])
        return vector
    # def executeCS(self, vector):
    #     itemSimilarity = cosine_similarity(vector)
    #     return itemSimilarity
    def runtimeMap(self, x):
        if x['runtime'] < 120:
            if x['runtime'] <= 30:
                return 'Short'
            else :
                return 'Medium'
        else :
            return 'Long'
    def mainExecute(self):
        self.executeDataPrep()
        self.executeCombiningFeatures()
        vector = self.executeFeatureExtracting()
        # itemSimilarity = self.executeCS(vector)
        return vector

# %%
pipe = PipeLine(movies_pipe_line)
vector = pipe.mainExecute()
pipe.df
# Out:
#                          genres original_language  \
# 0       Animation,Comedy,Family                en
# 1      Adventure,Fantasy,Family                en
# 2                Romance,Comedy                en
# 3          Comedy,Drama,Romance                en
# 4                        Comedy                en
# ...                         ...               ...
# 22392   Horror,Mystery,Thriller                en
# 22393                    Horror                en
# 22394           Science Fiction                en
# 22395      Drama,Action,Romance                en
# 22396     Action,Drama,Thriller                en
#
#                     original_title  \
# 0                        Toy Story
# 1                          Jumanji
# 2                 Grumpier Old Men
# 3                Waiting to Exhale
# 4      Father of the Bride Part II
# ...                            ...
# 22392             House of Horrors
# 22393          The Burkittsville 7
# 22394              Caged Heat 3000
# 22395                   Robin Hood
# 22396                     Betrayal
#
#                                                 overview popularity  \
# 0      Led by Woody, Andy's toys live happily in his ...        Low
# 1      When siblings Judy and Peter discover an encha...        Low
# 2      A family wedding reignites the ancient feud be...        Low
# 3      Cheated on, mistreated and stepped on, the wom...        Low
# 4      Just when George Banks has recovered from his ...        Low
# ...                                                  ...        ...
# 22392  An unsuccessful sculptor saves a madman named ...        Low
# 22393  A film archivist revisits the story of Rustin ...        Low
# 22394  It's the year 3000 AD. The world's most danger...        Low
# 22395  Yet another version of the classic epic, with ...        Low
# 22396  When one of her hits goes wrong, a professiona...        Low
#
#                                     production_companies runtime vote_average  \
# 0                                Pixar Animation Studios  Medium         High
# 1      TriStar Pictures,Teitler Film,Interscope Commu...  Medium         High
# 2                            Warner Bros.,Lancaster Gate  Medium       Medium
# 3                 Twentieth Century Fox Film Corporation    Long       Medium
# 4              Sandollar Productions,Touchstone Pictures  Medium       Medium
# ...                                                  ...     ...          ...
# 22392                                 Universal Pictures  Medium       Medium
# 22393      Neptune Salad Entertainment,Pirie Productions   Short         High
# 22394                              Concorde-New Horizons  Medium          Low
# 22395  Westdeutscher Rundfunk (WDR),Working Title Fil...  Medium       Medium
# 22396                            American World Pictures  Medium       Medium
#
#       vote_count                                  combined_features
# 0         Medium  Animation,Comedy,Family Toy Story Pixar Animat...
# 1            Low  Adventure,Fantasy,Family Jumanji TriStar Pictu...
# 2            Low  Romance,Comedy Grumpier Old Men Warner Bros.,L...
# 3            Low  Comedy,Drama,Romance Waiting to Exhale Twentie...
# 4            Low  Comedy Father of the Bride Part II Sandollar P...
# ...          ...                                                ...
# 22392        Low  Horror,Mystery,Thriller House of Horrors Unive...
# 22393        Low  Horror The Burkittsville 7 Neptune Salad Enter...
# 22394        Low  Science Fiction Caged Heat 3000 Concorde-New H...
# 22395        Low  Drama,Action,Romance Robin Hood Westdeutscher ...
# 22396        Low  Action,Drama,Thriller Betrayal American World ...
#
# [22397 rows x 10 columns]

# %%
itemSimilarity = cosine_similarity(vector)

# %% [markdown]
# # Recommendation Function
#     - Getting an input from users
#     - Finding index of movie name
#     - Getting similar movies as an array
#     - Sorting array
#     - Getting the first 5 positions which are similar to the input

# %%
class Recommender:
    def __init__(self, movieName, movieData, itemSimilarity) -> None:
        self.movieName = movieName
        self.df = movieData.copy()
        self.itemSimilarity = itemSimilarity
    def getIndex(self, movieName):
        return self.df.loc[self.df['original_title'] == movieName].index.values[0]
    def getTitle(self, index):
        return self.df.loc[self.df.index == index]['original_title'].values[0] , self.df.loc[self.df.index == index]['genres'].values[0] , self.df.loc[self.df.index == index]['overview'].values[0]
    def printResult(self, sortedSimilarMovie):
        moviesName = list()
        moviesGenre = list()
        moviesOverview = list()
        moviesScore = list()
        for j in range(1, 6):
            setMovieName, setMovieGenre, setMovieOverview = self.getTitle(sortedSimilarMovie[j][0])
            moviesName.append(setMovieName)
            moviesGenre.append(setMovieGenre)
            moviesOverview.append(setMovieOverview)
            moviesScore.append(sortedSimilarMovie[j][1])
            print(f'Movie name = {self.getTitle(sortedSimilarMovie[j][0])} |   Movie Score = {sortedSimilarMovie[j][1].round(2)}')
        return moviesName, moviesOverview, moviesGenre, moviesScore
    def recommend(self, movieName):
        movieIndex = self.getIndex(movieName)
        similarMovie = list(enumerate(self.itemSimilarity[movieIndex]))
        sortedSimilarMovie = sorted(similarMovie, key=lambda x:x[1], reverse=True)
        moviesName, moviesOverview, moviesGenre, moviesScore = self.printResult(sortedSimilarMovie)
        preferedMovieGenre = self.df.loc[self.df['original_title'] == movieName]['genres'].values[0]
        preferedMovieOverview = self.df.loc[self.df['original_title'] == movieName]['overview'].values[0]
        preferedMovieStatement = '-'*50+ f'\n| Movie title : {movieName} |\n| Genre : {preferedMovieGenre} |\n| Overview : {preferedMovieOverview} |\n' + '-'*50
        output = f'The most similar movie is => {moviesName[0]}\nGenre = {moviesGenre[0]}\nOverview : {moviesOverview[0]}\nMatching score = {(moviesScore[0] * 100).round(2)}%\n\nThe 2nd similar movie is => {moviesName[1]}\nGenre = {moviesGenre[1]}\nOverview : {moviesOverview[1]}\nMatching score = {(moviesScore[1]*100).round(2)}%\n\nThe 3rd similar movie is => {moviesName[2]}\nGenre = {moviesGenre[2]}\nOverview : {moviesOverview[2]}\nMatching score = {(moviesScore[2]*100).round(2)}%\n\nThe 4th similar movie is => {moviesName[3]}\nGenre = {moviesGenre[3]}\nOverview : {moviesOverview[3]}\nMatching score = {(moviesScore[3]*100).round(2)}%\n\nThe 5th similar movie is => {moviesName[4]}\nGenre = {moviesGenre[4]}\nOverview : {moviesOverview[4]}\nMatching score = {(moviesScore[4]*100).round(2)}%\n'
        return preferedMovieStatement, output

# %%
rcmder = Recommender('Jumanji', movieData=pipe.df, itemSimilarity=itemSimilarity)

# %% [markdown]
# # Deployment
#     - Web app
#         - Getting an input in string form. (Movie name)
#         - Output as a set of movies with its detail.

# %%
import gradio

# %%
iface = gradio.Interface(fn=rcmder.recommend,
                     inputs=[gradio.inputs.Textbox(label='Enter Movie Name', default='Jumanji')],
                     outputs=[gradio.outputs.Textbox(label="User preference movie"),
                     gradio.outputs.Textbox(label="Similar movies")])
iface.launch()
# Out:
# Running on local URL:  http://127.0.0.1:7860/
#
# To create a public link, set `share=True` in `launch()`.
#         <iframe
#             width="900"
#             height="500"
#             src="http://127.0.0.1:7860/"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>
# (<Flask 'gradio.networking'>, 'http://127.0.0.1:7860/', None)
# Movie name = ('The Long and the Short and the Tall', 'War,Drama', 'Based on a play by Willis Hall. A troop of British soldiers are out in the jungle to record jungle noises and troop noises in the jungle so that the recordings can be played back by other troops to divert the enemy to their whereabouts. As they progress to what they think is closer to the base camp they find themselves farther and farther from radio range until the only channel they can get clearly is that of a Japanese broadcast. They now realize they are probably only 10 to 15 miles from a Japanese camp! The tension is added to by rowdy and openly admitted "non-hero" Private Bamforth who has nothing good to say about anyone and especially Corporal Johnstone (who holds an equal dislike for Bamforth). When a Japanese soldier is taken as their prisoner, the true colors of each man comes to the surface') |   Movie Score = 0.46
# Movie name = ('Stay Alive', 'Horror,Thriller', 'After the mysterious, brutal death of an old friend, a group of teenagers find themselves in possession of "Stay Alive," an ultra-realistic 3-D videogame based on the spine-chilling true story of a 17th century noblewoman, known as "The Blood Countess." The gamers don\'t know anything about the game other than they\'re not supposed to have it... and they\'re dying to play it. Not able to resist temptation, the kids begin to play the grisly game but soon make a chilling connection -- they are each being murdered one-by-one in the same way as the characters they played in the game. As the line between the game world and the real world disappears, the teens must find a way to defeat the vicious and merciless Blood Countess, all the while trying to... stay alive.') |   Movie Score = 0.46
# Movie name = ('Make-Out with Violence', 'Comedy,Fantasy,Horror,Romance', "A genre-bending tale of a boy trying to fulfill his unrequited love for a girl who has risen from the dead. It tells the story of twin brothers Patrick and Carol Darling, newly graduated from high school and struggling to come to terms with the mysterious disappearance of their friend, the bright and beautiful Wendy Hearst. When a drive through the countryside surrounding their suburban community leads to the discovery of Wendy's mysteriously animated corpse, the boys secretly transport the un-dead Wendy to an empty house in hopes of somehow bringing her back to life. As the sweltering summer pushes on, they must maintain the appearance of normalcy for their friends and family as they search for ways to revive the Wendy they once knew, or, failing that, to satisfy their own quests for love amongst the living and the dead.") |   Movie Score = 0.46
# Movie name = ('Beta Test', 'Thriller,Action,Science Fiction', "While testing the latest first person shooter from global game developer, Sentinel, video game champion Max Troy discovers the events happening within the game are being reflected in the real world. He soon determines that the game's protagonist is real-life Orson Creed, an ex-Sentinel employee who is being remotely controlled by the corporation for reasons unknown. As virtual and real worlds collide, Max and Creed must join forces to unravel the conspiracy before the game's sinister events escalate and overwhelm the city.") |   Movie Score = 0.45
# Movie name = ('3 Ninjas', 'Action,Adventure,Comedy,Family', "Each year, three brothers Samuel, Jeffrey and Michael Douglas visits their Japanese grandfather, Mori Shintaro whom the boys affectionately refer to as Grandpa, for the summer. Mori is a highly skilled in the fields of Martial arts and Ninjutsu, and for years he has trained the boys in his techniques. After an organized crime ring proves to be too much for the FBI, it's time for the 3 brother NINJAS! To use their martial arts skills, they team up to battle the crime ring and outwit some very persistent kidnappers!") |   Movie Score = 0.45
# Movie name = ('Toy Story 2', 'Animation,Comedy,Family', "Andy heads off to Cowboy Camp, leaving his toys to their own devices. Things shift into high gear when an obsessive toy collector named Al McWhiggen, owner of Al's Toy Barn kidnaps Woody. Andy's toys mount a daring rescue mission, Buzz Lightyear meets his match and Woody has to decide where he and his heart truly belong.") |   Movie Score = 0.55
# Movie name = ('Toy Story 3', 'Animation,Family,Comedy', "Woody, Buzz, and the rest of Andy's toys haven't been played with in years. With Andy about to go to college, the gang find themselves accidentally left at a nefarious day care center. The toys must band together to escape and return home to Andy.") |   Movie Score = 0.52
# Movie name = ('Small Fry', 'Animation,Family', 'A fast food restaurant mini variant of Buzz forcibly switches places with the real Buzz and his friends have to deal with the obnoxious impostor.') |   Movie Score = 0.41
# Movie name = ('The Smurfs', 'Animation,Family,Adventure,Comedy,Fantasy', 'When the evil wizard Gargamel chases the tiny blue Smurfs out of their village, they tumble from their magical world and into ours -- in fact, smack dab in the middle of Central Park. Just three apples high and stuck in the Big Apple, the Smurfs must find a way to get back to their village before Gargamel tracks them down.') |   Movie Score = 0.4
# Movie name = ("Andy Hardy's Private Secretary", 'Comedy,Romance', 'Andy\'s gone and done it this time. All set to graduate from high school and he flunks his English exam -- in spite of the fact that Aunt Milly is his teacher, and that the Judge has gone to all the trouble of getting him his very own private secretary (Kathryn Grayson in her screen debut). What makes this Andy Hardy movie, according to The Hollywood Reporter, "even better than the wildly cheered Love Finds Andy Hardy?" It could be Mickey Rooney\'s irresistible charm. Or could it be the perfected plot of Andy juggling his steady love (Polly Benedict) with his growing affections for another girl? Or perhaps it\'s the nonstop laughs Rooney generates with such antics as trying to buy ladies\' hose or letting the Judge take a spin in his jalopy in the pouring rain. Whatever the case, here\'s your chance to return to a simpler and happier time with the family America loved to love.') |   Movie Score = 0.4
# Movie name = ('Robin Redbreast', 'Drama,Horror,Mystery', 'After the break-up of a long-term relationship, urban sophisticate Norah seeks refuge in a remote house in the country. The locals are friendly, if eccentric, and she toys with the idea of a flirtation with dishy young gamekeeper Rob. But events at Harvest Festival leave her feeling manipulated, and six months later, with the consequences all too evident, she finds herself trapped in what is more like a nightmare. What role is she destined to play in the cycle of the seasons -- and of the generations?') |   Movie Score = 0.52
# Movie name = ('Ella Cinders', 'Romance,Comedy', 'Poor Ella Cinders is much abused by her evil step-mother and step-sisters. When she wins a local beauty contest she jumps at the chance to get out of her dead-end life and go to Hollywood, where she is promised a job in the movies. When she arrives in Hollywood, she discovers that the contest was a scam and the job non-existent. But through pluck, luck, and talent, she makes it in the movies anyway, and finds true love.') |   Movie Score = 0.52
# Movie name = ('The Snapper', 'Comedy,Drama', 'Set in Ireland, Sharon Curley is a 20 year old living with her parents and many brothers and sisters. When she gets herself pregnant and refuses to name the father, she becomes the talk of the town.') |   Movie Score = 0.51
# Movie name = ('Escape in the Fog', 'Mystery,Thriller', 'A nurse recovering in a hospital from a nervous breakdown keeps having dreams where she sees two men trying to murder a third. When she meets the the officer in charge of psychology at the hospital, she is astounded to discover that he is the man in her dream who is the intended murder victim.') |   Movie Score = 0.5
# Movie name = ('The Unsinkable Molly Brown', 'Comedy,Music', "Majestic mountains are in the background and a waterfall in the foreground. Is that a canoe on the river? No it's a cradle with a baby. The buoyant Molly Brown has survived the first crisis of her life -- a flood. Sixteen years later she sets out to make her way in the world. Can she sing and play the piano? She assures the Leadville saloon keeper that she can and learns quickly. Soon she is the bride of Johnny Brown, who in a few years will be able to replace the original cigar wrapper wedding ring with a replica in gold and gemstones. But it takes more than a few million dollars to be accepted by Denver society. The Browns head for Europe and bring a few crowned heads back to Denver for a party that turns into a ballroom brawl. Molly goes to Europe alone, returning on the Titanic. She didn't survive a flood as a baby for the story to end here.") |   Movie Score = 0.5
# Movie name = ('The Long and the Short and the Tall', 'War,Drama', 'Based on a play by Willis Hall. A troop of British soldiers are out in the jungle to record jungle noises and troop noises in the jungle so that the recordings can be played back by other troops to divert the enemy to their whereabouts. As they progress to what they think is closer to the base camp they find themselves farther and farther from radio range until the only channel they can get clearly is that of a Japanese broadcast. They now realize they are probably only 10 to 15 miles from a Japanese camp! The tension is added to by rowdy and openly admitted "non-hero" Private Bamforth who has nothing good to say about anyone and especially Corporal Johnstone (who holds an equal dislike for Bamforth). When a Japanese soldier is taken as their prisoner, the true colors of each man comes to the surface') |   Movie Score = 0.46
# Movie name = ('Stay Alive', 'Horror,Thriller', 'After the mysterious, brutal death of an old friend, a group of teenagers find themselves in possession of "Stay Alive," an ultra-realistic 3-D videogame based on the spine-chilling true story of a 17th century noblewoman, known as "The Blood Countess." The gamers don\'t know anything about the game other than they\'re not supposed to have it... and they\'re dying to play it. Not able to resist temptation, the kids begin to play the grisly game but soon make a chilling connection -- they are each being murdered one-by-one in the same way as the characters they played in the game. As the line between the game world and the real world disappears, the teens must find a way to defeat the vicious and merciless Blood Countess, all the while trying to... stay alive.') |   Movie Score = 0.46
# Movie name = ('Make-Out with Violence', 'Comedy,Fantasy,Horror,Romance', "A genre-bending tale of a boy trying to fulfill his unrequited love for a girl who has risen from the dead. It tells the story of twin brothers Patrick and Carol Darling, newly graduated from high school and struggling to come to terms with the mysterious disappearance of their friend, the bright and beautiful Wendy Hearst. When a drive through the countryside surrounding their suburban community leads to the discovery of Wendy's mysteriously animated corpse, the boys secretly transport the un-dead Wendy to an empty house in hopes of somehow bringing her back to life. As the sweltering summer pushes on, they must maintain the appearance of normalcy for their friends and family as they search for ways to revive the Wendy they once knew, or, failing that, to satisfy their own quests for love amongst the living and the dead.") |   Movie Score = 0.46
# Movie name = ('Beta Test', 'Thriller,Action,Science Fiction', "While testing the latest first person shooter from global game developer, Sentinel, video game champion Max Troy discovers the events happening within the game are being reflected in the real world. He soon determines that the game's protagonist is real-life Orson Creed, an ex-Sentinel employee who is being remotely controlled by the corporation for reasons unknown. As virtual and real worlds collide, Max and Creed must join forces to unravel the conspiracy before the game's sinister events escalate and overwhelm the city.") |   Movie Score = 0.45
# Movie name = ('3 Ninjas', 'Action,Adventure,Comedy,Family', "Each year, three brothers Samuel, Jeffrey and Michael Douglas visits their Japanese grandfather, Mori Shintaro whom the boys affectionately refer to as Grandpa, for the summer. Mori is a highly skilled in the fields of Martial arts and Ninjutsu, and for years he has trained the boys in his techniques. After an organized crime ring proves to be too much for the FBI, it's time for the 3 brother NINJAS! To use their martial arts skills, they team up to battle the crime ring and outwit some very persistent kidnappers!") |   Movie Score = 0.45
# Movie name = ('Toy Story 2', 'Animation,Comedy,Family', "Andy heads off to Cowboy Camp, leaving his toys to their own devices. Things shift into high gear when an obsessive toy collector named Al McWhiggen, owner of Al's Toy Barn kidnaps Woody. Andy's toys mount a daring rescue mission, Buzz Lightyear meets his match and Woody has to decide where he and his heart truly belong.") |   Movie Score = 0.55
# Movie name = ('Toy Story 3', 'Animation,Family,Comedy', "Woody, Buzz, and the rest of Andy's toys haven't been played with in years. With Andy about to go to college, the gang find themselves accidentally left at a nefarious day care center. The toys must band together to escape and return home to Andy.") |   Movie Score = 0.52
# Movie name = ('Small Fry', 'Animation,Family', 'A fast food restaurant mini variant of Buzz forcibly switches places with the real Buzz and his friends have to deal with the obnoxious impostor.') |   Movie Score = 0.41
# Movie name = ('The Smurfs', 'Animation,Family,Adventure,Comedy,Fantasy', 'When the evil wizard Gargamel chases the tiny blue Smurfs out of their village, they tumble from their magical world and into ours -- in fact, smack dab in the middle of Central Park. Just three apples high and stuck in the Big Apple, the Smurfs must find a way to get back to their village before Gargamel tracks them down.') |   Movie Score = 0.4
# Movie name = ("Andy Hardy's Private Secretary", 'Comedy,Romance', 'Andy\'s gone and done it this time. All set to graduate from high school and he flunks his English exam -- in spite of the fact that Aunt Milly is his teacher, and that the Judge has gone to all the trouble of getting him his very own private secretary (Kathryn Grayson in her screen debut). What makes this Andy Hardy movie, according to The Hollywood Reporter, "even better than the wildly cheered Love Finds Andy Hardy?" It could be Mickey Rooney\'s irresistible charm. Or could it be the perfected plot of Andy juggling his steady love (Polly Benedict) with his growing affections for another girl? Or perhaps it\'s the nonstop laughs Rooney generates with such antics as trying to buy ladies\' hose or letting the Judge take a spin in his jalopy in the pouring rain. Whatever the case, here\'s your chance to return to a simpler and happier time with the family America loved to love.') |   Movie Score = 0.4
# Movie name = ('Robin Redbreast', 'Drama,Horror,Mystery', 'After the break-up of a long-term relationship, urban sophisticate Norah seeks refuge in a remote house in the country. The locals are friendly, if eccentric, and she toys with the idea of a flirtation with dishy young gamekeeper Rob. But events at Harvest Festival leave her feeling manipulated, and six months later, with the consequences all too evident, she finds herself trapped in what is more like a nightmare. What role is she destined to play in the cycle of the seasons -- and of the generations?') |   Movie Score = 0.52
# Movie name = ('Ella Cinders', 'Romance,Comedy', 'Poor Ella Cinders is much abused by her evil step-mother and step-sisters. When she wins a local beauty contest she jumps at the chance to get out of her dead-end life and go to Hollywood, where she is promised a job in the movies. When she arrives in Hollywood, she discovers that the contest was a scam and the job non-existent. But through pluck, luck, and talent, she makes it in the movies anyway, and finds true love.') |   Movie Score = 0.52
# Movie name = ('The Snapper', 'Comedy,Drama', 'Set in Ireland, Sharon Curley is a 20 year old living with her parents and many brothers and sisters. When she gets herself pregnant and refuses to name the father, she becomes the talk of the town.') |   Movie Score = 0.51
# Movie name = ('Escape in the Fog', 'Mystery,Thriller', 'A nurse recovering in a hospital from a nervous breakdown keeps having dreams where she sees two men trying to murder a third. When she meets the the officer in charge of psychology at the hospital, she is astounded to discover that he is the man in her dream who is the intended murder victim.') |   Movie Score = 0.5
# Movie name = ('The Unsinkable Molly Brown', 'Comedy,Music', "Majestic mountains are in the background and a waterfall in the foreground. Is that a canoe on the river? No it's a cradle with a baby. The buoyant Molly Brown has survived the first crisis of her life -- a flood. Sixteen years later she sets out to make her way in the world. Can she sing and play the piano? She assures the Leadville saloon keeper that she can and learns quickly. Soon she is the bride of Johnny Brown, who in a few years will be able to replace the original cigar wrapper wedding ring with a replica in gold and gemstones. But it takes more than a few million dollars to be accepted by Denver society. The Browns head for Europe and bring a few crowned heads back to Denver for a party that turns into a ballroom brawl. Molly goes to Europe alone, returning on the Titanic. She didn't survive a flood as a baby for the story to end here.") |   Movie Score = 0.5

# %% [markdown]
# # References
#     - https://www.kaggle.com/bentan233/movie-recommender-systems
#     - https://www.kaggle.com/hankarmostafa/building-a-simple-movie-recommendation-system
#     - https://www.kaggle.com/jashandeepkaur06/tmdb-movies-eda-jk#Project:-Investigating-TMDb-dataset
#     - https://www.kaggle.com/rounakbanik/the-movies-dataset
#     - https://github.com/MacClay/CS434/blob/main/cs434_finalexam__%E0%B8%AD%E0%B8%B5%E0%B8%AB%E0%B8%A2%E0%B8%B1%E0%B8%87%E0%B8%A7%E0%B8%B0_%E0%B8%AB%E0%B9%89%E0%B8%A7%E0%B8%A2_!_.ipynb

# %% [markdown]
# # Members
#     - Krittinaphat Srisuwan 1620704823
#     - Tanabut Porka 1620703254
#     - Teerapop Junchean 1620703312
