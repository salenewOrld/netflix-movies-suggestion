# %% [markdown]
# # Check whether this thing is working

# %%
"Hello World"
# Out:
# 'Hello World'

# %% [markdown]
# # DNA Framework

# %% [markdown]
# # Import libraries

# %%
import numpy
import seaborn as sns
import matplotlib as plt
import re
import sklearn
import pandas as pd

# %% [markdown]
# # Import Dataset

# %%
movies = pd.read_csv('movies_metadata.csv')
movies_pipe_line = movies.copy()
# Out:
# C:\Python\lib\site-packages\IPython\core\interactiveshell.py:3457: DtypeWarning: Columns (10) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %% [markdown]
# # Data pre-processing

# %%
movies.isna().sum()
# Out:
# adult                        0
# belongs_to_collection    40972
# budget                       0
# genres                       0
# homepage                 37684
# id                           0
# imdb_id                     17
# original_language           11
# original_title               0
# overview                   954
# popularity                   5
# poster_path                386
# production_companies         3
# production_countries         3
# release_date                87
# revenue                      6
# runtime                    263
# spoken_languages             6
# status                      87
# tagline                  25054
# title                        6
# video                        6
# vote_average                 6
# vote_count                   6
# dtype: int64

# %%
movies.columns
# Out:
# Index(['adult', 'belongs_to_collection', 'budget', 'genres', 'homepage', 'id',
#        'imdb_id', 'original_language', 'original_title', 'overview',
#        'popularity', 'poster_path', 'production_companies',
#        'production_countries', 'release_date', 'revenue', 'runtime',
#        'spoken_languages', 'status', 'tagline', 'title', 'video',
#        'vote_average', 'vote_count'],
#       dtype='object')

# %%
movies.duplicated().sum()
# Out:
# 13

# %%
movies.drop_duplicates(inplace=True)

# %%
movies.reset_index()
# Out:
#        index  adult                              belongs_to_collection  \
# 0          0  False  {'id': 10194, 'name': 'Toy Story Collection', ...
# 1          1  False                                                NaN
# 2          2  False  {'id': 119050, 'name': 'Grumpy Old Men Collect...
# 3          3  False                                                NaN
# 4          4  False  {'id': 96871, 'name': 'Father of the Bride Col...
# ...      ...    ...                                                ...
# 45448  45461  False                                                NaN
# 45449  45462  False                                                NaN
# 45450  45463  False                                                NaN
# 45451  45464  False                                                NaN
# 45452  45465  False                                                NaN
#
#          budget                                             genres  \
# 0      30000000  [{'id': 16, 'name': 'Animation'}, {'id': 35, '...
# 1      65000000  [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...
# 2             0  [{'id': 10749, 'name': 'Romance'}, {'id': 35, ...
# 3      16000000  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 4             0                     [{'id': 35, 'name': 'Comedy'}]
# ...         ...                                                ...
# 45448         0  [{'id': 18, 'name': 'Drama'}, {'id': 10751, 'n...
# 45449         0                      [{'id': 18, 'name': 'Drama'}]
# 45450         0  [{'id': 28, 'name': 'Action'}, {'id': 18, 'nam...
# 45451         0                                                 []
# 45452         0                                                 []
#
#                                    homepage      id    imdb_id  \
# 0      http://toystory.disney.com/toy-story     862  tt0114709
# 1                                       NaN    8844  tt0113497
# 2                                       NaN   15602  tt0113228
# 3                                       NaN   31357  tt0114885
# 4                                       NaN   11862  tt0113041
# ...                                     ...     ...        ...
# 45448  http://www.imdb.com/title/tt6209470/  439050  tt6209470
# 45449                                   NaN  111109  tt2028550
# 45450                                   NaN   67758  tt0303758
# 45451                                   NaN  227506  tt0008536
# 45452                                   NaN  461257  tt6980792
#
#       original_language               original_title  ... release_date  \
# 0                    en                    Toy Story  ...   1995-10-30
# 1                    en                      Jumanji  ...   1995-12-15
# 2                    en             Grumpier Old Men  ...   1995-12-22
# 3                    en            Waiting to Exhale  ...   1995-12-22
# 4                    en  Father of the Bride Part II  ...   1995-02-10
# ...                 ...                          ...  ...          ...
# 45448                fa                      رگ خواب  ...          NaN
# 45449                tl          Siglo ng Pagluluwal  ...   2011-11-17
# 45450                en                     Betrayal  ...   2003-08-01
# 45451                en          Satana likuyushchiy  ...   1917-10-21
# 45452                en                     Queerama  ...   2017-06-09
#
#            revenue runtime                                   spoken_languages  \
# 0      373554033.0    81.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 1      262797249.0   104.0  [{'iso_639_1': 'en', 'name': 'English'}, {'iso...
# 2              0.0   101.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 3       81452156.0   127.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 4       76578911.0   106.0           [{'iso_639_1': 'en', 'name': 'English'}]
# ...            ...     ...                                                ...
# 45448          0.0    90.0             [{'iso_639_1': 'fa', 'name': 'فارسی'}]
# 45449          0.0   360.0                  [{'iso_639_1': 'tl', 'name': ''}]
# 45450          0.0    90.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 45451          0.0    87.0                                                 []
# 45452          0.0    75.0           [{'iso_639_1': 'en', 'name': 'English'}]
#
#          status                                            tagline  \
# 0      Released                                                NaN
# 1      Released          Roll the dice and unleash the excitement!
# 2      Released  Still Yelling. Still Fighting. Still Ready for...
# 3      Released  Friends are the people who let you be yourself...
# 4      Released  Just When His World Is Back To Normal... He's ...
# ...         ...                                                ...
# 45448  Released         Rising and falling between a man and woman
# 45449  Released                                                NaN
# 45450  Released                             A deadly game of wits.
# 45451  Released                                                NaN
# 45452  Released                                                NaN
#
#                              title  video vote_average vote_count
# 0                        Toy Story  False          7.7     5415.0
# 1                          Jumanji  False          6.9     2413.0
# 2                 Grumpier Old Men  False          6.5       92.0
# 3                Waiting to Exhale  False          6.1       34.0
# 4      Father of the Bride Part II  False          5.7      173.0
# ...                            ...    ...          ...        ...
# 45448                       Subdue  False          4.0        1.0
# 45449          Century of Birthing  False          9.0        3.0
# 45450                     Betrayal  False          3.8        6.0
# 45451             Satan Triumphant  False          0.0        0.0
# 45452                     Queerama  False          0.0        0.0
#
# [45453 rows x 25 columns]

# %%
movies.duplicated().sum()
# Out:
# 0

# %%
movies['overview']
# Out:
# 0        Led by Woody, Andy's toys live happily in his ...
# 1        When siblings Judy and Peter discover an encha...
# 2        A family wedding reignites the ancient feud be...
# 3        Cheated on, mistreated and stepped on, the wom...
# 4        Just when George Banks has recovered from his ...
#                                ...
# 45461          Rising and falling between a man and woman.
# 45462    An artist struggles to finish his work while a...
# 45463    When one of her hits goes wrong, a professiona...
# 45464    In a small town live two brothers, one a minis...
# 45465    50 years after decriminalisation of homosexual...
# Name: overview, Length: 45453, dtype: object

# %%
movies.shape
# Out:
# (45453, 24)

# %% [markdown]
# ## To see that how do the NA columns look like

# %%
movies.isna().sum()
# Out:
# adult                        0
# belongs_to_collection    40959
# budget                       0
# genres                       0
# homepage                 37673
# id                           0
# imdb_id                     17
# original_language           11
# original_title               0
# overview                   954
# popularity                   5
# poster_path                386
# production_companies         3
# production_countries         3
# release_date                87
# revenue                      6
# runtime                    263
# spoken_languages             6
# status                      87
# tagline                  25045
# title                        6
# video                        6
# vote_average                 6
# vote_count                   6
# dtype: int64

# %%
#Check null first
movies.loc[movies['homepage'].isnull()].head(5)
# Out:
#    adult                              belongs_to_collection    budget  \
# 1  False                                                NaN  65000000
# 2  False  {'id': 119050, 'name': 'Grumpy Old Men Collect...         0
# 3  False                                                NaN  16000000
# 4  False  {'id': 96871, 'name': 'Father of the Bride Col...         0
# 5  False                                                NaN  60000000
#
#                                               genres homepage     id  \
# 1  [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...      NaN   8844
# 2  [{'id': 10749, 'name': 'Romance'}, {'id': 35, ...      NaN  15602
# 3  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...      NaN  31357
# 4                     [{'id': 35, 'name': 'Comedy'}]      NaN  11862
# 5  [{'id': 28, 'name': 'Action'}, {'id': 80, 'nam...      NaN    949
#
#      imdb_id original_language               original_title  \
# 1  tt0113497                en                      Jumanji
# 2  tt0113228                en             Grumpier Old Men
# 3  tt0114885                en            Waiting to Exhale
# 4  tt0113041                en  Father of the Bride Part II
# 5  tt0113277                en                         Heat
#
#                                             overview  ... release_date  \
# 1  When siblings Judy and Peter discover an encha...  ...   1995-12-15
# 2  A family wedding reignites the ancient feud be...  ...   1995-12-22
# 3  Cheated on, mistreated and stepped on, the wom...  ...   1995-12-22
# 4  Just when George Banks has recovered from his ...  ...   1995-02-10
# 5  Obsessive master thief, Neil McCauley leads a ...  ...   1995-12-15
#
#        revenue runtime                                   spoken_languages  \
# 1  262797249.0   104.0  [{'iso_639_1': 'en', 'name': 'English'}, {'iso...
# 2          0.0   101.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 3   81452156.0   127.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 4   76578911.0   106.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 5  187436818.0   170.0  [{'iso_639_1': 'en', 'name': 'English'}, {'iso...
#
#      status                                            tagline  \
# 1  Released          Roll the dice and unleash the excitement!
# 2  Released  Still Yelling. Still Fighting. Still Ready for...
# 3  Released  Friends are the people who let you be yourself...
# 4  Released  Just When His World Is Back To Normal... He's ...
# 5  Released                           A Los Angeles Crime Saga
#
#                          title  video vote_average vote_count
# 1                      Jumanji  False          6.9     2413.0
# 2             Grumpier Old Men  False          6.5       92.0
# 3            Waiting to Exhale  False          6.1       34.0
# 4  Father of the Bride Part II  False          5.7      173.0
# 5                         Heat  False          7.7     1886.0
#
# [5 rows x 24 columns]

# %%
#check not null
movies.loc[movies['homepage'].notnull()].head()
# Out:
#     adult                              belongs_to_collection    budget  \
# 0   False  {'id': 10194, 'name': 'Toy Story Collection', ...  30000000
# 9   False  {'id': 645, 'name': 'James Bond Collection', '...  58000000
# 24  False                                                NaN   3600000
# 46  False                                                NaN  33000000
# 49  False                                                NaN   6000000
#
#                                                genres  \
# 0   [{'id': 16, 'name': 'Animation'}, {'id': 35, '...
# 9   [{'id': 12, 'name': 'Adventure'}, {'id': 28, '...
# 24  [{'id': 18, 'name': 'Drama'}, {'id': 10749, 'n...
# 46  [{'id': 80, 'name': 'Crime'}, {'id': 9648, 'na...
# 49  [{'id': 18, 'name': 'Drama'}, {'id': 80, 'name...
#
#                                              homepage   id    imdb_id  \
# 0                http://toystory.disney.com/toy-story  862  tt0114709
# 9        http://www.mgm.com/view/movie/757/Goldeneye/  710  tt0113189
# 24  http://www.mgm.com/title_title.do?title_star=L...  451  tt0113627
# 46                         http://www.sevenmovie.com/  807  tt0114369
# 49  http://www.mgm.com/#/our-titles/2083/The-Usual...  629  tt0114814
#
#    original_language      original_title  \
# 0                 en           Toy Story
# 9                 en           GoldenEye
# 24                en   Leaving Las Vegas
# 46                en               Se7en
# 49                en  The Usual Suspects
#
#                                              overview  ... release_date  \
# 0   Led by Woody, Andy's toys live happily in his ...  ...   1995-10-30
# 9   James Bond must unmask the mysterious head of ...  ...   1995-11-16
# 24  Ben Sanderson, an alcoholic Hollywood screenwr...  ...   1995-10-27
# 46  Two homicide detectives are on a desperate hun...  ...   1995-09-22
# 49  Held in an L.A. interrogation room, Verbal Kin...  ...   1995-07-19
#
#         revenue runtime                                   spoken_languages  \
# 0   373554033.0    81.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 9   352194034.0   130.0  [{'iso_639_1': 'en', 'name': 'English'}, {'iso...
# 24   49800000.0   112.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 46  327311859.0   127.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 49   23341568.0   106.0  [{'iso_639_1': 'es', 'name': 'Español'}, {'iso...
#
#       status                                       tagline  \
# 0   Released                                           NaN
# 9   Released          No limits. No fears. No substitutes.
# 24  Released                I Love You... The Way You Are.
# 46  Released         Seven deadly sins. Seven ways to die.
# 49  Released  Five Criminals. One Line Up. No Coincidence.
#
#                  title  video vote_average vote_count
# 0            Toy Story  False          7.7     5415.0
# 9            GoldenEye  False          6.6     1194.0
# 24   Leaving Las Vegas  False          7.1      365.0
# 46               Se7en  False          8.1     5915.0
# 49  The Usual Suspects  False          8.1     3334.0
#
# [5 rows x 24 columns]

# %%
# We already know that HomePage column is just a hompage of each movies
# Out objective is to recommend movies to user so, homepage isn't that neccessary
# How about drop the column?
# Yes of course that's a great idea
# but we must first create another dataFrame so, we won't end up like s*** if we f***ed up
df = movies.copy()

# %%
#dropping
df.drop('homepage', axis='columns', inplace=True)

# %%
#check if it's dropped
df.columns
# Out:
# Index(['adult', 'belongs_to_collection', 'budget', 'genres', 'id', 'imdb_id',
#        'original_language', 'original_title', 'overview', 'popularity',
#        'poster_path', 'production_companies', 'production_countries',
#        'release_date', 'revenue', 'runtime', 'spoken_languages', 'status',
#        'tagline', 'title', 'video', 'vote_average', 'vote_count'],
#       dtype='object')

# %%
# it's gone so let's check another columns
df.isna().sum()
# Out:
# adult                        0
# belongs_to_collection    40959
# budget                       0
# genres                       0
# id                           0
# imdb_id                     17
# original_language           11
# original_title               0
# overview                   954
# popularity                   5
# poster_path                386
# production_companies         3
# production_countries         3
# release_date                87
# revenue                      6
# runtime                    263
# spoken_languages             6
# status                      87
# tagline                  25045
# title                        6
# video                        6
# vote_average                 6
# vote_count                   6
# dtype: int64

# %%
#the next column that we'll inspect will be belong_to_collection one
#check whether how much is it to the whole count of dataset
len(df.loc[df['belongs_to_collection'].isnull()]) * 100 / df.shape[0]
# Out:
# 90.11286383737047

# %%
#it's almost 100% holy s***
#so I wonder how about another null columns?
(df.isna().sum() * 100 / df.shape[0]).round(2)
# Out:
# adult                     0.00
# belongs_to_collection    90.11
# budget                    0.00
# genres                    0.00
# id                        0.00
# imdb_id                   0.04
# original_language         0.02
# original_title            0.00
# overview                  2.10
# popularity                0.01
# poster_path               0.85
# production_companies      0.01
# production_countries      0.01
# release_date              0.19
# revenue                   0.01
# runtime                   0.58
# spoken_languages          0.01
# status                    0.19
# tagline                  55.10
# title                     0.01
# video                     0.01
# vote_average              0.01
# vote_count                0.01
# dtype: float64

# %%
#there are two columns that're above 50%
#dropping
df.drop('belongs_to_collection', axis='columns', inplace=True)

# %%
df.drop('tagline', axis='columns', inplace=True)

# %%
#check
df.columns
# Out:
# Index(['adult', 'budget', 'genres', 'id', 'imdb_id', 'original_language',
#        'original_title', 'overview', 'popularity', 'poster_path',
#        'production_companies', 'production_countries', 'release_date',
#        'revenue', 'runtime', 'spoken_languages', 'status', 'title', 'video',
#        'vote_average', 'vote_count'],
#       dtype='object')

# %%
#let's move to the next one
#overview
df.loc[df['overview'].isnull()]
# Out:
#        adult    budget                                             genres  \
# 32     False         0  [{'id': 10749, 'name': 'Romance'}, {'id': 12, ...
# 300    False  22000000  [{'id': 18, 'name': 'Drama'}, {'id': 35, 'name...
# 634    False         0                     [{'id': 35, 'name': 'Comedy'}]
# 635    False         0                     [{'id': 35, 'name': 'Comedy'}]
# 641    False         0                     [{'id': 35, 'name': 'Comedy'}]
# ...      ...       ...                                                ...
# 45342  False         0                      [{'id': 18, 'name': 'Drama'}]
# 45377  False         0                  [{'id': 12, 'name': 'Adventure'}]
# 45398  False   1254040  [{'id': 10749, 'name': 'Romance'}, {'id': 35, ...
# 45399  False    750000  [{'id': 80, 'name': 'Crime'}, {'id': 35, 'name...
# 45410  False         0  [{'id': 18, 'name': 'Drama'}, {'id': 80, 'name...
#
#            id    imdb_id original_language                    original_title  \
# 32      78802  tt0114952                fr  Guillaumet, les ailes du courage
# 300    161495  tt0114296                sv                         Roommates
# 634    287305  tt0117312                de    Peanuts – Die Bank zahlt alles
# 635    339428  tt0116485                de                     Happy Weekend
# 641     10801  tt0117788                de                     Das Superweib
# ...       ...        ...               ...                               ...
# 45342  199887  tt1771636                en                        Over/Under
# 45377  317389  tt0070695                es     Simbad e il califfo di Bagdad
# 45398  468707  tt5742932                fi  Lauri Mäntyvaaran tuuheet ripset
# 45399  280422  tt3805180                ru                       Все и сразу
# 45410  449131  tt0321264                ru                             Aprel
#
#       overview popularity                       poster_path  ...  \
# 32         NaN   0.745542  /k6ODtR38dKEfuzSGjggr8KDyAF4.jpg  ...
# 300        NaN   3.395867  /hvHNlMvWS2GBt7RR971bJ3k4bJc.jpg  ...
# 634        NaN   0.066123  /wpk30SvRHmjC2plgKHZXxG0FlKd.jpg  ...
# 635        NaN   0.002229                               NaN  ...
# 641        NaN   0.821299  /AbhMKCh3fV5PY2B9uSPF1DWEvq2.jpg  ...
# ...        ...        ...                               ...  ...
# 45342      NaN   0.704642  /1xLaIBGGPE4APtBJdfeuyOWICZ0.jpg  ...
# 45377      NaN   0.006352  /izk7KbT6LZO9baEhCkOZYMgj60w.jpg  ...
# 45398      NaN   0.347806  /rKOpJuwb7pTqYVShHM2tl25VxyF.jpg  ...
# 45399      NaN   0.201582  /hNsmPpl3zLG36jr4EIEd5P8I4pa.jpg  ...
# 45410      NaN   0.008903                               NaN  ...
#
#                                     production_countries release_date  \
# 32     [{'iso_3166_1': 'FR', 'name': 'France'}, {'iso...   1996-09-18
# 300    [{'iso_3166_1': 'US', 'name': 'United States o...   1995-03-01
# 634            [{'iso_3166_1': 'DE', 'name': 'Germany'}]   1996-03-21
# 635            [{'iso_3166_1': 'DE', 'name': 'Germany'}]   1996-03-14
# 641            [{'iso_3166_1': 'DE', 'name': 'Germany'}]   1996-03-06
# ...                                                  ...          ...
# 45342  [{'iso_3166_1': 'US', 'name': 'United States o...   2013-01-04
# 45377            [{'iso_3166_1': 'IT', 'name': 'Italy'}]   1973-07-22
# 45398          [{'iso_3166_1': 'FI', 'name': 'Finland'}]   2017-07-28
# 45399           [{'iso_3166_1': 'RU', 'name': 'Russia'}]   2014-06-05
# 45410           [{'iso_3166_1': 'RU', 'name': 'Russia'}]          NaN
#
#           revenue  runtime                           spoken_languages  \
# 32            0.0     50.0   [{'iso_639_1': 'en', 'name': 'English'}]
# 300    12400000.0    108.0   [{'iso_639_1': 'en', 'name': 'English'}]
# 634           0.0      NaN                                         []
# 635       65335.0      NaN   [{'iso_639_1': 'de', 'name': 'Deutsch'}]
# 641           0.0     86.0   [{'iso_639_1': 'de', 'name': 'Deutsch'}]
# ...           ...      ...                                        ...
# 45342         0.0     87.0   [{'iso_639_1': 'en', 'name': 'English'}]
# 45377         0.0      NaN  [{'iso_639_1': 'it', 'name': 'Italiano'}]
# 45398         0.0     90.0     [{'iso_639_1': 'fi', 'name': 'suomi'}]
# 45399         3.0      0.0   [{'iso_639_1': 'ru', 'name': 'Pусский'}]
# 45410         0.0      NaN                                         []
#
#          status                             title  video vote_average  \
# 32     Released                  Wings of Courage  False          6.8
# 300    Released                         Roommates  False          6.4
# 634    Released    Peanuts – Die Bank zahlt alles  False          4.0
# 635    Released                     Happy Weekend  False          0.0
# 641    Released                     The Superwife  False          5.3
# ...         ...                               ...    ...          ...
# 45342  Released                        Over/Under  False          4.0
# 45377  Released     Simbad e il califfo di Bagdad  False          0.0
# 45398  Released  Thick Lashes of Lauri Mäntyvaara  False          8.0
# 45399  Released                       All at Once  False          6.0
# 45410  Released                             Aprel  False          6.0
#
#        vote_count
# 32            4.0
# 300           7.0
# 634           1.0
# 635           0.0
# 641           7.0
# ...           ...
# 45342         2.0
# 45377         0.0
# 45398         1.0
# 45399         4.0
# 45410         1.0
#
# [954 rows x 21 columns]

# %%
#it's neccesary to have overview, it represents as a short version of the movie
#so I decided to drop the NaN rows
df.dropna(axis='rows', inplace=True)

# %%
df.isna().sum()
# Out:
# adult                   0
# budget                  0
# genres                  0
# id                      0
# imdb_id                 0
# original_language       0
# original_title          0
# overview                0
# popularity              0
# poster_path             0
# production_companies    0
# production_countries    0
# release_date            0
# revenue                 0
# runtime                 0
# spoken_languages        0
# status                  0
# title                   0
# video                   0
# vote_average            0
# vote_count              0
# dtype: int64

# %%
df.head()
# Out:
#    adult    budget                                             genres     id  \
# 0  False  30000000  [{'id': 16, 'name': 'Animation'}, {'id': 35, '...    862
# 1  False  65000000  [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...   8844
# 2  False         0  [{'id': 10749, 'name': 'Romance'}, {'id': 35, ...  15602
# 3  False  16000000  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...  31357
# 4  False         0                     [{'id': 35, 'name': 'Comedy'}]  11862
#
#      imdb_id original_language               original_title  \
# 0  tt0114709                en                    Toy Story
# 1  tt0113497                en                      Jumanji
# 2  tt0113228                en             Grumpier Old Men
# 3  tt0114885                en            Waiting to Exhale
# 4  tt0113041                en  Father of the Bride Part II
#
#                                             overview popularity  \
# 0  Led by Woody, Andy's toys live happily in his ...  21.946943
# 1  When siblings Judy and Peter discover an encha...  17.015539
# 2  A family wedding reignites the ancient feud be...    11.7129
# 3  Cheated on, mistreated and stepped on, the wom...   3.859495
# 4  Just when George Banks has recovered from his ...   8.387519
#
#                         poster_path  ...  \
# 0  /rhIRbceoE9lR4veEXuwCC2wARtG.jpg  ...
# 1  /vzmL6fP7aPKNKPRTFnZmiUfciyV.jpg  ...
# 2  /6ksm1sjKMFLbO7UY2i6G1ju9SML.jpg  ...
# 3  /16XOMpEaLWkrcPqSQqhTmeJuqQl.jpg  ...
# 4  /e64sOI48hQXyru7naBFyssKFxVd.jpg  ...
#
#                                 production_countries release_date  \
# 0  [{'iso_3166_1': 'US', 'name': 'United States o...   1995-10-30
# 1  [{'iso_3166_1': 'US', 'name': 'United States o...   1995-12-15
# 2  [{'iso_3166_1': 'US', 'name': 'United States o...   1995-12-22
# 3  [{'iso_3166_1': 'US', 'name': 'United States o...   1995-12-22
# 4  [{'iso_3166_1': 'US', 'name': 'United States o...   1995-02-10
#
#        revenue  runtime                                   spoken_languages  \
# 0  373554033.0     81.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 1  262797249.0    104.0  [{'iso_639_1': 'en', 'name': 'English'}, {'iso...
# 2          0.0    101.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 3   81452156.0    127.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 4   76578911.0    106.0           [{'iso_639_1': 'en', 'name': 'English'}]
#
#      status                        title  video vote_average  vote_count
# 0  Released                    Toy Story  False          7.7      5415.0
# 1  Released                      Jumanji  False          6.9      2413.0
# 2  Released             Grumpier Old Men  False          6.5        92.0
# 3  Released            Waiting to Exhale  False          6.1        34.0
# 4  Released  Father of the Bride Part II  False          5.7       173.0
#
# [5 rows x 21 columns]

# %%
#rename genres of each movies
regex = re.compile(r": '(.*?)'")
df['genres'] = df['genres'].apply(lambda x: ", ".join(regex.findall(x)))
df
# Out:
#        adult    budget                      genres      id    imdb_id  \
# 0      False  30000000   Animation, Comedy, Family     862  tt0114709
# 1      False  65000000  Adventure, Fantasy, Family    8844  tt0113497
# 2      False         0             Romance, Comedy   15602  tt0113228
# 3      False  16000000      Comedy, Drama, Romance   31357  tt0114885
# 4      False         0                      Comedy   11862  tt0113041
# ...      ...       ...                         ...     ...        ...
# 45460  False         0      Drama, Action, Romance   30840  tt0102797
# 45462  False         0                       Drama  111109  tt2028550
# 45463  False         0     Action, Drama, Thriller   67758  tt0303758
# 45464  False         0                              227506  tt0008536
# 45465  False         0                              461257  tt6980792
#
#       original_language               original_title  \
# 0                    en                    Toy Story
# 1                    en                      Jumanji
# 2                    en             Grumpier Old Men
# 3                    en            Waiting to Exhale
# 4                    en  Father of the Bride Part II
# ...                 ...                          ...
# 45460                en                   Robin Hood
# 45462                tl          Siglo ng Pagluluwal
# 45463                en                     Betrayal
# 45464                en          Satana likuyushchiy
# 45465                en                     Queerama
#
#                                                 overview popularity  \
# 0      Led by Woody, Andy's toys live happily in his ...  21.946943
# 1      When siblings Judy and Peter discover an encha...  17.015539
# 2      A family wedding reignites the ancient feud be...    11.7129
# 3      Cheated on, mistreated and stepped on, the wom...   3.859495
# 4      Just when George Banks has recovered from his ...   8.387519
# ...                                                  ...        ...
# 45460  Yet another version of the classic epic, with ...   5.683753
# 45462  An artist struggles to finish his work while a...   0.178241
# 45463  When one of her hits goes wrong, a professiona...   0.903007
# 45464  In a small town live two brothers, one a minis...   0.003503
# 45465  50 years after decriminalisation of homosexual...   0.163015
#
#                             poster_path  ...  \
# 0      /rhIRbceoE9lR4veEXuwCC2wARtG.jpg  ...
# 1      /vzmL6fP7aPKNKPRTFnZmiUfciyV.jpg  ...
# 2      /6ksm1sjKMFLbO7UY2i6G1ju9SML.jpg  ...
# 3      /16XOMpEaLWkrcPqSQqhTmeJuqQl.jpg  ...
# 4      /e64sOI48hQXyru7naBFyssKFxVd.jpg  ...
# ...                                 ...  ...
# 45460  /fQC46NglNiEMZBv5XHoyLuOWoN5.jpg  ...
# 45462  /xZkmxsNmYXJbKVsTRLLx3pqGHx7.jpg  ...
# 45463  /d5bX92nDsISNhu3ZT69uHwmfCGw.jpg  ...
# 45464  /aorBPO7ak8e8iJKT5OcqYxU3jlK.jpg  ...
# 45465  /s5UkZt6NTsrS7ZF0Rh8nzupRlIU.jpg  ...
#
#                                     production_countries release_date  \
# 0      [{'iso_3166_1': 'US', 'name': 'United States o...   1995-10-30
# 1      [{'iso_3166_1': 'US', 'name': 'United States o...   1995-12-15
# 2      [{'iso_3166_1': 'US', 'name': 'United States o...   1995-12-22
# 3      [{'iso_3166_1': 'US', 'name': 'United States o...   1995-12-22
# 4      [{'iso_3166_1': 'US', 'name': 'United States o...   1995-02-10
# ...                                                  ...          ...
# 45460  [{'iso_3166_1': 'CA', 'name': 'Canada'}, {'iso...   1991-05-13
# 45462      [{'iso_3166_1': 'PH', 'name': 'Philippines'}]   2011-11-17
# 45463  [{'iso_3166_1': 'US', 'name': 'United States o...   2003-08-01
# 45464           [{'iso_3166_1': 'RU', 'name': 'Russia'}]   1917-10-21
# 45465   [{'iso_3166_1': 'GB', 'name': 'United Kingdom'}]   2017-06-09
#
#            revenue  runtime  \
# 0      373554033.0     81.0
# 1      262797249.0    104.0
# 2              0.0    101.0
# 3       81452156.0    127.0
# 4       76578911.0    106.0
# ...            ...      ...
# 45460          0.0    104.0
# 45462          0.0    360.0
# 45463          0.0     90.0
# 45464          0.0     87.0
# 45465          0.0     75.0
#
#                                         spoken_languages    status  \
# 0               [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 1      [{'iso_639_1': 'en', 'name': 'English'}, {'iso...  Released
# 2               [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 3               [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 4               [{'iso_639_1': 'en', 'name': 'English'}]  Released
# ...                                                  ...       ...
# 45460           [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 45462                  [{'iso_639_1': 'tl', 'name': ''}]  Released
# 45463           [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 45464                                                 []  Released
# 45465           [{'iso_639_1': 'en', 'name': 'English'}]  Released
#
#                              title  video vote_average  vote_count
# 0                        Toy Story  False          7.7      5415.0
# 1                          Jumanji  False          6.9      2413.0
# 2                 Grumpier Old Men  False          6.5        92.0
# 3                Waiting to Exhale  False          6.1        34.0
# 4      Father of the Bride Part II  False          5.7       173.0
# ...                            ...    ...          ...         ...
# 45460                   Robin Hood  False          5.7        26.0
# 45462          Century of Birthing  False          9.0         3.0
# 45463                     Betrayal  False          3.8         6.0
# 45464             Satan Triumphant  False          0.0         0.0
# 45465                     Queerama  False          0.0         0.0
#
# [44035 rows x 21 columns]

# %%
#reset index
df.reset_index(drop=True)
# Out:
#        adult    budget                      genres      id    imdb_id  \
# 0      False  30000000   Animation, Comedy, Family     862  tt0114709
# 1      False  65000000  Adventure, Fantasy, Family    8844  tt0113497
# 2      False         0             Romance, Comedy   15602  tt0113228
# 3      False  16000000      Comedy, Drama, Romance   31357  tt0114885
# 4      False         0                      Comedy   11862  tt0113041
# ...      ...       ...                         ...     ...        ...
# 44030  False         0      Drama, Action, Romance   30840  tt0102797
# 44031  False         0                       Drama  111109  tt2028550
# 44032  False         0     Action, Drama, Thriller   67758  tt0303758
# 44033  False         0                              227506  tt0008536
# 44034  False         0                              461257  tt6980792
#
#       original_language               original_title  \
# 0                    en                    Toy Story
# 1                    en                      Jumanji
# 2                    en             Grumpier Old Men
# 3                    en            Waiting to Exhale
# 4                    en  Father of the Bride Part II
# ...                 ...                          ...
# 44030                en                   Robin Hood
# 44031                tl          Siglo ng Pagluluwal
# 44032                en                     Betrayal
# 44033                en          Satana likuyushchiy
# 44034                en                     Queerama
#
#                                                 overview popularity  \
# 0      Led by Woody, Andy's toys live happily in his ...  21.946943
# 1      When siblings Judy and Peter discover an encha...  17.015539
# 2      A family wedding reignites the ancient feud be...    11.7129
# 3      Cheated on, mistreated and stepped on, the wom...   3.859495
# 4      Just when George Banks has recovered from his ...   8.387519
# ...                                                  ...        ...
# 44030  Yet another version of the classic epic, with ...   5.683753
# 44031  An artist struggles to finish his work while a...   0.178241
# 44032  When one of her hits goes wrong, a professiona...   0.903007
# 44033  In a small town live two brothers, one a minis...   0.003503
# 44034  50 years after decriminalisation of homosexual...   0.163015
#
#                             poster_path  ...  \
# 0      /rhIRbceoE9lR4veEXuwCC2wARtG.jpg  ...
# 1      /vzmL6fP7aPKNKPRTFnZmiUfciyV.jpg  ...
# 2      /6ksm1sjKMFLbO7UY2i6G1ju9SML.jpg  ...
# 3      /16XOMpEaLWkrcPqSQqhTmeJuqQl.jpg  ...
# 4      /e64sOI48hQXyru7naBFyssKFxVd.jpg  ...
# ...                                 ...  ...
# 44030  /fQC46NglNiEMZBv5XHoyLuOWoN5.jpg  ...
# 44031  /xZkmxsNmYXJbKVsTRLLx3pqGHx7.jpg  ...
# 44032  /d5bX92nDsISNhu3ZT69uHwmfCGw.jpg  ...
# 44033  /aorBPO7ak8e8iJKT5OcqYxU3jlK.jpg  ...
# 44034  /s5UkZt6NTsrS7ZF0Rh8nzupRlIU.jpg  ...
#
#                                     production_countries release_date  \
# 0      [{'iso_3166_1': 'US', 'name': 'United States o...   1995-10-30
# 1      [{'iso_3166_1': 'US', 'name': 'United States o...   1995-12-15
# 2      [{'iso_3166_1': 'US', 'name': 'United States o...   1995-12-22
# 3      [{'iso_3166_1': 'US', 'name': 'United States o...   1995-12-22
# 4      [{'iso_3166_1': 'US', 'name': 'United States o...   1995-02-10
# ...                                                  ...          ...
# 44030  [{'iso_3166_1': 'CA', 'name': 'Canada'}, {'iso...   1991-05-13
# 44031      [{'iso_3166_1': 'PH', 'name': 'Philippines'}]   2011-11-17
# 44032  [{'iso_3166_1': 'US', 'name': 'United States o...   2003-08-01
# 44033           [{'iso_3166_1': 'RU', 'name': 'Russia'}]   1917-10-21
# 44034   [{'iso_3166_1': 'GB', 'name': 'United Kingdom'}]   2017-06-09
#
#            revenue  runtime  \
# 0      373554033.0     81.0
# 1      262797249.0    104.0
# 2              0.0    101.0
# 3       81452156.0    127.0
# 4       76578911.0    106.0
# ...            ...      ...
# 44030          0.0    104.0
# 44031          0.0    360.0
# 44032          0.0     90.0
# 44033          0.0     87.0
# 44034          0.0     75.0
#
#                                         spoken_languages    status  \
# 0               [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 1      [{'iso_639_1': 'en', 'name': 'English'}, {'iso...  Released
# 2               [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 3               [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 4               [{'iso_639_1': 'en', 'name': 'English'}]  Released
# ...                                                  ...       ...
# 44030           [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 44031                  [{'iso_639_1': 'tl', 'name': ''}]  Released
# 44032           [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 44033                                                 []  Released
# 44034           [{'iso_639_1': 'en', 'name': 'English'}]  Released
#
#                              title  video vote_average  vote_count
# 0                        Toy Story  False          7.7      5415.0
# 1                          Jumanji  False          6.9      2413.0
# 2                 Grumpier Old Men  False          6.5        92.0
# 3                Waiting to Exhale  False          6.1        34.0
# 4      Father of the Bride Part II  False          5.7       173.0
# ...                            ...    ...          ...         ...
# 44030                   Robin Hood  False          5.7        26.0
# 44031          Century of Birthing  False          9.0         3.0
# 44032                     Betrayal  False          3.8         6.0
# 44033             Satan Triumphant  False          0.0         0.0
# 44034                     Queerama  False          0.0         0.0
#
# [44035 rows x 21 columns]

# %%
#rename production names and production countries
df['production_companies'] = df['production_companies'].apply(lambda x: ', '.join(regex.findall(x)))
df['production_countries'] = df['production_countries'].apply(lambda x: ', '.join(regex.findall(x)))

# %%
#rename spoken langs
df['spoken_languages'] = df['spoken_languages'].apply(lambda x: ', '.join(regex.findall(x)))

# %%
#check
df
# Out:
#        adult    budget                      genres      id    imdb_id  \
# 0      False  30000000   Animation, Comedy, Family     862  tt0114709
# 1      False  65000000  Adventure, Fantasy, Family    8844  tt0113497
# 2      False         0             Romance, Comedy   15602  tt0113228
# 3      False  16000000      Comedy, Drama, Romance   31357  tt0114885
# 4      False         0                      Comedy   11862  tt0113041
# ...      ...       ...                         ...     ...        ...
# 45460  False         0      Drama, Action, Romance   30840  tt0102797
# 45462  False         0                       Drama  111109  tt2028550
# 45463  False         0     Action, Drama, Thriller   67758  tt0303758
# 45464  False         0                              227506  tt0008536
# 45465  False         0                              461257  tt6980792
#
#       original_language               original_title  \
# 0                    en                    Toy Story
# 1                    en                      Jumanji
# 2                    en             Grumpier Old Men
# 3                    en            Waiting to Exhale
# 4                    en  Father of the Bride Part II
# ...                 ...                          ...
# 45460                en                   Robin Hood
# 45462                tl          Siglo ng Pagluluwal
# 45463                en                     Betrayal
# 45464                en          Satana likuyushchiy
# 45465                en                     Queerama
#
#                                                 overview popularity  \
# 0      Led by Woody, Andy's toys live happily in his ...  21.946943
# 1      When siblings Judy and Peter discover an encha...  17.015539
# 2      A family wedding reignites the ancient feud be...    11.7129
# 3      Cheated on, mistreated and stepped on, the wom...   3.859495
# 4      Just when George Banks has recovered from his ...   8.387519
# ...                                                  ...        ...
# 45460  Yet another version of the classic epic, with ...   5.683753
# 45462  An artist struggles to finish his work while a...   0.178241
# 45463  When one of her hits goes wrong, a professiona...   0.903007
# 45464  In a small town live two brothers, one a minis...   0.003503
# 45465  50 years after decriminalisation of homosexual...   0.163015
#
#                             poster_path  ...  \
# 0      /rhIRbceoE9lR4veEXuwCC2wARtG.jpg  ...
# 1      /vzmL6fP7aPKNKPRTFnZmiUfciyV.jpg  ...
# 2      /6ksm1sjKMFLbO7UY2i6G1ju9SML.jpg  ...
# 3      /16XOMpEaLWkrcPqSQqhTmeJuqQl.jpg  ...
# 4      /e64sOI48hQXyru7naBFyssKFxVd.jpg  ...
# ...                                 ...  ...
# 45460  /fQC46NglNiEMZBv5XHoyLuOWoN5.jpg  ...
# 45462  /xZkmxsNmYXJbKVsTRLLx3pqGHx7.jpg  ...
# 45463  /d5bX92nDsISNhu3ZT69uHwmfCGw.jpg  ...
# 45464  /aorBPO7ak8e8iJKT5OcqYxU3jlK.jpg  ...
# 45465  /s5UkZt6NTsrS7ZF0Rh8nzupRlIU.jpg  ...
#
#                                     production_countries release_date  \
# 0                           US, United States of America   1995-10-30
# 1                           US, United States of America   1995-12-15
# 2                           US, United States of America   1995-12-22
# 3                           US, United States of America   1995-12-22
# 4                           US, United States of America   1995-02-10
# ...                                                  ...          ...
# 45460  CA, Canada, DE, Germany, GB, United Kingdom, U...   1991-05-13
# 45462                                    PH, Philippines   2011-11-17
# 45463                       US, United States of America   2003-08-01
# 45464                                         RU, Russia   1917-10-21
# 45465                                 GB, United Kingdom   2017-06-09
#
#            revenue  runtime           spoken_languages    status  \
# 0      373554033.0     81.0                en, English  Released
# 1      262797249.0    104.0  en, English, fr, Français  Released
# 2              0.0    101.0                en, English  Released
# 3       81452156.0    127.0                en, English  Released
# 4       76578911.0    106.0                en, English  Released
# ...            ...      ...                        ...       ...
# 45460          0.0    104.0                en, English  Released
# 45462          0.0    360.0                       tl,   Released
# 45463          0.0     90.0                en, English  Released
# 45464          0.0     87.0                             Released
# 45465          0.0     75.0                en, English  Released
#
#                              title  video vote_average  vote_count
# 0                        Toy Story  False          7.7      5415.0
# 1                          Jumanji  False          6.9      2413.0
# 2                 Grumpier Old Men  False          6.5        92.0
# 3                Waiting to Exhale  False          6.1        34.0
# 4      Father of the Bride Part II  False          5.7       173.0
# ...                            ...    ...          ...         ...
# 45460                   Robin Hood  False          5.7        26.0
# 45462          Century of Birthing  False          9.0         3.0
# 45463                     Betrayal  False          3.8         6.0
# 45464             Satan Triumphant  False          0.0         0.0
# 45465                     Queerama  False          0.0         0.0
#
# [44035 rows x 21 columns]

# %%
df.loc[df['genres'] == 'Science Fiction']
# Out:
#        adult    budget           genres      id    imdb_id original_language  \
# 170    False  90000000  Science Fiction    9482  tt0113492                en
# 663    False   9000000  Science Fiction    8069  tt0062711                en
# 1638   False         0  Science Fiction  438108  tt0128755                en
# 1684   False  75000000  Science Fiction   10153  tt0120184                en
# 2583   False         0  Science Fiction   67067  tt0120554                en
# ...      ...       ...              ...     ...        ...               ...
# 45069  False         0  Science Fiction  401427  tt5769236                en
# 45075  False         0  Science Fiction  314238  tt1899268                en
# 45183  False         0  Science Fiction  429101  tt4881364                en
# 45367  False         0  Science Fiction  449696  tt0105492                en
# 45459  False         0  Science Fiction  222848  tt0112613                en
#
#                           original_title  \
# 170                          Judge Dredd
# 663                           Barbarella
# 1638                        Time Tracers
# 1684                              Sphere
# 2583                             Zone 39
# ...                                  ...
# 45069                              Elegy
# 45075                               Plug
# 45183                        Anti Matter
# 45367  The Stranger: Summoned by Shadows
# 45459                    Caged Heat 3000
#
#                                                 overview popularity  \
# 170    In a dystopian future, Dredd, the most famous ...   8.184815
# 663    In the far future, a highly sexual woman is ta...  14.304205
# 1638   When the discovery of a five-thousand year old...   0.001247
# 1684   The OSSA discovers a spacecraft thought to be ...   7.124735
# 2583   In a time of misery and fear two enemies come ...   0.087065
# ...                                                  ...        ...
# 45069  In the future, nature has evolved to destroy h...   0.016472
# 45075  On a post-apocalyptic Earth, Leila Dawn (Natal...   0.495194
# 45183  Anti Matter (AKA Worm) is a sci-fi noir take o...    4.57264
# 45367  Wearied by his travels through time and space ...    3.5e-05
# 45459  It's the year 3000 AD. The world's most danger...   0.661558
#
#                             poster_path  ...          production_countries  \
# 170    /r17S4XlQ3Jq5U1KRovFUwU8P4aG.jpg  ...  US, United States of America
# 663    /fntrx2BzHkdSNFe5jkgP09XsK7g.jpg  ...  US, United States of America
# 1638   /tU52aw3QwOV2a7zD4T659iAKGwr.jpg  ...  US, United States of America
# 1684   /jrjzPjKnpJq99GPePKf64k7Fzqh.jpg  ...  US, United States of America
# 2583   /5VMuNPqKhc0gEH0HyVxgjUXAgs9.jpg  ...                 AU, Australia
# ...                                 ...  ...                           ...
# 45069  /wcq1a3heYgd8TOuctso0c3Pk4wx.jpg  ...
# 45075  /3Sa0PaFHLQWe3q60sNOXCb4RkbB.jpg  ...  US, United States of America
# 45183  /fQq24L8ioUy3cHWPo8LheguicxF.jpg  ...            GB, United Kingdom
# 45367  /aWnsJwOZB1ARhavpnh0O5ae8qWn.jpg  ...            GB, United Kingdom
# 45459  /4lF9LH0b0Z1X94xGK9IOzqEW6k1.jpg  ...  US, United States of America
#
#       release_date      revenue  runtime  spoken_languages    status  \
# 170     1995-06-30  113493481.0     96.0       en, English  Released
# 663     1968-10-10    2500000.0     98.0       en, English  Released
# 1638    1997-12-16          0.0    101.0       en, English  Released
# 1684    1998-02-13   13100000.0    134.0       en, English  Released
# 2583    1996-05-04          0.0     95.0       en, English  Released
# ...            ...          ...      ...               ...       ...
# 45069   2014-09-10          0.0     16.0                    Released
# 45075   2014-10-25          0.0     16.0       en, English  Released
# 45183   2016-01-01          0.0    109.0                    Released
# 45367   1991-01-01          0.0     34.0       en, English  Released
# 45459   1995-01-01          0.0     85.0       en, English  Released
#
#                                    title  video vote_average  vote_count
# 170                          Judge Dredd  False          5.4       643.0
# 663                           Barbarella  False          5.7       149.0
# 1638                        Time Tracers  False          0.0         0.0
# 1684                              Sphere  False          5.8       483.0
# 2583                             Zone 39  False          5.0         2.0
# ...                                  ...    ...          ...         ...
# 45069                              Elegy  False          0.0         0.0
# 45075                               Plug  False          5.6         5.0
# 45183                        Anti Matter  False          6.7        22.0
# 45367  The Stranger: Summoned by Shadows  False          0.0         0.0
# 45459                    Caged Heat 3000  False          3.5         1.0
#
# [193 rows x 21 columns]

# %%
df.loc[df['genres'] == 'SciFi']
# Out:
# Empty DataFrame
# Columns: [adult, budget, genres, id, imdb_id, original_language, original_title, overview, popularity, poster_path, production_companies, production_countries, release_date, revenue, runtime, spoken_languages, status, title, video, vote_average, vote_count]
# Index: []
#
# [0 rows x 21 columns]

# %%
#check whether renamed columns are null or not
df.isna().sum()
# Out:
# adult                   0
# budget                  0
# genres                  0
# id                      0
# imdb_id                 0
# original_language       0
# original_title          0
# overview                0
# popularity              0
# poster_path             0
# production_companies    0
# production_countries    0
# release_date            0
# revenue                 0
# runtime                 0
# spoken_languages        0
# status                  0
# title                   0
# video                   0
# vote_average            0
# vote_count              0
# dtype: int64

# %%
#Dropping rows that don't contain type
df.drop(df.loc[df['genres'] == ""].index, inplace=True)

# %%
df
# Out:
#        adult    budget                      genres      id    imdb_id  \
# 0      False  30000000   Animation, Comedy, Family     862  tt0114709
# 1      False  65000000  Adventure, Fantasy, Family    8844  tt0113497
# 2      False         0             Romance, Comedy   15602  tt0113228
# 3      False  16000000      Comedy, Drama, Romance   31357  tt0114885
# 4      False         0                      Comedy   11862  tt0113041
# ...      ...       ...                         ...     ...        ...
# 45458  False         0                      Horror  289923  tt0252966
# 45459  False         0             Science Fiction  222848  tt0112613
# 45460  False         0      Drama, Action, Romance   30840  tt0102797
# 45462  False         0                       Drama  111109  tt2028550
# 45463  False         0     Action, Drama, Thriller   67758  tt0303758
#
#       original_language               original_title  \
# 0                    en                    Toy Story
# 1                    en                      Jumanji
# 2                    en             Grumpier Old Men
# 3                    en            Waiting to Exhale
# 4                    en  Father of the Bride Part II
# ...                 ...                          ...
# 45458                en          The Burkittsville 7
# 45459                en              Caged Heat 3000
# 45460                en                   Robin Hood
# 45462                tl          Siglo ng Pagluluwal
# 45463                en                     Betrayal
#
#                                                 overview popularity  \
# 0      Led by Woody, Andy's toys live happily in his ...  21.946943
# 1      When siblings Judy and Peter discover an encha...  17.015539
# 2      A family wedding reignites the ancient feud be...    11.7129
# 3      Cheated on, mistreated and stepped on, the wom...   3.859495
# 4      Just when George Banks has recovered from his ...   8.387519
# ...                                                  ...        ...
# 45458  A film archivist revisits the story of Rustin ...    0.38645
# 45459  It's the year 3000 AD. The world's most danger...   0.661558
# 45460  Yet another version of the classic epic, with ...   5.683753
# 45462  An artist struggles to finish his work while a...   0.178241
# 45463  When one of her hits goes wrong, a professiona...   0.903007
#
#                             poster_path  ...  \
# 0      /rhIRbceoE9lR4veEXuwCC2wARtG.jpg  ...
# 1      /vzmL6fP7aPKNKPRTFnZmiUfciyV.jpg  ...
# 2      /6ksm1sjKMFLbO7UY2i6G1ju9SML.jpg  ...
# 3      /16XOMpEaLWkrcPqSQqhTmeJuqQl.jpg  ...
# 4      /e64sOI48hQXyru7naBFyssKFxVd.jpg  ...
# ...                                 ...  ...
# 45458  /lXtoHVdej6kS1Dc7KAhw05sMos9.jpg  ...
# 45459  /4lF9LH0b0Z1X94xGK9IOzqEW6k1.jpg  ...
# 45460  /fQC46NglNiEMZBv5XHoyLuOWoN5.jpg  ...
# 45462  /xZkmxsNmYXJbKVsTRLLx3pqGHx7.jpg  ...
# 45463  /d5bX92nDsISNhu3ZT69uHwmfCGw.jpg  ...
#
#                                     production_countries release_date  \
# 0                           US, United States of America   1995-10-30
# 1                           US, United States of America   1995-12-15
# 2                           US, United States of America   1995-12-22
# 3                           US, United States of America   1995-12-22
# 4                           US, United States of America   1995-02-10
# ...                                                  ...          ...
# 45458                       US, United States of America   2000-10-03
# 45459                       US, United States of America   1995-01-01
# 45460  CA, Canada, DE, Germany, GB, United Kingdom, U...   1991-05-13
# 45462                                    PH, Philippines   2011-11-17
# 45463                       US, United States of America   2003-08-01
#
#            revenue  runtime           spoken_languages    status  \
# 0      373554033.0     81.0                en, English  Released
# 1      262797249.0    104.0  en, English, fr, Français  Released
# 2              0.0    101.0                en, English  Released
# 3       81452156.0    127.0                en, English  Released
# 4       76578911.0    106.0                en, English  Released
# ...            ...      ...                        ...       ...
# 45458          0.0     30.0                en, English  Released
# 45459          0.0     85.0                en, English  Released
# 45460          0.0    104.0                en, English  Released
# 45462          0.0    360.0                       tl,   Released
# 45463          0.0     90.0                en, English  Released
#
#                              title  video vote_average  vote_count
# 0                        Toy Story  False          7.7      5415.0
# 1                          Jumanji  False          6.9      2413.0
# 2                 Grumpier Old Men  False          6.5        92.0
# 3                Waiting to Exhale  False          6.1        34.0
# 4      Father of the Bride Part II  False          5.7       173.0
# ...                            ...    ...          ...         ...
# 45458          The Burkittsville 7  False          7.0         1.0
# 45459              Caged Heat 3000  False          3.5         1.0
# 45460                   Robin Hood  False          5.7        26.0
# 45462          Century of Birthing  False          9.0         3.0
# 45463                     Betrayal  False          3.8         6.0
#
# [42069 rows x 21 columns]

# %%
# #Change movies that have multiple genres into only one genre
# df.loc[df['genres'].str.len() > 12, 'genres'] = "MultipleType"

# %%
df.columns
# Out:
# Index(['adult', 'budget', 'genres', 'id', 'imdb_id', 'original_language',
#        'original_title', 'overview', 'popularity', 'poster_path',
#        'production_companies', 'production_countries', 'release_date',
#        'revenue', 'runtime', 'spoken_languages', 'status', 'title', 'video',
#        'vote_average', 'vote_count'],
#       dtype='object')

# %%
df['title'] = df['title'].drop_duplicates()

# %% [markdown]
# # EDA

# %%
###Visualization
import matplotlib.pyplot as plt

# def similarMovies(movieName):
#     movie_sim = df.loc[df['title'] == movieName]
#     tmp = movie_sim['genres'].values
#     a = tmp[0].split(',')
#     return a

#selecting jumanji movie to compare which movies are similar?
similar_jumanji = df.loc[df['title'] == 'Jumanji']
s = similar_jumanji['genres'][1].split(',')
print(s)
# Out:
# ['Adventure', ' Fantasy', ' Family']

# %%
similarMovie = df.loc[(df['genres'] == s[0]) | (df['genres'] == s[1]) | (df['genres'] == s[2])]
plt.figure(figsize=(30, 10))
ax = sns.barplot(data=similarMovie.nlargest(15,'vote_average'), x='title', y='vote_average', palette="gnuplot2")
ax.set_xticklabels(ax.get_xticklabels(), fontsize=20, rotation=20, ha="right")
ax.set_ylabel('Vote Average', fontsize=20)
# Out:
# Text(0, 0.5, 'Vote Average')

# %%
#count amount of total genres
def countgenre(data):
  dicts = {}
  for x in data:
    for y in x:
      if y not in dicts.keys():
        dicts[y] = 0
      dicts[y] = int(dicts[y])+1
  return dicts

# %%
GENRE = df['genres'].str.split(",")
GENRE = countgenre(GENRE)

# %%
colGenre = pd.DataFrame(data=GENRE.keys(),columns=['genres'])
rowGenre = pd.DataFrame(data=GENRE.values(),columns=['count_genre'])
colGenre.reset_index(inplace=True)
rowGenre.reset_index(inplace=True)
Genre = pd.merge(colGenre,rowGenre,on=['index','index'])
# create count genres dataframe for checking value count each genres

# %%
### mostly movies genre
plt.figure(figsize=(30, 10))
ax = sns.barplot(data=Genre.nlargest(32,'count_genre'), x='genres', y='count_genre' )
ax.set_xticklabels(ax.get_xticklabels(), fontsize=20, rotation=40, ha="right")
ax.set_ylabel('Count Genres', fontsize=20)
# Out:
# Text(0, 0.5, 'Count Genres')

# %%
plt.figure(figsize=(10,10))
sns.distplot(df['vote_average']);
#check the voting period
# Out:
# C:\Python\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
data_task = df.original_language.value_counts().head(20)
data_task = pd.DataFrame({"Language" : data_task.index, "Count" : data_task}).reset_index(drop = True)
data_task
# Out:
#    Language  Count
# 0        en  30329
# 1        fr   2213
# 2        ja   1284
# 3        it   1181
# 4        de    926
# 5        es    874
# 6        ru    756
# 7        hi    476
# 8        ko    431
# 9        zh    389
# 10       sv    355
# 11       cn    310
# 12       pt    284
# 13       da    214
# 14       nl    211
# 15       fi    199
# 16       pl    192
# 17       cs    121
# 18       no     99
# 19       tr     96

# %%
#check other languages without eng
plt.figure(figsize = (20, 10))
plt.title("Number of movies in languages other than english", fontsize = 27, fontweight = 'bold')

sns.barplot(x = data_task.loc[(data_task.Language != 'en'), 'Language'] ,
            y = data_task.loc[(data_task.Language != 'en'), 'Count'],
           palette = sns.color_palette("BuGn_r", 25))

plt.xlabel('Language', fontsize = 20)
plt.ylabel('Number Of Movies', fontsize = 20)
plt.xticks(fontsize = 17)
plt.yticks(fontsize = 13)
# Out:
# (array([   0.,  500., 1000., 1500., 2000., 2500.]),
#  [Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, '')])

# %%
#create new dataframe for checking wether how many adult in column adult
check_adult = df.adult.value_counts()
adult_df = pd.DataFrame({"adult" : check_adult.index, "adult_count" : check_adult}).reset_index(drop = True)
adult_df
# Out:
#    adult  adult_count
# 0  False        42061
# 1   True            8

# %%
adult_df['adult'] = adult_df['adult'].apply(lambda x: 'teenager' if x == 'False' else 'Adult')
adult_df
# Out:
#       adult  adult_count
# 0  teenager        42061
# 1     Adult            8

# %%
plt.figure(figsize = (5, 5))
sns.barplot(data=adult_df, x='adult', y='adult_count',color="#222")
plt.ylabel("Adult and Teenager Count")
plt.xlabel("<3")
plt.title("Adult & Teenager");

# %% [markdown]
# # Feature Engineering
# ## What feature should I decide to give the model to train itself to be predicting a similarity movie?
#     1. Genre
#     2. Overview
#     4. imdb score

# %%
from sklearn.feature_extraction.text import TfidfVectorizer, CountVectorizer
from sklearn.metrics.pairwise import cosine_similarity, linear_kernel

# %% [markdown]
# ### Combining features

# %%
def combining_features(row):
    return row['genres'] + " " + row['overview']

# %%
df['combining_features'] = df.apply(combining_features, axis=1)

# %% [markdown]
# # Modeling
# ## Decide by time it spends to train
#     We have got 4 choices which are
#         1. CountVectorizer with linear_kernel
#         2. CountVectorizer with Cosine_similarity
#         3. TfidfVectorizer with linear_kernel
#         4. TfidfVectorizer with cosine_similarity

# %% [markdown]
# ### CountVectorizer with Linear_Kernel
#     this dude takes 0.1 sec for generating @vector
#     and another 17.9 secs for generating @item_similarity

# %%
vector = CountVectorizer().fit_transform(df['combining_features'])

# %%
df.columns
# Out:
# Index(['adult', 'budget', 'genres', 'id', 'imdb_id', 'original_language',
#        'original_title', 'overview', 'popularity', 'poster_path',
#        'production_companies', 'production_countries', 'release_date',
#        'revenue', 'runtime', 'spoken_languages', 'status', 'title', 'video',
#        'vote_average', 'vote_count', 'combining_features'],
#       dtype='object')

# %%
item_similarity = linear_kernel(vector)
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_17360/1418099711.py in <module>
# ----> 1 item_similarity = linear_kernel(vector)
#
# C:\Python\lib\site-packages\sklearn\metrics\pairwise.py in linear_kernel(X, Y, dense_output)
#    1066     """
#    1067     X, Y = check_pairwise_arrays(X, Y)
# -> 1068     return safe_sparse_dot(X, Y.T, dense_output=dense_output)
#    1069
#    1070
#
# C:\Python\lib\site-packages\sklearn\utils\extmath.py in safe_sparse_dot(a, b, dense_output)
#     159         and hasattr(ret, "toarray")
#     160     ):
# --> 161         return ret.toarray()
#     162     return ret
#     163
#
# C:\Python\lib\site-packages\scipy\sparse\compressed.py in toarray(self, order, out)
#    1037         if out is None and order is None:
#    1038             order = self._swap('cf')[0]
# -> 1039         out = self._process_toarray_args(order, out)
#    1040         if not (out.flags.c_contiguous or out.flags.f_contiguous):
#    1041             raise ValueError('Output array must be C or F contiguous')
#
# C:\Python\lib\site-packages\scipy\sparse\base.py in _process_toarray_args(self, order, out)
#    1200             return out
#    1201         else:
# -> 1202             return np.zeros(self.shape, dtype=self.dtype, order=order)
#    1203
#    1204
#
# MemoryError: Unable to allocate 13.2 GiB for an array with shape (42069, 42069) and data type float64

# %% [markdown]
# ### CountVectorizer With Cosine_Similarity
#     it spends 18.2 seconds according to the timer in the below of the cell
#     this dude is the 2nd runner up for the fastest algorithm

# %%
# vector = CountVectorizer().fit_transform(df['genres'])
# item_similarity = cosine_similarity(vector)

# %% [markdown]
# ### TfidfVectorizer with Linear_Kernel
#     20.2 secs for this one

# %%
# vector = TfidfVectorizer(stop_words='english').fit_transform(df['genres'])
# item_similarity = linear_kernel(vector)

# %% [markdown]
# ### TfidfVectorizer with Cosine_similarity
#     20.4 seconds

# %%
# vector = TfidfVectorizer(stop_words='english').fit_transform(df['genres'])
# item_similarity = cosine_similarity(vector)

# %% [markdown]
# ### Summary
#     1. CountVectorizer with linear_kernel 18.0 secs
#     2. CountVectorizer with Cosine_similarity 18.2 secs
#     3. TfidfVectorizer with linear_kernel 20.2 secs
#     4. TfidfVectorizer with cosine_similarity 20.4 secs
#
#     ALGORITHM HAS BEEN SELECTED, IT'S CountVectorizer with linear_kernel WITH IT'S FASTEST CALCULATION TIME 18.0 secs

# %% [markdown]
# ## Show similar movies

# %%
# giving a dummy of user's movie
dummy = "Jumanji"

#getting index of movie from extraction features array
def get_index(dummy):
    return df[df['title'] == dummy].index.values[0]

movies_index = get_index(dummy)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_17572/1465299225.py in <module>
#       6     return df[df['title'] == dummy].index.values[0]
#       7
# ----> 8 movies_index = get_index(dummy)
#
# ~\AppData\Local\Temp/ipykernel_17572/1465299225.py in get_index(dummy)
#       4 #getting index of movie from extraction features array
#       5 def get_index(dummy):
# ----> 6     return df[df['title'] == dummy].index.values[0]
#       7
#       8 movies_index = get_index(dummy)
#
# NameError: name 'df' is not defined

# %%
movies_index
# Out:
# 1

# %%
# Generating similar movies to dummy
similar_movies = list(enumerate(item_similarity[movies_index]))

# %%
# sorting 
sorted_similar_movies = sorted(similar_movies, key=lambda x: x[1], reverse=True)

# %%
sorted_similar_movies
# Out:
# [(30135, 126.0),
#  (3354, 105.0),
#  (13265, 103.0),
#  (17926, 103.0),
#  (5401, 102.0),
#  (22084, 102.0),
#  (21106, 101.0),
#  (12625, 99.0),
#  (18501, 99.0),
#  (39354, 99.0),
#  (37134, 98.0),
#  (40996, 98.0),
#  (18199, 97.0),
#  (28860, 97.0),
#  (37628, 97.0),
#  (10680, 96.0),
#  (17637, 96.0),
#  (27864, 96.0),
#  (8627, 94.0),
#  (12202, 94.0),
#  (15675, 94.0),
#  (23483, 94.0),
#  (28050, 94.0),
#  (36794, 94.0),
#  (9647, 93.0),
#  (14659, 93.0),
#  (16529, 93.0),
#  (17889, 93.0),
#  (31371, 93.0),
#  (32733, 93.0),
#  (7137, 92.0),
#  (14105, 92.0),
#  (19302, 92.0),
#  (25319, 92.0),
#  (31084, 92.0),
#  (36058, 92.0),
#  (37205, 92.0),
#  (39647, 92.0),
#  (40058, 92.0),
#  (8666, 91.0),
#  (16947, 91.0),
#  (19195, 91.0),
#  (27958, 91.0),
#  (29356, 91.0),
#  (35584, 91.0),
#  (40515, 91.0),
#  (13797, 90.0),
#  (14240, 90.0),
#  (30133, 90.0),
#  (33294, 90.0),
#  (33409, 90.0),
#  (36729, 90.0),
#  (1, 89.0),
#  (33188, 89.0),
#  (36628, 89.0),
#  (1921, 88.0),
#  (14376, 88.0),
#  (16553, 88.0),
#  (17234, 88.0),
#  (22873, 88.0),
#  (26851, 88.0),
#  (30163, 88.0),
#  (31087, 88.0),
#  (38744, 88.0),
#  (2120, 87.0),
#  (3418, 87.0),
#  (14587, 87.0),
#  (23802, 87.0),
#  (24842, 87.0),
#  (31808, 87.0),
#  (32461, 87.0),
#  (36426, 87.0),
#  (39668, 87.0),
#  (932, 86.0),
#  (6159, 86.0),
#  (7861, 86.0),
#  (9224, 86.0),
#  (9669, 86.0),
#  (16480, 86.0),
#  (28018, 86.0),
#  (31072, 86.0),
#  (34884, 86.0),
#  (34907, 86.0),
#  (35074, 86.0),
#  (35498, 86.0),
#  (4992, 85.0),
#  (5493, 85.0),
#  (9705, 85.0),
#  (10153, 85.0),
#  (15940, 85.0),
#  (16682, 85.0),
#  (17575, 85.0),
#  (20988, 85.0),
df.columns
# Out:
# Index(['adult', 'budget', 'genres', 'id', 'imdb_id', 'original_language',
#        'original_title', 'overview', 'popularity', 'poster_path',
#        'production_companies', 'production_countries', 'release_date',
#        'revenue', 'runtime', 'spoken_languages', 'status', 'title', 'video',
#        'vote_average', 'vote_count', 'combining_features'],
#       dtype='object')

# %%
# it returns an array of index of movies and its score
# so we have to find what is the index represents the title of the movie
similar_movies_arr = []
score = []
def get_title(index):
    return df.loc[df.index == index]['title'].values[0]
for i in range(1, 6):
    similar_movies_arr.append(get_title(index = sorted_similar_movies[i][0]))
    score.append(sorted_similar_movies[i][1])

# %%
similar_movies_arr
# Out:
# ['Retroactive',
#  'High and Dizzy',
#  'Brothers at War',
#  'How I Killed My Father',
#  'Bells of Capistrano']

# %%
score
# Out:
# [105.0, 103.0, 103.0, 102.0, 102.0]

# %%
for j in range(len(similar_movies_arr)):
    print(f'Movie name = {similar_movies_arr[j]} | Matching score = {(score[j] * 0.01).round(2)}')
# Out:
# Movie name = Retroactive | Matching score = 1.05
# Movie name = High and Dizzy | Matching score = 1.03
# Movie name = Brothers at War | Matching score = 1.03
# Movie name = How I Killed My Father | Matching score = 1.02
# Movie name = Bells of Capistrano | Matching score = 1.02

# %% [markdown]
# # Pipeline
# ## Pre-Processing
#     - Remove rows which are null
#     - Remove rows which are duplicated
#     - Correcting genres (into string form)
#     - Mapping genres

# %%
class Pipe_Line:
    def __init__(self, data) -> None:
        self.data = data
    def drop_null_rows(self, data):
        data.dropna(axis='rows', inplace=True)
        return data
    def drop_duplicated(self, data):
        data.drop_duplicates(inplace=True)
        data.drop(data.loc[data['genres'] == ""].index, inplace=True)
        data.drop_duplicates(subset='title')
        return data
    def correcting_genre_form(self, data):
        regex = re.compile(r": '(.*?)'")
        data['genres'] = data['genres'].apply(lambda x: ",".join(regex.findall(x)))
        return data
    def combining_features(self, row):
        return row['genres'] + " " + row['overview']
    def feature_engineering(self, data):
        model = CountVectorizer()
        vector = model.fit_transform(data['combining_features'])
        return vector
    def reset_index(self, data):
        data.reset_index(drop=True, inplace=True)
        return data
    def execute(self, data):
        data = self.drop_null_rows(data)
        data = self.drop_duplicated(data)
        data = self.correcting_genre_form(data)
        data = self.reset_index(data)
        data['combining_features'] = data.apply(self.combining_features, axis=1)
        vector = self.feature_engineering(data)
        return vector

# %%
pipe_line = Pipe_Line(movies_pipe_line)

# %%
vector = pipe_line.execute(movies_pipe_line)

# %%
item_similarity = linear_kernel(vector)

# %% [markdown]
# # Recommendation Function
#     - Getting an input from users
#     - Finding index of movie name
#     - Getting similar movies as an array
#     - Sorting array
#     - Getting the first 5 positions which are similar to the input

# %%
movies_pipe_line
# Out:
#      adult                              belongs_to_collection     budget  \
# 0    False  {'id': 645, 'name': 'James Bond Collection', '...   58000000
# 1    False  {'id': 43563, 'name': 'Friday Collection', 'po...    3500000
# 2    False  {'id': 10924, 'name': 'From Dusk Till Dawn Col...   19000000
# 3    False  {'id': 439053, 'name': 'Brooklyn Cigar Store C...    2000000
# 4    False  {'id': 286162, 'name': 'Power Rangers Collecti...   15000000
# ..     ...                                                ...        ...
# 682  False  {'id': 473840, 'name': 'Little Forest Collecti...          0
# 683  False  {'id': 173710, 'name': 'Planet of the Apes (Re...  152000000
# 684  False  {'id': 476961, 'name': 'Goon Collection', 'pos...          0
# 685  False  {'id': 8650, 'name': 'Transformers Collection'...  260000000
# 686  False  {'id': 417491, 'name': 'Bon Cop Bad Cop Collec...          0
#
#     genres                                           homepage      id  \
# 0                http://www.mgm.com/view/movie/757/Goldeneye/     710
# 1               http://www.newline.com/properties/friday.html   10634
# 2           http://www.miramax.com/movie/from-dusk-till-dawn/     755
# 3                  http://miramax.com/movie/blue-in-the-face/    5894
# 4                                http://www.powerrangers.com/    9070
# ..     ...                                                ...     ...
# 682         https://web.archive.org/web/20160111092554/htt...  294682
# 683         http://www.foxmovies.com/movies/war-for-the-pl...  281338
# 684                https://www.facebook.com/GoonFilm/?fref=ts  336890
# 685                         http://www.transformersmovie.com/  335988
# 686                                       http://bcbc2.ca/en/  417489
#
#        imdb_id original_language                           original_title  \
# 0    tt0113189                en                                GoldenEye
# 1    tt0113118                en                                   Friday
# 2    tt0116367                en                      From Dusk Till Dawn
# 3    tt0112541                en                         Blue in the Face
# 4    tt0113820                en  Mighty Morphin Power Rangers: The Movie
# ..         ...               ...                                      ...
# 682  tt3474600                ja                            リトル・フォレスト 夏・秋
# 683  tt3450958                en           War for the Planet of the Apes
# 684  tt2417712                en              Goon: Last of the Enforcers
# 685  tt3371366                en            Transformers: The Last Knight
# 686  tt4738174                fr                        Bon Cop Bad Cop 2
#
#                                               overview  ...      revenue  \
# 0    James Bond must unmask the mysterious head of ...  ...  352194034.0
# 1    Craig and Smokey are two guys in Los Angeles h...  ...   28215918.0
# 2    Seth Gecko and his younger brother Richard are...  ...   25836616.0
# 3    Auggie runs a small tobacco shop in Brooklyn, ...  ...    1275000.0
# 4    Power up with six incredible teens who out-man...  ...   66000000.0
# ..                                                 ...  ...          ...
# 682  Abandoned by her mother, young Ichiko leaves h...  ...          0.0
# 683  Caesar and his apes are forced into a deadly c...  ...  369907963.0
# 684  During a pro lockout, Doug "The Thug" Glatt is...  ...          0.0
# 685  Autobots and Decepticons are at war, with huma...  ...  604942143.0
# 686  Ward and Bouchard must face an important car t...  ...          0.0
#
#     runtime                                   spoken_languages    status  \
# 0     130.0  [{'iso_639_1': 'en', 'name': 'English'}, {'iso...  Released
# 1      91.0           [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 2     108.0  [{'iso_639_1': 'en', 'name': 'English'}, {'iso...  Released
# 3      83.0           [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 4      92.0           [{'iso_639_1': 'en', 'name': 'English'}]  Released
# ..      ...                                                ...       ...
# 682   111.0               [{'iso_639_1': 'ja', 'name': '日本語'}]  Released
# 683   140.0           [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 684   101.0           [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 685   149.0           [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 686     0.0  [{'iso_639_1': 'en', 'name': 'English'}, {'iso...  Released
#
#                                                tagline  \
# 0                 No limits. No fears. No substitutes.
# 1    A lot can go down between thursday and saturda...
# 2    One night is all that stands between them and ...
# 3                      Welcome to the planet Brooklyn.
# 4                                     The Power Is On!
# ..                                                 ...
# 682                                    Back to nature.
# 683           For freedom. For family. For the planet.
# 684                                      Glatt's Back!
# 685         For one world to live, the other must die.
# 686            It's okay America, we've got your back.
#
#                                        title  video vote_average vote_count  \
# 0                                  GoldenEye  False          6.6     1194.0
# 1                                     Friday  False          7.0      513.0
# 2                        From Dusk Till Dawn  False          6.9     1644.0
# 3                           Blue in the Face  False          6.8       28.0
# 4    Mighty Morphin Power Rangers: The Movie  False          5.2      153.0
# ..                                       ...    ...          ...        ...
# 682             Little Forest: Summer/Autumn  False          8.3       16.0
# 683           War for the Planet of the Apes  False          6.7     1675.0
# 684              Goon: Last of the Enforcers  False          6.0       35.0
# 685            Transformers: The Last Knight  False          6.2     1440.0
# 686                        Bon Cop Bad Cop 2  False          6.8        5.0
#
#                                     combining_features
# 0     James Bond must unmask the mysterious head of...
# 1     Craig and Smokey are two guys in Los Angeles ...
# 2     Seth Gecko and his younger brother Richard ar...
# 3     Auggie runs a small tobacco shop in Brooklyn,...
# 4     Power up with six incredible teens who out-ma...
# ..                                                 ...
# 682   Abandoned by her mother, young Ichiko leaves ...
# 683   Caesar and his apes are forced into a deadly ...
# 684   During a pro lockout, Doug "The Thug" Glatt i...
# 685   Autobots and Decepticons are at war, with hum...
# 686   Ward and Bouchard must face an important car ...
#
# [687 rows x 25 columns]

# %%
movies_pipe_line.loc[movies_pipe_line['title'] == "Bon Cop Bad Cop 2"].index.values[0]
# Out:
# 45029

# %%
def recommend(movie_name):
    def get_index(movie_name):
        return movies_pipe_line[movies_pipe_line['title'] == movie_name].index.values[0]
    index = get_index(movie_name=movie_name)
    similar_items = list(enumerate(item_similarity[index]))
    sorted_similar_movies = sorted(similar_items, key=lambda x:x[1], reverse=True)
    movies_name = list()
    movies_matching_scores = list()
    def get_title(index):
        return movies_pipe_line[movies_pipe_line.index == index]['title'].values[0]
    for j in range(5):
        title = get_title(sorted_similar_movies[j][0])
        print(f"Movie Name = {title} | Matching Score = {(sorted_similar_movies[j][1] * 0.01).round(2)}")
        movies_name.append(title)
        movies_matching_scores.append((sorted_similar_movies[j][1] * 0.01).round(2))
    return movies_name, movies_matching_scores

# %%
#testing
print(recommend('Bon Cop Bad Cop 2'))
# Out:
# Movie Name = Pokémon: Zoroark: Master of Illusions | Matching Score = 0.4
# Movie Name = Bill & Ted's Excellent Adventure | Matching Score = 0.37
# Movie Name = Tribulation | Matching Score = 0.37
# Movie Name = Don : The Chase Begins Again | Matching Score = 0.35
# Movie Name = Pokémon: Arceus and the Jewel of Life | Matching Score = 0.35
# (['Pokémon: Zoroark: Master of Illusions', "Bill & Ted's Excellent Adventure", 'Tribulation', 'Don : The Chase Begins Again', 'Pokémon: Arceus and the Jewel of Life'], [0.4, 0.37, 0.37, 0.35, 0.35])

# %% [markdown]
# # Deployment
#     - Web app
#         - Getting an input in movie_name form
#         - Output as a set of movie names with its matching score

# %%
import gradio

# %%
iface = gradio.Interface(fn=recommend,
                     inputs=[gradio.inputs.Textbox(label='Enter Movie Name')],
                     outputs=[gradio.outputs.Textbox(label="Movies Title"), gradio.outputs.Dataframe(label='Movies Matching Score')])
iface.launch()
# Out:
# Running on local URL:  http://127.0.0.1:7862/
#
# To create a public link, set `share=True` in `launch()`.
#         <iframe
#             width="900"
#             height="500"
#             src="http://127.0.0.1:7862/"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>
# (<Flask 'gradio.networking'>, 'http://127.0.0.1:7862/', None)
# Movie Name = Pokémon: Zoroark: Master of Illusions | Matching Score = 0.4
# Movie Name = Bill & Ted's Excellent Adventure | Matching Score = 0.38
# Movie Name = Bon Cop Bad Cop 2 | Matching Score = 0.38
# Movie Name = Tribulation | Matching Score = 0.37
# Movie Name = Don : The Chase Begins Again | Matching Score = 0.36
