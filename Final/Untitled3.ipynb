# %% [markdown]
# # Check whether this thing is working

# %%
"Hello World"
# Out:
# 'Hello World'

# %% [markdown]
# # DNA Framework

# %% [markdown]
# # Import libraries

# %%
import seaborn as sns
import matplotlib as plt
import re
import pandas as pd

# %% [markdown]
# # Import Dataset

# %%
movies = pd.read_csv('movies_metadata.csv')

# %% [markdown]
# # Data pre-processing

# %%
movies.isna().sum()
# Out:
# adult                        0
# belongs_to_collection    40972
# budget                       0
# genres                       0
# homepage                 37684
# id                           0
# imdb_id                     17
# original_language           11
# original_title               0
# overview                   954
# popularity                   5
# poster_path                386
# production_companies         3
# production_countries         3
# release_date                87
# revenue                      6
# runtime                    263
# spoken_languages             6
# status                      87
# tagline                  25054
# title                        6
# video                        6
# vote_average                 6
# vote_count                   6
# dtype: int64

# %%
movies.columns
# Out:
# Index(['adult', 'belongs_to_collection', 'budget', 'genres', 'homepage', 'id',
#        'imdb_id', 'original_language', 'original_title', 'overview',
#        'popularity', 'poster_path', 'production_companies',
#        'production_countries', 'release_date', 'revenue', 'runtime',
#        'spoken_languages', 'status', 'tagline', 'title', 'video',
#        'vote_average', 'vote_count'],
#       dtype='object')

# %%
movies.duplicated().sum()
# Out:
# 13

# %%
movies.drop_duplicates(inplace=True)

# %%
movies.reset_index()
# Out:
#        index  adult                              belongs_to_collection  \
# 0          0  False  {'id': 10194, 'name': 'Toy Story Collection', ...
# 1          1  False                                                NaN
# 2          2  False  {'id': 119050, 'name': 'Grumpy Old Men Collect...
# 3          3  False                                                NaN
# 4          4  False  {'id': 96871, 'name': 'Father of the Bride Col...
# ...      ...    ...                                                ...
# 45448  45461  False                                                NaN
# 45449  45462  False                                                NaN
# 45450  45463  False                                                NaN
# 45451  45464  False                                                NaN
# 45452  45465  False                                                NaN
#
#          budget                                             genres  \
# 0      30000000  [{'id': 16, 'name': 'Animation'}, {'id': 35, '...
# 1      65000000  [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...
# 2             0  [{'id': 10749, 'name': 'Romance'}, {'id': 35, ...
# 3      16000000  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 4             0                     [{'id': 35, 'name': 'Comedy'}]
# ...         ...                                                ...
# 45448         0  [{'id': 18, 'name': 'Drama'}, {'id': 10751, 'n...
# 45449         0                      [{'id': 18, 'name': 'Drama'}]
# 45450         0  [{'id': 28, 'name': 'Action'}, {'id': 18, 'nam...
# 45451         0                                                 []
# 45452         0                                                 []
#
#                                    homepage      id    imdb_id  \
# 0      http://toystory.disney.com/toy-story     862  tt0114709
# 1                                       NaN    8844  tt0113497
# 2                                       NaN   15602  tt0113228
# 3                                       NaN   31357  tt0114885
# 4                                       NaN   11862  tt0113041
# ...                                     ...     ...        ...
# 45448  http://www.imdb.com/title/tt6209470/  439050  tt6209470
# 45449                                   NaN  111109  tt2028550
# 45450                                   NaN   67758  tt0303758
# 45451                                   NaN  227506  tt0008536
# 45452                                   NaN  461257  tt6980792
#
#       original_language               original_title  ... release_date  \
# 0                    en                    Toy Story  ...   1995-10-30
# 1                    en                      Jumanji  ...   1995-12-15
# 2                    en             Grumpier Old Men  ...   1995-12-22
# 3                    en            Waiting to Exhale  ...   1995-12-22
# 4                    en  Father of the Bride Part II  ...   1995-02-10
# ...                 ...                          ...  ...          ...
# 45448                fa                      رگ خواب  ...          NaN
# 45449                tl          Siglo ng Pagluluwal  ...   2011-11-17
# 45450                en                     Betrayal  ...   2003-08-01
# 45451                en          Satana likuyushchiy  ...   1917-10-21
# 45452                en                     Queerama  ...   2017-06-09
#
#            revenue runtime                                   spoken_languages  \
# 0      373554033.0    81.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 1      262797249.0   104.0  [{'iso_639_1': 'en', 'name': 'English'}, {'iso...
# 2              0.0   101.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 3       81452156.0   127.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 4       76578911.0   106.0           [{'iso_639_1': 'en', 'name': 'English'}]
# ...            ...     ...                                                ...
# 45448          0.0    90.0             [{'iso_639_1': 'fa', 'name': 'فارسی'}]
# 45449          0.0   360.0                  [{'iso_639_1': 'tl', 'name': ''}]
# 45450          0.0    90.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 45451          0.0    87.0                                                 []
# 45452          0.0    75.0           [{'iso_639_1': 'en', 'name': 'English'}]
#
#          status                                            tagline  \
# 0      Released                                                NaN
# 1      Released          Roll the dice and unleash the excitement!
# 2      Released  Still Yelling. Still Fighting. Still Ready for...
# 3      Released  Friends are the people who let you be yourself...
# 4      Released  Just When His World Is Back To Normal... He's ...
# ...         ...                                                ...
# 45448  Released         Rising and falling between a man and woman
# 45449  Released                                                NaN
# 45450  Released                             A deadly game of wits.
# 45451  Released                                                NaN
# 45452  Released                                                NaN
#
#                              title  video vote_average vote_count
# 0                        Toy Story  False          7.7     5415.0
# 1                          Jumanji  False          6.9     2413.0
# 2                 Grumpier Old Men  False          6.5       92.0
# 3                Waiting to Exhale  False          6.1       34.0
# 4      Father of the Bride Part II  False          5.7      173.0
# ...                            ...    ...          ...        ...
# 45448                       Subdue  False          4.0        1.0
# 45449          Century of Birthing  False          9.0        3.0
# 45450                     Betrayal  False          3.8        6.0
# 45451             Satan Triumphant  False          0.0        0.0
# 45452                     Queerama  False          0.0        0.0
#
# [45453 rows x 25 columns]

# %%
movies.duplicated().sum()
# Out:
# 0

# %%
movies['overview']
# Out:
# 0        Led by Woody, Andy's toys live happily in his ...
# 1        When siblings Judy and Peter discover an encha...
# 2        A family wedding reignites the ancient feud be...
# 3        Cheated on, mistreated and stepped on, the wom...
# 4        Just when George Banks has recovered from his ...
#                                ...
# 45461          Rising and falling between a man and woman.
# 45462    An artist struggles to finish his work while a...
# 45463    When one of her hits goes wrong, a professiona...
# 45464    In a small town live two brothers, one a minis...
# 45465    50 years after decriminalisation of homosexual...
# Name: overview, Length: 45453, dtype: object

# %%
movies.shape
# Out:
# (45453, 24)

# %% [markdown]
# ## To see that how do the NA columns look like

# %%
movies.isna().sum()
# Out:
# adult                        0
# belongs_to_collection    40959
# budget                       0
# genres                       0
# homepage                 37673
# id                           0
# imdb_id                     17
# original_language           11
# original_title               0
# overview                   954
# popularity                   5
# poster_path                386
# production_companies         3
# production_countries         3
# release_date                87
# revenue                      6
# runtime                    263
# spoken_languages             6
# status                      87
# tagline                  25045
# title                        6
# video                        6
# vote_average                 6
# vote_count                   6
# dtype: int64

# %%
#Check null first
movies.loc[movies['homepage'].isnull()].head(5)
# Out:
#    adult                              belongs_to_collection    budget  \
# 1  False                                                NaN  65000000
# 2  False  {'id': 119050, 'name': 'Grumpy Old Men Collect...         0
# 3  False                                                NaN  16000000
# 4  False  {'id': 96871, 'name': 'Father of the Bride Col...         0
# 5  False                                                NaN  60000000
#
#                                               genres homepage     id  \
# 1  [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...      NaN   8844
# 2  [{'id': 10749, 'name': 'Romance'}, {'id': 35, ...      NaN  15602
# 3  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...      NaN  31357
# 4                     [{'id': 35, 'name': 'Comedy'}]      NaN  11862
# 5  [{'id': 28, 'name': 'Action'}, {'id': 80, 'nam...      NaN    949
#
#      imdb_id original_language               original_title  \
# 1  tt0113497                en                      Jumanji
# 2  tt0113228                en             Grumpier Old Men
# 3  tt0114885                en            Waiting to Exhale
# 4  tt0113041                en  Father of the Bride Part II
# 5  tt0113277                en                         Heat
#
#                                             overview  ... release_date  \
# 1  When siblings Judy and Peter discover an encha...  ...   1995-12-15
# 2  A family wedding reignites the ancient feud be...  ...   1995-12-22
# 3  Cheated on, mistreated and stepped on, the wom...  ...   1995-12-22
# 4  Just when George Banks has recovered from his ...  ...   1995-02-10
# 5  Obsessive master thief, Neil McCauley leads a ...  ...   1995-12-15
#
#        revenue runtime                                   spoken_languages  \
# 1  262797249.0   104.0  [{'iso_639_1': 'en', 'name': 'English'}, {'iso...
# 2          0.0   101.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 3   81452156.0   127.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 4   76578911.0   106.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 5  187436818.0   170.0  [{'iso_639_1': 'en', 'name': 'English'}, {'iso...
#
#      status                                            tagline  \
# 1  Released          Roll the dice and unleash the excitement!
# 2  Released  Still Yelling. Still Fighting. Still Ready for...
# 3  Released  Friends are the people who let you be yourself...
# 4  Released  Just When His World Is Back To Normal... He's ...
# 5  Released                           A Los Angeles Crime Saga
#
#                          title  video vote_average vote_count
# 1                      Jumanji  False          6.9     2413.0
# 2             Grumpier Old Men  False          6.5       92.0
# 3            Waiting to Exhale  False          6.1       34.0
# 4  Father of the Bride Part II  False          5.7      173.0
# 5                         Heat  False          7.7     1886.0
#
# [5 rows x 24 columns]

# %%
#check not null
movies.loc[movies['homepage'].notnull()].head()
# Out:
#     adult                              belongs_to_collection    budget  \
# 0   False  {'id': 10194, 'name': 'Toy Story Collection', ...  30000000
# 9   False  {'id': 645, 'name': 'James Bond Collection', '...  58000000
# 24  False                                                NaN   3600000
# 46  False                                                NaN  33000000
# 49  False                                                NaN   6000000
#
#                                                genres  \
# 0   [{'id': 16, 'name': 'Animation'}, {'id': 35, '...
# 9   [{'id': 12, 'name': 'Adventure'}, {'id': 28, '...
# 24  [{'id': 18, 'name': 'Drama'}, {'id': 10749, 'n...
# 46  [{'id': 80, 'name': 'Crime'}, {'id': 9648, 'na...
# 49  [{'id': 18, 'name': 'Drama'}, {'id': 80, 'name...
#
#                                              homepage   id    imdb_id  \
# 0                http://toystory.disney.com/toy-story  862  tt0114709
# 9        http://www.mgm.com/view/movie/757/Goldeneye/  710  tt0113189
# 24  http://www.mgm.com/title_title.do?title_star=L...  451  tt0113627
# 46                         http://www.sevenmovie.com/  807  tt0114369
# 49  http://www.mgm.com/#/our-titles/2083/The-Usual...  629  tt0114814
#
#    original_language      original_title  \
# 0                 en           Toy Story
# 9                 en           GoldenEye
# 24                en   Leaving Las Vegas
# 46                en               Se7en
# 49                en  The Usual Suspects
#
#                                              overview  ... release_date  \
# 0   Led by Woody, Andy's toys live happily in his ...  ...   1995-10-30
# 9   James Bond must unmask the mysterious head of ...  ...   1995-11-16
# 24  Ben Sanderson, an alcoholic Hollywood screenwr...  ...   1995-10-27
# 46  Two homicide detectives are on a desperate hun...  ...   1995-09-22
# 49  Held in an L.A. interrogation room, Verbal Kin...  ...   1995-07-19
#
#         revenue runtime                                   spoken_languages  \
# 0   373554033.0    81.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 9   352194034.0   130.0  [{'iso_639_1': 'en', 'name': 'English'}, {'iso...
# 24   49800000.0   112.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 46  327311859.0   127.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 49   23341568.0   106.0  [{'iso_639_1': 'es', 'name': 'Español'}, {'iso...
#
#       status                                       tagline  \
# 0   Released                                           NaN
# 9   Released          No limits. No fears. No substitutes.
# 24  Released                I Love You... The Way You Are.
# 46  Released         Seven deadly sins. Seven ways to die.
# 49  Released  Five Criminals. One Line Up. No Coincidence.
#
#                  title  video vote_average vote_count
# 0            Toy Story  False          7.7     5415.0
# 9            GoldenEye  False          6.6     1194.0
# 24   Leaving Las Vegas  False          7.1      365.0
# 46               Se7en  False          8.1     5915.0
# 49  The Usual Suspects  False          8.1     3334.0
#
# [5 rows x 24 columns]

# %%
# We already know that HomePage column is just a hompage of each movies
# Out objective is to recommend movies to user so, homepage isn't that neccessary
# How about drop the column?
# Yes of course that's a great idea
# but we must first create another dataFrame so, we won't end up like s*** if we f***ed up
df = movies.copy()

# %%
#dropping
df.drop('homepage', axis='columns', inplace=True)

# %%
#check if it's dropped
df.columns
# Out:
# Index(['adult', 'belongs_to_collection', 'budget', 'genres', 'id', 'imdb_id',
#        'original_language', 'original_title', 'overview', 'popularity',
#        'poster_path', 'production_companies', 'production_countries',
#        'release_date', 'revenue', 'runtime', 'spoken_languages', 'status',
#        'tagline', 'title', 'video', 'vote_average', 'vote_count'],
#       dtype='object')

# %%
# it's gone so let's check another columns
df.isna().sum()
# Out:
# adult                        0
# belongs_to_collection    40959
# budget                       0
# genres                       0
# id                           0
# imdb_id                     17
# original_language           11
# original_title               0
# overview                   954
# popularity                   5
# poster_path                386
# production_companies         3
# production_countries         3
# release_date                87
# revenue                      6
# runtime                    263
# spoken_languages             6
# status                      87
# tagline                  25045
# title                        6
# video                        6
# vote_average                 6
# vote_count                   6
# dtype: int64

# %%
#the next column that we'll inspect will be belong_to_collection one
#check whether how much is it to the whole count of dataset
len(df.loc[df['belongs_to_collection'].isnull()]) * 100 / df.shape[0]
# Out:
# 90.11286383737047

# %%
#it's almost 100% holy s***
#so I wonder how about another null columns?
(df.isna().sum() * 100 / df.shape[0]).round(2)
# Out:
# adult                     0.00
# belongs_to_collection    90.11
# budget                    0.00
# genres                    0.00
# id                        0.00
# imdb_id                   0.04
# original_language         0.02
# original_title            0.00
# overview                  2.10
# popularity                0.01
# poster_path               0.85
# production_companies      0.01
# production_countries      0.01
# release_date              0.19
# revenue                   0.01
# runtime                   0.58
# spoken_languages          0.01
# status                    0.19
# tagline                  55.10
# title                     0.01
# video                     0.01
# vote_average              0.01
# vote_count                0.01
# dtype: float64

# %%
#there are two columns that're above 50%
#dropping
df.drop('belongs_to_collection', axis='columns', inplace=True)

# %%
df.drop('tagline', axis='columns', inplace=True)

# %%
#check
df.columns
# Out:
# Index(['adult', 'budget', 'genres', 'id', 'imdb_id', 'original_language',
#        'original_title', 'overview', 'popularity', 'poster_path',
#        'production_companies', 'production_countries', 'release_date',
#        'revenue', 'runtime', 'spoken_languages', 'status', 'title', 'video',
#        'vote_average', 'vote_count'],
#       dtype='object')

# %%
#let's move to the next one
#overview
df.loc[df['overview'].isnull()]
# Out:
#        adult    budget                                             genres  \
# 32     False         0  [{'id': 10749, 'name': 'Romance'}, {'id': 12, ...
# 300    False  22000000  [{'id': 18, 'name': 'Drama'}, {'id': 35, 'name...
# 634    False         0                     [{'id': 35, 'name': 'Comedy'}]
# 635    False         0                     [{'id': 35, 'name': 'Comedy'}]
# 641    False         0                     [{'id': 35, 'name': 'Comedy'}]
# ...      ...       ...                                                ...
# 45342  False         0                      [{'id': 18, 'name': 'Drama'}]
# 45377  False         0                  [{'id': 12, 'name': 'Adventure'}]
# 45398  False   1254040  [{'id': 10749, 'name': 'Romance'}, {'id': 35, ...
# 45399  False    750000  [{'id': 80, 'name': 'Crime'}, {'id': 35, 'name...
# 45410  False         0  [{'id': 18, 'name': 'Drama'}, {'id': 80, 'name...
#
#            id    imdb_id original_language                    original_title  \
# 32      78802  tt0114952                fr  Guillaumet, les ailes du courage
# 300    161495  tt0114296                sv                         Roommates
# 634    287305  tt0117312                de    Peanuts – Die Bank zahlt alles
# 635    339428  tt0116485                de                     Happy Weekend
# 641     10801  tt0117788                de                     Das Superweib
# ...       ...        ...               ...                               ...
# 45342  199887  tt1771636                en                        Over/Under
# 45377  317389  tt0070695                es     Simbad e il califfo di Bagdad
# 45398  468707  tt5742932                fi  Lauri Mäntyvaaran tuuheet ripset
# 45399  280422  tt3805180                ru                       Все и сразу
# 45410  449131  tt0321264                ru                             Aprel
#
#       overview popularity                       poster_path  ...  \
# 32         NaN   0.745542  /k6ODtR38dKEfuzSGjggr8KDyAF4.jpg  ...
# 300        NaN    3.39587  /hvHNlMvWS2GBt7RR971bJ3k4bJc.jpg  ...
# 634        NaN   0.066123  /wpk30SvRHmjC2plgKHZXxG0FlKd.jpg  ...
# 635        NaN   0.002229                               NaN  ...
# 641        NaN   0.821299  /AbhMKCh3fV5PY2B9uSPF1DWEvq2.jpg  ...
# ...        ...        ...                               ...  ...
# 45342      NaN   0.704642  /1xLaIBGGPE4APtBJdfeuyOWICZ0.jpg  ...
# 45377      NaN   0.006352  /izk7KbT6LZO9baEhCkOZYMgj60w.jpg  ...
# 45398      NaN   0.347806  /rKOpJuwb7pTqYVShHM2tl25VxyF.jpg  ...
# 45399      NaN   0.201582  /hNsmPpl3zLG36jr4EIEd5P8I4pa.jpg  ...
# 45410      NaN   0.008903                               NaN  ...
#
#                                     production_countries release_date  \
# 32     [{'iso_3166_1': 'FR', 'name': 'France'}, {'iso...   1996-09-18
# 300    [{'iso_3166_1': 'US', 'name': 'United States o...   1995-03-01
# 634            [{'iso_3166_1': 'DE', 'name': 'Germany'}]   1996-03-21
# 635            [{'iso_3166_1': 'DE', 'name': 'Germany'}]   1996-03-14
# 641            [{'iso_3166_1': 'DE', 'name': 'Germany'}]   1996-03-06
# ...                                                  ...          ...
# 45342  [{'iso_3166_1': 'US', 'name': 'United States o...   2013-01-04
# 45377            [{'iso_3166_1': 'IT', 'name': 'Italy'}]   1973-07-22
# 45398          [{'iso_3166_1': 'FI', 'name': 'Finland'}]   2017-07-28
# 45399           [{'iso_3166_1': 'RU', 'name': 'Russia'}]   2014-06-05
# 45410           [{'iso_3166_1': 'RU', 'name': 'Russia'}]          NaN
#
#           revenue  runtime                           spoken_languages  \
# 32            0.0     50.0   [{'iso_639_1': 'en', 'name': 'English'}]
# 300    12400000.0    108.0   [{'iso_639_1': 'en', 'name': 'English'}]
# 634           0.0      NaN                                         []
# 635       65335.0      NaN   [{'iso_639_1': 'de', 'name': 'Deutsch'}]
# 641           0.0     86.0   [{'iso_639_1': 'de', 'name': 'Deutsch'}]
# ...           ...      ...                                        ...
# 45342         0.0     87.0   [{'iso_639_1': 'en', 'name': 'English'}]
# 45377         0.0      NaN  [{'iso_639_1': 'it', 'name': 'Italiano'}]
# 45398         0.0     90.0     [{'iso_639_1': 'fi', 'name': 'suomi'}]
# 45399         3.0      0.0   [{'iso_639_1': 'ru', 'name': 'Pусский'}]
# 45410         0.0      NaN                                         []
#
#          status                             title  video vote_average  \
# 32     Released                  Wings of Courage  False          6.8
# 300    Released                         Roommates  False          6.4
# 634    Released    Peanuts – Die Bank zahlt alles  False          4.0
# 635    Released                     Happy Weekend  False          0.0
# 641    Released                     The Superwife  False          5.3
# ...         ...                               ...    ...          ...
# 45342  Released                        Over/Under  False          4.0
# 45377  Released     Simbad e il califfo di Bagdad  False          0.0
# 45398  Released  Thick Lashes of Lauri Mäntyvaara  False          8.0
# 45399  Released                       All at Once  False          6.0
# 45410  Released                             Aprel  False          6.0
#
#        vote_count
# 32            4.0
# 300           7.0
# 634           1.0
# 635           0.0
# 641           7.0
# ...           ...
# 45342         2.0
# 45377         0.0
# 45398         1.0
# 45399         4.0
# 45410         1.0
#
# [954 rows x 21 columns]

# %%
#it's neccesary to have overview, it represents as a short version of the movie
#so I decided to drop the NaN rows
df.dropna(axis='rows', inplace=True)

# %%
df.shape[0]
# Out:
# 44035

# %%
df.isna().sum()
# Out:
# adult                   0
# budget                  0
# genres                  0
# id                      0
# imdb_id                 0
# original_language       0
# original_title          0
# overview                0
# popularity              0
# poster_path             0
# production_companies    0
# production_countries    0
# release_date            0
# revenue                 0
# runtime                 0
# spoken_languages        0
# status                  0
# title                   0
# video                   0
# vote_average            0
# vote_count              0
# dtype: int64

# %%
df.head()
# Out:
#    adult    budget                                             genres     id  \
# 0  False  30000000  [{'id': 16, 'name': 'Animation'}, {'id': 35, '...    862
# 1  False  65000000  [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...   8844
# 2  False         0  [{'id': 10749, 'name': 'Romance'}, {'id': 35, ...  15602
# 3  False  16000000  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...  31357
# 4  False         0                     [{'id': 35, 'name': 'Comedy'}]  11862
#
#      imdb_id original_language               original_title  \
# 0  tt0114709                en                    Toy Story
# 1  tt0113497                en                      Jumanji
# 2  tt0113228                en             Grumpier Old Men
# 3  tt0114885                en            Waiting to Exhale
# 4  tt0113041                en  Father of the Bride Part II
#
#                                             overview popularity  \
# 0  Led by Woody, Andy's toys live happily in his ...    21.9469
# 1  When siblings Judy and Peter discover an encha...    17.0155
# 2  A family wedding reignites the ancient feud be...    11.7129
# 3  Cheated on, mistreated and stepped on, the wom...    3.85949
# 4  Just when George Banks has recovered from his ...    8.38752
#
#                         poster_path  ...  \
# 0  /rhIRbceoE9lR4veEXuwCC2wARtG.jpg  ...
# 1  /vzmL6fP7aPKNKPRTFnZmiUfciyV.jpg  ...
# 2  /6ksm1sjKMFLbO7UY2i6G1ju9SML.jpg  ...
# 3  /16XOMpEaLWkrcPqSQqhTmeJuqQl.jpg  ...
# 4  /e64sOI48hQXyru7naBFyssKFxVd.jpg  ...
#
#                                 production_countries release_date  \
# 0  [{'iso_3166_1': 'US', 'name': 'United States o...   1995-10-30
# 1  [{'iso_3166_1': 'US', 'name': 'United States o...   1995-12-15
# 2  [{'iso_3166_1': 'US', 'name': 'United States o...   1995-12-22
# 3  [{'iso_3166_1': 'US', 'name': 'United States o...   1995-12-22
# 4  [{'iso_3166_1': 'US', 'name': 'United States o...   1995-02-10
#
#        revenue  runtime                                   spoken_languages  \
# 0  373554033.0     81.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 1  262797249.0    104.0  [{'iso_639_1': 'en', 'name': 'English'}, {'iso...
# 2          0.0    101.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 3   81452156.0    127.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 4   76578911.0    106.0           [{'iso_639_1': 'en', 'name': 'English'}]
#
#      status                        title  video vote_average  vote_count
# 0  Released                    Toy Story  False          7.7      5415.0
# 1  Released                      Jumanji  False          6.9      2413.0
# 2  Released             Grumpier Old Men  False          6.5        92.0
# 3  Released            Waiting to Exhale  False          6.1        34.0
# 4  Released  Father of the Bride Part II  False          5.7       173.0
#
# [5 rows x 21 columns]

# %%
#rename genres of each movies
regex = re.compile(r": '(.*?)'")
df['genres'] = df['genres'].apply(lambda x: ", ".join(regex.findall(x)))
df
# Out:
#        adult    budget                      genres      id    imdb_id  \
# 0      False  30000000   Animation, Comedy, Family     862  tt0114709
# 1      False  65000000  Adventure, Fantasy, Family    8844  tt0113497
# 2      False         0             Romance, Comedy   15602  tt0113228
# 3      False  16000000      Comedy, Drama, Romance   31357  tt0114885
# 4      False         0                      Comedy   11862  tt0113041
# ...      ...       ...                         ...     ...        ...
# 45460  False         0      Drama, Action, Romance   30840  tt0102797
# 45462  False         0                       Drama  111109  tt2028550
# 45463  False         0     Action, Drama, Thriller   67758  tt0303758
# 45464  False         0                              227506  tt0008536
# 45465  False         0                              461257  tt6980792
#
#       original_language               original_title  \
# 0                    en                    Toy Story
# 1                    en                      Jumanji
# 2                    en             Grumpier Old Men
# 3                    en            Waiting to Exhale
# 4                    en  Father of the Bride Part II
# ...                 ...                          ...
# 45460                en                   Robin Hood
# 45462                tl          Siglo ng Pagluluwal
# 45463                en                     Betrayal
# 45464                en          Satana likuyushchiy
# 45465                en                     Queerama
#
#                                                 overview popularity  \
# 0      Led by Woody, Andy's toys live happily in his ...    21.9469
# 1      When siblings Judy and Peter discover an encha...    17.0155
# 2      A family wedding reignites the ancient feud be...    11.7129
# 3      Cheated on, mistreated and stepped on, the wom...    3.85949
# 4      Just when George Banks has recovered from his ...    8.38752
# ...                                                  ...        ...
# 45460  Yet another version of the classic epic, with ...   5.683753
# 45462  An artist struggles to finish his work while a...   0.178241
# 45463  When one of her hits goes wrong, a professiona...   0.903007
# 45464  In a small town live two brothers, one a minis...   0.003503
# 45465  50 years after decriminalisation of homosexual...   0.163015
#
#                             poster_path  ...  \
# 0      /rhIRbceoE9lR4veEXuwCC2wARtG.jpg  ...
# 1      /vzmL6fP7aPKNKPRTFnZmiUfciyV.jpg  ...
# 2      /6ksm1sjKMFLbO7UY2i6G1ju9SML.jpg  ...
# 3      /16XOMpEaLWkrcPqSQqhTmeJuqQl.jpg  ...
# 4      /e64sOI48hQXyru7naBFyssKFxVd.jpg  ...
# ...                                 ...  ...
# 45460  /fQC46NglNiEMZBv5XHoyLuOWoN5.jpg  ...
# 45462  /xZkmxsNmYXJbKVsTRLLx3pqGHx7.jpg  ...
# 45463  /d5bX92nDsISNhu3ZT69uHwmfCGw.jpg  ...
# 45464  /aorBPO7ak8e8iJKT5OcqYxU3jlK.jpg  ...
# 45465  /s5UkZt6NTsrS7ZF0Rh8nzupRlIU.jpg  ...
#
#                                     production_countries release_date  \
# 0      [{'iso_3166_1': 'US', 'name': 'United States o...   1995-10-30
# 1      [{'iso_3166_1': 'US', 'name': 'United States o...   1995-12-15
# 2      [{'iso_3166_1': 'US', 'name': 'United States o...   1995-12-22
# 3      [{'iso_3166_1': 'US', 'name': 'United States o...   1995-12-22
# 4      [{'iso_3166_1': 'US', 'name': 'United States o...   1995-02-10
# ...                                                  ...          ...
# 45460  [{'iso_3166_1': 'CA', 'name': 'Canada'}, {'iso...   1991-05-13
# 45462      [{'iso_3166_1': 'PH', 'name': 'Philippines'}]   2011-11-17
# 45463  [{'iso_3166_1': 'US', 'name': 'United States o...   2003-08-01
# 45464           [{'iso_3166_1': 'RU', 'name': 'Russia'}]   1917-10-21
# 45465   [{'iso_3166_1': 'GB', 'name': 'United Kingdom'}]   2017-06-09
#
#            revenue  runtime  \
# 0      373554033.0     81.0
# 1      262797249.0    104.0
# 2              0.0    101.0
# 3       81452156.0    127.0
# 4       76578911.0    106.0
# ...            ...      ...
# 45460          0.0    104.0
# 45462          0.0    360.0
# 45463          0.0     90.0
# 45464          0.0     87.0
# 45465          0.0     75.0
#
#                                         spoken_languages    status  \
# 0               [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 1      [{'iso_639_1': 'en', 'name': 'English'}, {'iso...  Released
# 2               [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 3               [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 4               [{'iso_639_1': 'en', 'name': 'English'}]  Released
# ...                                                  ...       ...
# 45460           [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 45462                  [{'iso_639_1': 'tl', 'name': ''}]  Released
# 45463           [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 45464                                                 []  Released
# 45465           [{'iso_639_1': 'en', 'name': 'English'}]  Released
#
#                              title  video vote_average  vote_count
# 0                        Toy Story  False          7.7      5415.0
# 1                          Jumanji  False          6.9      2413.0
# 2                 Grumpier Old Men  False          6.5        92.0
# 3                Waiting to Exhale  False          6.1        34.0
# 4      Father of the Bride Part II  False          5.7       173.0
# ...                            ...    ...          ...         ...
# 45460                   Robin Hood  False          5.7        26.0
# 45462          Century of Birthing  False          9.0         3.0
# 45463                     Betrayal  False          3.8         6.0
# 45464             Satan Triumphant  False          0.0         0.0
# 45465                     Queerama  False          0.0         0.0
#
# [44035 rows x 21 columns]

# %%
#reset index
df.reset_index(drop=True)
# Out:
#        adult    budget                      genres      id    imdb_id  \
# 0      False  30000000   Animation, Comedy, Family     862  tt0114709
# 1      False  65000000  Adventure, Fantasy, Family    8844  tt0113497
# 2      False         0             Romance, Comedy   15602  tt0113228
# 3      False  16000000      Comedy, Drama, Romance   31357  tt0114885
# 4      False         0                      Comedy   11862  tt0113041
# ...      ...       ...                         ...     ...        ...
# 44030  False         0      Drama, Action, Romance   30840  tt0102797
# 44031  False         0                       Drama  111109  tt2028550
# 44032  False         0     Action, Drama, Thriller   67758  tt0303758
# 44033  False         0                              227506  tt0008536
# 44034  False         0                              461257  tt6980792
#
#       original_language               original_title  \
# 0                    en                    Toy Story
# 1                    en                      Jumanji
# 2                    en             Grumpier Old Men
# 3                    en            Waiting to Exhale
# 4                    en  Father of the Bride Part II
# ...                 ...                          ...
# 44030                en                   Robin Hood
# 44031                tl          Siglo ng Pagluluwal
# 44032                en                     Betrayal
# 44033                en          Satana likuyushchiy
# 44034                en                     Queerama
#
#                                                 overview popularity  \
# 0      Led by Woody, Andy's toys live happily in his ...    21.9469
# 1      When siblings Judy and Peter discover an encha...    17.0155
# 2      A family wedding reignites the ancient feud be...    11.7129
# 3      Cheated on, mistreated and stepped on, the wom...    3.85949
# 4      Just when George Banks has recovered from his ...    8.38752
# ...                                                  ...        ...
# 44030  Yet another version of the classic epic, with ...   5.683753
# 44031  An artist struggles to finish his work while a...   0.178241
# 44032  When one of her hits goes wrong, a professiona...   0.903007
# 44033  In a small town live two brothers, one a minis...   0.003503
# 44034  50 years after decriminalisation of homosexual...   0.163015
#
#                             poster_path  ...  \
# 0      /rhIRbceoE9lR4veEXuwCC2wARtG.jpg  ...
# 1      /vzmL6fP7aPKNKPRTFnZmiUfciyV.jpg  ...
# 2      /6ksm1sjKMFLbO7UY2i6G1ju9SML.jpg  ...
# 3      /16XOMpEaLWkrcPqSQqhTmeJuqQl.jpg  ...
# 4      /e64sOI48hQXyru7naBFyssKFxVd.jpg  ...
# ...                                 ...  ...
# 44030  /fQC46NglNiEMZBv5XHoyLuOWoN5.jpg  ...
# 44031  /xZkmxsNmYXJbKVsTRLLx3pqGHx7.jpg  ...
# 44032  /d5bX92nDsISNhu3ZT69uHwmfCGw.jpg  ...
# 44033  /aorBPO7ak8e8iJKT5OcqYxU3jlK.jpg  ...
# 44034  /s5UkZt6NTsrS7ZF0Rh8nzupRlIU.jpg  ...
#
#                                     production_countries release_date  \
# 0      [{'iso_3166_1': 'US', 'name': 'United States o...   1995-10-30
# 1      [{'iso_3166_1': 'US', 'name': 'United States o...   1995-12-15
# 2      [{'iso_3166_1': 'US', 'name': 'United States o...   1995-12-22
# 3      [{'iso_3166_1': 'US', 'name': 'United States o...   1995-12-22
# 4      [{'iso_3166_1': 'US', 'name': 'United States o...   1995-02-10
# ...                                                  ...          ...
# 44030  [{'iso_3166_1': 'CA', 'name': 'Canada'}, {'iso...   1991-05-13
# 44031      [{'iso_3166_1': 'PH', 'name': 'Philippines'}]   2011-11-17
# 44032  [{'iso_3166_1': 'US', 'name': 'United States o...   2003-08-01
# 44033           [{'iso_3166_1': 'RU', 'name': 'Russia'}]   1917-10-21
# 44034   [{'iso_3166_1': 'GB', 'name': 'United Kingdom'}]   2017-06-09
#
#            revenue  runtime  \
# 0      373554033.0     81.0
# 1      262797249.0    104.0
# 2              0.0    101.0
# 3       81452156.0    127.0
# 4       76578911.0    106.0
# ...            ...      ...
# 44030          0.0    104.0
# 44031          0.0    360.0
# 44032          0.0     90.0
# 44033          0.0     87.0
# 44034          0.0     75.0
#
#                                         spoken_languages    status  \
# 0               [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 1      [{'iso_639_1': 'en', 'name': 'English'}, {'iso...  Released
# 2               [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 3               [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 4               [{'iso_639_1': 'en', 'name': 'English'}]  Released
# ...                                                  ...       ...
# 44030           [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 44031                  [{'iso_639_1': 'tl', 'name': ''}]  Released
# 44032           [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 44033                                                 []  Released
# 44034           [{'iso_639_1': 'en', 'name': 'English'}]  Released
#
#                              title  video vote_average  vote_count
# 0                        Toy Story  False          7.7      5415.0
# 1                          Jumanji  False          6.9      2413.0
# 2                 Grumpier Old Men  False          6.5        92.0
# 3                Waiting to Exhale  False          6.1        34.0
# 4      Father of the Bride Part II  False          5.7       173.0
# ...                            ...    ...          ...         ...
# 44030                   Robin Hood  False          5.7        26.0
# 44031          Century of Birthing  False          9.0         3.0
# 44032                     Betrayal  False          3.8         6.0
# 44033             Satan Triumphant  False          0.0         0.0
# 44034                     Queerama  False          0.0         0.0
#
# [44035 rows x 21 columns]

# %%
#rename production names and production countries
df['production_companies'] = df['production_companies'].apply(lambda x: ', '.join(regex.findall(x)))
df['production_countries'] = df['production_countries'].apply(lambda x: ', '.join(regex.findall(x)))

# %%
#rename spoken langs
df['spoken_languages'] = df['spoken_languages'].apply(lambda x: ', '.join(regex.findall(x)))

# %%
#check
df
# Out:
#        adult    budget                      genres      id    imdb_id  \
# 0      False  30000000   Animation, Comedy, Family     862  tt0114709
# 1      False  65000000  Adventure, Fantasy, Family    8844  tt0113497
# 2      False         0             Romance, Comedy   15602  tt0113228
# 3      False  16000000      Comedy, Drama, Romance   31357  tt0114885
# 4      False         0                      Comedy   11862  tt0113041
# ...      ...       ...                         ...     ...        ...
# 45460  False         0      Drama, Action, Romance   30840  tt0102797
# 45462  False         0                       Drama  111109  tt2028550
# 45463  False         0     Action, Drama, Thriller   67758  tt0303758
# 45464  False         0                              227506  tt0008536
# 45465  False         0                              461257  tt6980792
#
#       original_language               original_title  \
# 0                    en                    Toy Story
# 1                    en                      Jumanji
# 2                    en             Grumpier Old Men
# 3                    en            Waiting to Exhale
# 4                    en  Father of the Bride Part II
# ...                 ...                          ...
# 45460                en                   Robin Hood
# 45462                tl          Siglo ng Pagluluwal
# 45463                en                     Betrayal
# 45464                en          Satana likuyushchiy
# 45465                en                     Queerama
#
#                                                 overview popularity  \
# 0      Led by Woody, Andy's toys live happily in his ...    21.9469
# 1      When siblings Judy and Peter discover an encha...    17.0155
# 2      A family wedding reignites the ancient feud be...    11.7129
# 3      Cheated on, mistreated and stepped on, the wom...    3.85949
# 4      Just when George Banks has recovered from his ...    8.38752
# ...                                                  ...        ...
# 45460  Yet another version of the classic epic, with ...   5.683753
# 45462  An artist struggles to finish his work while a...   0.178241
# 45463  When one of her hits goes wrong, a professiona...   0.903007
# 45464  In a small town live two brothers, one a minis...   0.003503
# 45465  50 years after decriminalisation of homosexual...   0.163015
#
#                             poster_path  ...  \
# 0      /rhIRbceoE9lR4veEXuwCC2wARtG.jpg  ...
# 1      /vzmL6fP7aPKNKPRTFnZmiUfciyV.jpg  ...
# 2      /6ksm1sjKMFLbO7UY2i6G1ju9SML.jpg  ...
# 3      /16XOMpEaLWkrcPqSQqhTmeJuqQl.jpg  ...
# 4      /e64sOI48hQXyru7naBFyssKFxVd.jpg  ...
# ...                                 ...  ...
# 45460  /fQC46NglNiEMZBv5XHoyLuOWoN5.jpg  ...
# 45462  /xZkmxsNmYXJbKVsTRLLx3pqGHx7.jpg  ...
# 45463  /d5bX92nDsISNhu3ZT69uHwmfCGw.jpg  ...
# 45464  /aorBPO7ak8e8iJKT5OcqYxU3jlK.jpg  ...
# 45465  /s5UkZt6NTsrS7ZF0Rh8nzupRlIU.jpg  ...
#
#                                     production_countries release_date  \
# 0                           US, United States of America   1995-10-30
# 1                           US, United States of America   1995-12-15
# 2                           US, United States of America   1995-12-22
# 3                           US, United States of America   1995-12-22
# 4                           US, United States of America   1995-02-10
# ...                                                  ...          ...
# 45460  CA, Canada, DE, Germany, GB, United Kingdom, U...   1991-05-13
# 45462                                    PH, Philippines   2011-11-17
# 45463                       US, United States of America   2003-08-01
# 45464                                         RU, Russia   1917-10-21
# 45465                                 GB, United Kingdom   2017-06-09
#
#            revenue  runtime           spoken_languages    status  \
# 0      373554033.0     81.0                en, English  Released
# 1      262797249.0    104.0  en, English, fr, Français  Released
# 2              0.0    101.0                en, English  Released
# 3       81452156.0    127.0                en, English  Released
# 4       76578911.0    106.0                en, English  Released
# ...            ...      ...                        ...       ...
# 45460          0.0    104.0                en, English  Released
# 45462          0.0    360.0                       tl,   Released
# 45463          0.0     90.0                en, English  Released
# 45464          0.0     87.0                             Released
# 45465          0.0     75.0                en, English  Released
#
#                              title  video vote_average  vote_count
# 0                        Toy Story  False          7.7      5415.0
# 1                          Jumanji  False          6.9      2413.0
# 2                 Grumpier Old Men  False          6.5        92.0
# 3                Waiting to Exhale  False          6.1        34.0
# 4      Father of the Bride Part II  False          5.7       173.0
# ...                            ...    ...          ...         ...
# 45460                   Robin Hood  False          5.7        26.0
# 45462          Century of Birthing  False          9.0         3.0
# 45463                     Betrayal  False          3.8         6.0
# 45464             Satan Triumphant  False          0.0         0.0
# 45465                     Queerama  False          0.0         0.0
#
# [44035 rows x 21 columns]

# %%
df.loc[df['genres'] == 'Science Fiction']
# Out:
#        adult    budget           genres      id    imdb_id original_language  \
# 170    False  90000000  Science Fiction    9482  tt0113492                en
# 663    False   9000000  Science Fiction    8069  tt0062711                en
# 1638   False         0  Science Fiction  438108  tt0128755                en
# 1684   False  75000000  Science Fiction   10153  tt0120184                en
# 2583   False         0  Science Fiction   67067  tt0120554                en
# ...      ...       ...              ...     ...        ...               ...
# 45069  False         0  Science Fiction  401427  tt5769236                en
# 45075  False         0  Science Fiction  314238  tt1899268                en
# 45183  False         0  Science Fiction  429101  tt4881364                en
# 45367  False         0  Science Fiction  449696  tt0105492                en
# 45459  False         0  Science Fiction  222848  tt0112613                en
#
#                           original_title  \
# 170                          Judge Dredd
# 663                           Barbarella
# 1638                        Time Tracers
# 1684                              Sphere
# 2583                             Zone 39
# ...                                  ...
# 45069                              Elegy
# 45075                               Plug
# 45183                        Anti Matter
# 45367  The Stranger: Summoned by Shadows
# 45459                    Caged Heat 3000
#
#                                                 overview popularity  \
# 170    In a dystopian future, Dredd, the most famous ...    8.18481
# 663    In the far future, a highly sexual woman is ta...    14.3042
# 1638   When the discovery of a five-thousand year old...   0.001247
# 1684   The OSSA discovers a spacecraft thought to be ...    7.12474
# 2583   In a time of misery and fear two enemies come ...   0.087065
# ...                                                  ...        ...
# 45069  In the future, nature has evolved to destroy h...   0.016472
# 45075  On a post-apocalyptic Earth, Leila Dawn (Natal...   0.495194
# 45183  Anti Matter (AKA Worm) is a sci-fi noir take o...    4.57264
# 45367  Wearied by his travels through time and space ...    3.5e-05
# 45459  It's the year 3000 AD. The world's most danger...   0.661558
#
#                             poster_path  ...          production_countries  \
# 170    /r17S4XlQ3Jq5U1KRovFUwU8P4aG.jpg  ...  US, United States of America
# 663    /fntrx2BzHkdSNFe5jkgP09XsK7g.jpg  ...  US, United States of America
# 1638   /tU52aw3QwOV2a7zD4T659iAKGwr.jpg  ...  US, United States of America
# 1684   /jrjzPjKnpJq99GPePKf64k7Fzqh.jpg  ...  US, United States of America
# 2583   /5VMuNPqKhc0gEH0HyVxgjUXAgs9.jpg  ...                 AU, Australia
# ...                                 ...  ...                           ...
# 45069  /wcq1a3heYgd8TOuctso0c3Pk4wx.jpg  ...
# 45075  /3Sa0PaFHLQWe3q60sNOXCb4RkbB.jpg  ...  US, United States of America
# 45183  /fQq24L8ioUy3cHWPo8LheguicxF.jpg  ...            GB, United Kingdom
# 45367  /aWnsJwOZB1ARhavpnh0O5ae8qWn.jpg  ...            GB, United Kingdom
# 45459  /4lF9LH0b0Z1X94xGK9IOzqEW6k1.jpg  ...  US, United States of America
#
#       release_date      revenue  runtime  spoken_languages    status  \
# 170     1995-06-30  113493481.0     96.0       en, English  Released
# 663     1968-10-10    2500000.0     98.0       en, English  Released
# 1638    1997-12-16          0.0    101.0       en, English  Released
# 1684    1998-02-13   13100000.0    134.0       en, English  Released
# 2583    1996-05-04          0.0     95.0       en, English  Released
# ...            ...          ...      ...               ...       ...
# 45069   2014-09-10          0.0     16.0                    Released
# 45075   2014-10-25          0.0     16.0       en, English  Released
# 45183   2016-01-01          0.0    109.0                    Released
# 45367   1991-01-01          0.0     34.0       en, English  Released
# 45459   1995-01-01          0.0     85.0       en, English  Released
#
#                                    title  video vote_average  vote_count
# 170                          Judge Dredd  False          5.4       643.0
# 663                           Barbarella  False          5.7       149.0
# 1638                        Time Tracers  False          0.0         0.0
# 1684                              Sphere  False          5.8       483.0
# 2583                             Zone 39  False          5.0         2.0
# ...                                  ...    ...          ...         ...
# 45069                              Elegy  False          0.0         0.0
# 45075                               Plug  False          5.6         5.0
# 45183                        Anti Matter  False          6.7        22.0
# 45367  The Stranger: Summoned by Shadows  False          0.0         0.0
# 45459                    Caged Heat 3000  False          3.5         1.0
#
# [193 rows x 21 columns]

# %%
#check whether renamed columns are null or not
df.isna().sum()
# Out:
# adult                   0
# budget                  0
# genres                  0
# id                      0
# imdb_id                 0
# original_language       0
# original_title          0
# overview                0
# popularity              0
# poster_path             0
# production_companies    0
# production_countries    0
# release_date            0
# revenue                 0
# runtime                 0
# spoken_languages        0
# status                  0
# title                   0
# video                   0
# vote_average            0
# vote_count              0
# dtype: int64

# %%
#Dropping rows that don't contain type
df.drop(df.loc[df['genres'] == ""].index, inplace=True)

# %%
df
# Out:
#        adult    budget                      genres      id    imdb_id  \
# 0      False  30000000   Animation, Comedy, Family     862  tt0114709
# 1      False  65000000  Adventure, Fantasy, Family    8844  tt0113497
# 2      False         0             Romance, Comedy   15602  tt0113228
# 3      False  16000000      Comedy, Drama, Romance   31357  tt0114885
# 4      False         0                      Comedy   11862  tt0113041
# ...      ...       ...                         ...     ...        ...
# 45458  False         0                      Horror  289923  tt0252966
# 45459  False         0             Science Fiction  222848  tt0112613
# 45460  False         0      Drama, Action, Romance   30840  tt0102797
# 45462  False         0                       Drama  111109  tt2028550
# 45463  False         0     Action, Drama, Thriller   67758  tt0303758
#
#       original_language               original_title  \
# 0                    en                    Toy Story
# 1                    en                      Jumanji
# 2                    en             Grumpier Old Men
# 3                    en            Waiting to Exhale
# 4                    en  Father of the Bride Part II
# ...                 ...                          ...
# 45458                en          The Burkittsville 7
# 45459                en              Caged Heat 3000
# 45460                en                   Robin Hood
# 45462                tl          Siglo ng Pagluluwal
# 45463                en                     Betrayal
#
#                                                 overview popularity  \
# 0      Led by Woody, Andy's toys live happily in his ...    21.9469
# 1      When siblings Judy and Peter discover an encha...    17.0155
# 2      A family wedding reignites the ancient feud be...    11.7129
# 3      Cheated on, mistreated and stepped on, the wom...    3.85949
# 4      Just when George Banks has recovered from his ...    8.38752
# ...                                                  ...        ...
# 45458  A film archivist revisits the story of Rustin ...    0.38645
# 45459  It's the year 3000 AD. The world's most danger...   0.661558
# 45460  Yet another version of the classic epic, with ...   5.683753
# 45462  An artist struggles to finish his work while a...   0.178241
# 45463  When one of her hits goes wrong, a professiona...   0.903007
#
#                             poster_path  ...  \
# 0      /rhIRbceoE9lR4veEXuwCC2wARtG.jpg  ...
# 1      /vzmL6fP7aPKNKPRTFnZmiUfciyV.jpg  ...
# 2      /6ksm1sjKMFLbO7UY2i6G1ju9SML.jpg  ...
# 3      /16XOMpEaLWkrcPqSQqhTmeJuqQl.jpg  ...
# 4      /e64sOI48hQXyru7naBFyssKFxVd.jpg  ...
# ...                                 ...  ...
# 45458  /lXtoHVdej6kS1Dc7KAhw05sMos9.jpg  ...
# 45459  /4lF9LH0b0Z1X94xGK9IOzqEW6k1.jpg  ...
# 45460  /fQC46NglNiEMZBv5XHoyLuOWoN5.jpg  ...
# 45462  /xZkmxsNmYXJbKVsTRLLx3pqGHx7.jpg  ...
# 45463  /d5bX92nDsISNhu3ZT69uHwmfCGw.jpg  ...
#
#                                     production_countries release_date  \
# 0                           US, United States of America   1995-10-30
# 1                           US, United States of America   1995-12-15
# 2                           US, United States of America   1995-12-22
# 3                           US, United States of America   1995-12-22
# 4                           US, United States of America   1995-02-10
# ...                                                  ...          ...
# 45458                       US, United States of America   2000-10-03
# 45459                       US, United States of America   1995-01-01
# 45460  CA, Canada, DE, Germany, GB, United Kingdom, U...   1991-05-13
# 45462                                    PH, Philippines   2011-11-17
# 45463                       US, United States of America   2003-08-01
#
#            revenue  runtime           spoken_languages    status  \
# 0      373554033.0     81.0                en, English  Released
# 1      262797249.0    104.0  en, English, fr, Français  Released
# 2              0.0    101.0                en, English  Released
# 3       81452156.0    127.0                en, English  Released
# 4       76578911.0    106.0                en, English  Released
# ...            ...      ...                        ...       ...
# 45458          0.0     30.0                en, English  Released
# 45459          0.0     85.0                en, English  Released
# 45460          0.0    104.0                en, English  Released
# 45462          0.0    360.0                       tl,   Released
# 45463          0.0     90.0                en, English  Released
#
#                              title  video vote_average  vote_count
# 0                        Toy Story  False          7.7      5415.0
# 1                          Jumanji  False          6.9      2413.0
# 2                 Grumpier Old Men  False          6.5        92.0
# 3                Waiting to Exhale  False          6.1        34.0
# 4      Father of the Bride Part II  False          5.7       173.0
# ...                            ...    ...          ...         ...
# 45458          The Burkittsville 7  False          7.0         1.0
# 45459              Caged Heat 3000  False          3.5         1.0
# 45460                   Robin Hood  False          5.7        26.0
# 45462          Century of Birthing  False          9.0         3.0
# 45463                     Betrayal  False          3.8         6.0
#
# [42069 rows x 21 columns]

# %%
# #Change movies that have multiple genres into only one genre
# df.loc[df['genres'].str.len() > 12, 'genres'] = "MultipleType"

# %%
df.columns
# Out:
# Index(['adult', 'budget', 'genres', 'id', 'imdb_id', 'original_language',
#        'original_title', 'overview', 'popularity', 'poster_path',
#        'production_companies', 'production_countries', 'release_date',
#        'revenue', 'runtime', 'spoken_languages', 'status', 'title', 'video',
#        'vote_average', 'vote_count'],
#       dtype='object')

# %%
# mapping adult movies
df['adult'] = df['adult'].astype('string')
df['adult'] = df['adult'].map({"True" : "Adult", "False":"Non-Adult"})

# %%
df['title'] = df['title'].drop_duplicates()

# %%
df.drop(df.loc[df['original_language'] != 'en'].index, inplace=True)

# %%
df.shape[0]
# Out:
# 30329

# %%
df.drop(df.loc[df['title'].isnull()].index, inplace=True)

# %%
df.reset_index()
# Out:
#        index      adult    budget                      genres      id  \
# 0          0  Non-Adult  30000000   Animation, Comedy, Family     862
# 1          1  Non-Adult  65000000  Adventure, Fantasy, Family    8844
# 2          2  Non-Adult         0             Romance, Comedy   15602
# 3          3  Non-Adult  16000000      Comedy, Drama, Romance   31357
# 4          4  Non-Adult         0                      Comedy   11862
# ...      ...        ...       ...                         ...     ...
# 28288  45452  Non-Adult         0                 Documentary  276895
# 28289  45456  Non-Adult         0   Horror, Mystery, Thriller   84419
# 28290  45457  Non-Adult         0             Mystery, Horror  390959
# 28291  45458  Non-Adult         0                      Horror  289923
# 28292  45459  Non-Adult         0             Science Fiction  222848
#
#          imdb_id original_language               original_title  \
# 0      tt0114709                en                    Toy Story
# 1      tt0113497                en                      Jumanji
# 2      tt0113228                en             Grumpier Old Men
# 3      tt0114885                en            Waiting to Exhale
# 4      tt0113041                en  Father of the Bride Part II
# ...          ...               ...                          ...
# 28288  tt3054038                en                  Deep Hearts
# 28289  tt0038621                en             House of Horrors
# 28290  tt0265736                en    Shadow of the Blair Witch
# 28291  tt0252966                en          The Burkittsville 7
# 28292  tt0112613                en              Caged Heat 3000
#
#                                                 overview popularity  ...  \
# 0      Led by Woody, Andy's toys live happily in his ...    21.9469  ...
# 1      When siblings Judy and Peter discover an encha...    17.0155  ...
# 2      A family wedding reignites the ancient feud be...    11.7129  ...
# 3      Cheated on, mistreated and stepped on, the wom...    3.85949  ...
# 4      Just when George Banks has recovered from his ...    8.38752  ...
# ...                                                  ...        ...  ...
# 28288  Deep Hearts is a film about the Bororo Fulani,...   0.011025  ...
# 28289  An unsuccessful sculptor saves a madman named ...   0.222814  ...
# 28290  In this true-crime documentary, we delve into ...   0.076061  ...
# 28291  A film archivist revisits the story of Rustin ...    0.38645  ...
# 28292  It's the year 3000 AD. The world's most danger...   0.661558  ...
#
#                production_countries release_date      revenue runtime  \
# 0      US, United States of America   1995-10-30  373554033.0    81.0
# 1      US, United States of America   1995-12-15  262797249.0   104.0
# 2      US, United States of America   1995-12-22          0.0   101.0
# 3      US, United States of America   1995-12-22   81452156.0   127.0
# 4      US, United States of America   1995-02-10   76578911.0   106.0
# ...                             ...          ...          ...     ...
# 28288  US, United States of America   1981-01-01          0.0    58.0
# 28289  US, United States of America   1946-03-29          0.0    65.0
# 28290                                 2000-10-22          0.0    45.0
# 28291  US, United States of America   2000-10-03          0.0    30.0
# 28292  US, United States of America   1995-01-01          0.0    85.0
#
#                 spoken_languages    status                        title  \
# 0                    en, English  Released                    Toy Story
# 1      en, English, fr, Français  Released                      Jumanji
# 2                    en, English  Released             Grumpier Old Men
# 3                    en, English  Released            Waiting to Exhale
# 4                    en, English  Released  Father of the Bride Part II
# ...                          ...       ...                          ...
# 28288  ff, Fulfulde, en, English  Released                  Deep Hearts
# 28289                en, English  Released             House of Horrors
# 28290                en, English  Released    Shadow of the Blair Witch
# 28291                en, English  Released          The Burkittsville 7
# 28292                en, English  Released              Caged Heat 3000
#
#        video vote_average vote_count
# 0      False          7.7     5415.0
# 1      False          6.9     2413.0
# 2      False          6.5       92.0
# 3      False          6.1       34.0
# 4      False          5.7      173.0
# ...      ...          ...        ...
# 28288  False          0.0        0.0
# 28289  False          6.3        8.0
# 28290  False          7.0        2.0
# 28291  False          7.0        1.0
# 28292  False          3.5        1.0
#
# [28293 rows x 22 columns]

# %%
df['runtime'] = pd.cut(df['runtime'], bins=5, labels=['Short', 'Short-Medium', 'Medium', "Medium-Long", 'Long'])

# %%
df['popularity'] = df['popularity'].astype('float64')

# %%
df['popularity'] = pd.cut(df['popularity'], bins=3, labels=['Low', 'Medium', 'High'])

# %%
df['vote_average'] = pd.cut(df['vote_average'], bins=3, labels=['Low', 'Medium', 'High'])
df['vote_count'] = pd.cut(df['vote_count'], bins=3, labels=['Low', "Medium", 'High'])

# %%
df.reset_index(inplace=True)

# %% [markdown]
# # EDA

# %%
###Visualization
import matplotlib.pyplot as plt

# def similarMovies(movieName):
#     movie_sim = df.loc[df['title'] == movieName]
#     tmp = movie_sim['genres'].values
#     a = tmp[0].split(',')
#     return a

#selecting jumanji movie to compare which movies are similar?
similar_jumanji = df.loc[df['title'] == 'Jumanji']
s = similar_jumanji['genres'][1].split(',')
print(s)
# Out:
# ['Adventure', ' Fantasy', ' Family']

# %%
# similarMovie = df.loc[(df['genres'] == s[0]) | (df['genres'] == s[1]) | (df['genres'] == s[2])]
# plt.figure(figsize=(30, 10))
# ax = sns.barplot(data=similarMovie.nlargest(15,'vote_average'), x='title', y='vote_average', palette="gnuplot2")
# ax.set_xticklabels(ax.get_xticklabels(), fontsize=20, rotation=20, ha="right")
# ax.set_ylabel('Vote Average', fontsize=20)

# %%
#count amount of total genres
def countgenre(data):
  dicts = {}
  for x in data:
    for y in x:
      if y not in dicts.keys():
        dicts[y] = 0
      dicts[y] = int(dicts[y])+1
  return dicts

# %%
GENRE = df['genres'].str.split(",")
GENRE = countgenre(GENRE)

# %%
colGenre = pd.DataFrame(data=GENRE.keys(),columns=['genres'])
rowGenre = pd.DataFrame(data=GENRE.values(),columns=['count_genre'])
colGenre.reset_index(inplace=True)
rowGenre.reset_index(inplace=True)
Genre = pd.merge(colGenre,rowGenre,on=['index','index'])
# create count genres dataframe for checking value count each genres

# %%
### mostly movies genre
plt.figure(figsize=(30, 10))
ax = sns.barplot(data=Genre.nlargest(32,'count_genre'), x='genres', y='count_genre' )
ax.set_xticklabels(ax.get_xticklabels(), fontsize=20, rotation=40, ha="right")
ax.set_ylabel('Count Genres', fontsize=20)
# Out:
# Text(0, 0.5, 'Count Genres')

# %%
# plt.figure(figsize=(10,10))
# sns.distplot(df['vote_average']);
#check the voting period

# %%
data_task = df.original_language.value_counts().head(20)
data_task = pd.DataFrame({"Language" : data_task.index, "Count" : data_task}).reset_index(drop = True)
data_task
# Out:
#   Language  Count
# 0       en  28293

# %%
# #check other languages without eng
# plt.figure(figsize = (20, 10))
# plt.title("Number of movies in languages other than english", fontsize = 27, fontweight = 'bold')

# sns.barplot(x = data_task.loc[(data_task.Language != 'en'), 'Language'] ,
#             y = data_task.loc[(data_task.Language != 'en'), 'Count'],
#            palette = sns.color_palette("BuGn_r", 25))

# plt.xlabel('Language', fontsize = 20)
# plt.ylabel('Number Of Movies', fontsize = 20)
# plt.xticks(fontsize = 17)
# plt.yticks(fontsize = 13)

# %%
#create new dataframe for checking wether how many adult in column adult
check_adult = df.adult.value_counts()
adult_df = pd.DataFrame({"adult" : check_adult.index, "adult_count" : check_adult}).reset_index(drop = True)
adult_df
# Out:
#        adult  adult_count
# 0  Non-Adult        28289
# 1      Adult            4

# %%
# adult_df['adult'] = adult_df['adult'].apply(lambda x: 'teenager' if x == 'False' else 'Adult')
adult_df
# Out:
#        adult  adult_count
# 0  Non-Adult        28289
# 1      Adult            4

# %%
plt.figure(figsize = (5, 5))
sns.barplot(data=adult_df, x='adult', y='adult_count',color="#222")
plt.ylabel("Adult and Teenager Count")
plt.xlabel("<3")
plt.title("Adult & Teenager");

# %% [markdown]
# # Feature Engineering
# ## What feature should I decide to give the model to train itself to be predicting a similarity movie?
#     1. Genre
#     2. Overview
#     4. imdb score

# %%
from sklearn.feature_extraction.text import TfidfVectorizer, CountVectorizer
from sklearn.metrics.pairwise import cosine_similarity, linear_kernel

# %% [markdown]
# ## Drop unnecessary columns

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 28293 entries, 0 to 28292
# Data columns (total 22 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   index                 28293 non-null  int64
#  1   adult                 28293 non-null  object
#  2   budget                28293 non-null  object
#  3   genres                28293 non-null  object
#  4   id                    28293 non-null  object
#  5   imdb_id               28293 non-null  object
#  6   original_language     28293 non-null  object
#  7   original_title        28293 non-null  object
#  8   overview              28293 non-null  object
#  9   popularity            28293 non-null  category
#  10  poster_path           28293 non-null  object
#  11  production_companies  28293 non-null  object
#  12  production_countries  28293 non-null  object
#  13  release_date          28293 non-null  object
#  14  revenue               28293 non-null  float64
#  15  runtime               28293 non-null  category
#  16  spoken_languages      28293 non-null  object
#  17  status                28293 non-null  object
#  18  title                 28293 non-null  object
#  19  video                 28293 non-null  object
#  20  vote_average          28293 non-null  category
#  21  vote_count            28293 non-null  category
# dtypes: category(4), float64(1), int64(1), object(16)
# memory usage: 4.0+ MB

# %% [markdown]
# ### Combining features

# %%
df.drop(columns=['imdb_id', 'id', 'poster_path', 'production_countries', 'revenue', 'release_date', 'status', 'title', 'video', 'budget'], axis=1)
# Out:
#        index      adult                      genres original_language  \
# 0          0  Non-Adult   Animation, Comedy, Family                en
# 1          1  Non-Adult  Adventure, Fantasy, Family                en
# 2          2  Non-Adult             Romance, Comedy                en
# 3          3  Non-Adult      Comedy, Drama, Romance                en
# 4          4  Non-Adult                      Comedy                en
# ...      ...        ...                         ...               ...
# 28288  45452  Non-Adult                 Documentary                en
# 28289  45456  Non-Adult   Horror, Mystery, Thriller                en
# 28290  45457  Non-Adult             Mystery, Horror                en
# 28291  45458  Non-Adult                      Horror                en
# 28292  45459  Non-Adult             Science Fiction                en
#
#                     original_title  \
# 0                        Toy Story
# 1                          Jumanji
# 2                 Grumpier Old Men
# 3                Waiting to Exhale
# 4      Father of the Bride Part II
# ...                            ...
# 28288                  Deep Hearts
# 28289             House of Horrors
# 28290    Shadow of the Blair Witch
# 28291          The Burkittsville 7
# 28292              Caged Heat 3000
#
#                                                 overview popularity  \
# 0      Led by Woody, Andy's toys live happily in his ...        Low
# 1      When siblings Judy and Peter discover an encha...        Low
# 2      A family wedding reignites the ancient feud be...        Low
# 3      Cheated on, mistreated and stepped on, the wom...        Low
# 4      Just when George Banks has recovered from his ...        Low
# ...                                                  ...        ...
# 28288  Deep Hearts is a film about the Bororo Fulani,...        Low
# 28289  An unsuccessful sculptor saves a madman named ...        Low
# 28290  In this true-crime documentary, we delve into ...        Low
# 28291  A film archivist revisits the story of Rustin ...        Low
# 28292  It's the year 3000 AD. The world's most danger...        Low
#
#                                     production_companies runtime  \
# 0                                Pixar Animation Studios   Short
# 1      TriStar Pictures, Teitler Film, Interscope Com...   Short
# 2                           Warner Bros., Lancaster Gate   Short
# 3                 Twentieth Century Fox Film Corporation   Short
# 4             Sandollar Productions, Touchstone Pictures   Short
# ...                                                  ...     ...
# 28288                                                      Short
# 28289                                 Universal Pictures   Short
# 28290                                                      Short
# 28291     Neptune Salad Entertainment, Pirie Productions   Short
# 28292                              Concorde-New Horizons   Short
#
#                 spoken_languages vote_average vote_count
# 0                    en, English         High     Medium
# 1      en, English, fr, Français         High        Low
# 2                    en, English       Medium        Low
# 3                    en, English       Medium        Low
# 4                    en, English       Medium        Low
# ...                          ...          ...        ...
# 28288  ff, Fulfulde, en, English          Low        Low
# 28289                en, English       Medium        Low
# 28290                en, English         High        Low
# 28291                en, English         High        Low
# 28292                en, English       Medium        Low
#
# [28293 rows x 12 columns]

# %%
df.shape[0]
# Out:
# 28293

# %%
def combining_features(row):
    return row['genres'] + " " + row['adult'] + " " + row['original_title'] + " " + row['production_companies'] + " " + row['original_language'] + " " + row['runtime'] + " " + row['overview'] + " " + row['popularity'] + " " + row['vote_average'] + ' ' + row['vote_count']

# %%
df['combining_features'] = df.apply(combining_features, axis=1)

# %% [markdown]
# # Modeling
# ## Decide by time it spends to train
#     We have got 4 choices which are
#         1. CountVectorizer with linear_kernel
#         2. CountVectorizer with Cosine_similarity
#         3. TfidfVectorizer with linear_kernel
#         4. TfidfVectorizer with cosine_similarity

# %% [markdown]
# ## Dummy data to evaluate model

# %%
dummy_data = 'Jumanji'

# %%
def get_index(title):
    return df.loc[df['title'] == title].index.values[0]

# %%
dummy_index = get_index(dummy_data)
dummy_index
# Out:
# 1

# %% [markdown]
# ### CountVectorizer with Linear_Kernel

# %%
vector = CountVectorizer().fit_transform(df['combining_features'])

# %%
def get_title(index):
    return df.loc[df.index == index]['title'].values[0]

# %%
item_similarity = linear_kernel(vector)
item_similarity = list(enumerate(item_similarity[dummy_index]))

# %%
sorted_similar_movies = sorted(item_similarity, key=lambda x: x[1], reverse=True)
for j in range(1, 6):
    print(get_title(item_similarity[j][0]), sorted_similar_movies[j][0], df.loc[df.index == sorted_similar_movies[j][0]]['genres'].values[0])
# Out:
# Jumanji 2993 Action, Drama, Adventure
# Grumpier Old Men 15669 Fantasy, Adventure
# Waiting to Exhale 25699 Drama
# Father of the Bride Part II 10455 Action, Western
# Heat 13859 Horror

# %% [markdown]
# ### CountVectorizer With Cosine_Similarity

# %%
item_similarity = cosine_similarity(vector)

# %%
# vector = CountVectorizer().fit_transform(df['genres'])
item_similarity = list(enumerate(item_similarity[dummy_index]))
sorted_similar_movies = sorted(item_similarity, key=lambda x:x[1], reverse=True)
for j in range(1, 6):
    print(get_title(index=sorted_similar_movies[j][0]), sorted_similar_movies[j][1], df.loc[df.index == sorted_similar_movies[j][0]]['genres'].values[0])
# Out:
# Table No. 21 0.5168943500406085 Adventure, Thriller
# Are You Scared 2 0.46942943463037434 Action, Adventure, Horror
# Ashens and the Quest for the Gamechild 0.4692769977260045 Comedy, Adventure
# The Long and the Short and the Tall 0.46833182657973405 War, Drama
# Beta Test 0.45832959837804316 Thriller, Action, Science Fiction

# %% [markdown]
# ### TfidfVectorizer with Linear_Kernel

# %%
vector = TfidfVectorizer(stop_words='english').fit_transform(df['combining_features'])

# %%
item_similarity = linear_kernel(vector)

# %%
item_similarity = list(enumerate(item_similarity[dummy_index]))
sorted_similar_movies = sorted(item_similarity, key=lambda x:x[1], reverse=True)
for j in range(1, 6):
    print(get_title(index=sorted_similar_movies[j][0]), sorted_similar_movies[j][1], df.loc[df.index == sorted_similar_movies[j][0]]['genres'].values[0])
# Out:
# Table No. 21 0.20405213892932442 Adventure, Thriller
# Big Game 0.17079935777554936 Action, Drama, Thriller
# Snowed Under 0.1669783054332188 Comedy
# The Mend 0.165917669815596 Comedy
# The Dark Angel 0.15461056547280339 Romance, Drama

# %% [markdown]
# ### TfidfVectorizer with Cosine_similarity

# %%
# vector = TfidfVectorizer(stop_words='english').fit_transform(df['genres'])
item_similarity = cosine_similarity(vector)

# %%
item_similarity = list(enumerate(item_similarity[dummy_index]))
sorted_similar_movies = sorted(item_similarity, key=lambda x:x[1], reverse=True)
for j in range(1, 6):
    print(get_title(index=sorted_similar_movies[j][0]), sorted_similar_movies[j][1], df.loc[df.index == sorted_similar_movies[j][0]]['genres'].values[0])
# Out:
# Table No. 21 0.20405213892932442 Adventure, Thriller
# Big Game 0.17079935777554942 Action, Drama, Thriller
# Snowed Under 0.16697830543321887 Comedy
# The Mend 0.16591766981559603 Comedy
# The Dark Angel 0.15461056547280347 Romance, Drama

# %% [markdown]
# ### Summary

# %% [markdown]
# #### CountVectorizer with linear_kernel algorithm
# The pair of features_engineering algorithm "CountVectorizer" and the "linear_kernel" item similarity scoring,
# it results as with weird scores of each movies
# so we decided to check whether each movie has the similar type(s) to dummy data ('Jumanji')
# and here is the result :
#
# As you can see that there is only one movie that has the similar genres to Jumanji.
# So, we decided to cut this pair out from benchmark algorithms

# %% [markdown]
# #### CountVectorizer with cosine_similarity algorithm
# The pair of features_engineering algorithm "CountVectorizer" and the "cosine_similarity" item similarity scoring,
# it results with mid range (0.4-0.6) scores of each movies which are the highest scores.
# so we decided to check whether each movie has the similar type(s) to dummy data ('Jumanji')
# and here is the result :
#
# As you can see that there are four movies that has the similar genres to Jumanji.
# This algorithm takes 32.4 seconds to scoring movies similarity scores

# %% [markdown]
# #### TfidfVectorizer with Linear_kernel algorithm
# The pair of features_engineering algorithm "TfidfVectorizer" and the "linear_kernel" item similarity scoring,
# it results with low range (0.1-0.3) scores of each movies
# so we decided to check whether each movie has the similar type(s) to dummy data ('Jumanji')
# and here is the result :
#
# As you can see that there no movie that has the similar genres to Jumanji (if we don't take comedy movies).
# So we decided to cut this out from benchmark list of algorithms

# %% [markdown]
# #### TfidfVectorizer with cosine_similarity algorithm
# The pair of features_engineering algorithm "TfidfVectorizer" and the "linear_kernel" item similarity scoring,
# it results with low range (0.1-0.3) scores of each movies
# so we decided to check whether each movie has the similar type(s) to dummy data ('Jumanji')
# and here is the result :
#
# As you can see that there no movie that has the similar genres to Jumanji (if we don't take comedy movies).
# So we decided to cut this out from benchmark list of algorithms

# %% [markdown]
# #### Selected Algorithm
# So as the benchmark results say
#     - CountVectorizer with Linear_kernel results with one similar movies and mid range scores
#     - CountVectorizer with cosine_similarity results with four similar movies and mid range scores
#     - TfidfVectorizer with linear_kernel results with no similar movies and low range scores
#     - TfidfVectorizer with cosine_similarity results with no similar movies and low range scores
#
# According to the result, there's only a pair of algorithms that has the results as developer expected, it is
# ##### CountVectorizer with cosine_similarity

# %% [markdown]
# ## Show similar movies

# %%
model = CountVectorizer()
vector = model.fit_transform(df['combining_features'])

# %%
item_similarity = cosine_similarity(vector)

# %%
# Generating similar movies to dummy
# movies_dummy = Jumanji
# dummy_index = 1 (Index finding method is located above)
similar_movies = list(enumerate(item_similarity[dummy_index]))

# %%
# sorting 
sorted_similar_movies = sorted(similar_movies, key=lambda x: x[1], reverse=True)

# %%
sorted_similar_movies
# Out:
# [(1, 1.0),
#  (15513, 0.5168943500406085),
#  (15636, 0.46942943463037434),
#  (20775, 0.4692769977260045),
#  (19592, 0.46833182657973405),
#  (25477, 0.45832959837804316),
#  (4007, 0.45800257110652437),
#  (26933, 0.4563960315632021),
#  (8609, 0.45610645978878045),
#  (16989, 0.4518415200457906),
#  (7676, 0.4508849967218059),
#  (14346, 0.449616977498061),
#  (20788, 0.4489276572618495),
#  (5242, 0.44821419037571675),
#  (7761, 0.44760525833564513),
#  (18811, 0.4465164577487581),
#  (24777, 0.4445477705053972),
#  (27512, 0.4443387242826583),
#  (7354, 0.4443308525660311),
#  (14764, 0.4440641122369215),
#  (18422, 0.44341595878538587),
#  (6106, 0.44288618241056793),
#  (26397, 0.44262055823428254),
#  (750, 0.44260528933831905),
#  (13317, 0.44249182947739474),
#  (16695, 0.4422777974034763),
#  (5961, 0.4422021878982818),
#  (18557, 0.44220218789828175),
#  (2246, 0.44098445519045926),
#  (27874, 0.4407939549460739),
#  (20179, 0.43977763620686394),
#  (4174, 0.4394256768389381),
#  (6080, 0.4390274810290186),
#  (27390, 0.4387496373361088),
#  (4502, 0.4382852531422893),
#  (18792, 0.43821184877279035),
#  (27384, 0.4376821356787275),
#  (10001, 0.43754677704376665),
#  (742, 0.4375467770437666),
#  (26717, 0.43749499329578445),
#  (16439, 0.43726810021259516),
#  (23577, 0.43719768099960715),
#  (22633, 0.43700298619727523),
#  (16524, 0.4367424498197118),
#  (18700, 0.4365260109471104),
#  (3607, 0.4362503392991891),
#  (18773, 0.4359759507323242),
#  (20435, 0.43588358821351225),
#  (16984, 0.43576853710611224),
#  (26649, 0.4346586479429951),
#  (14777, 0.4346072060056657),
#  (26801, 0.4342502390411196),
#  (1384, 0.434135370880122),
#  (26445, 0.4341314453748176),
#  (1706, 0.434093649158736),
#  (18461, 0.4332211257029256),
#  (1982, 0.43318459267641757),
#  (4972, 0.43259496849197737),
#  (5396, 0.43176240124339293),
#  (2970, 0.4315916476325223),
#  (8383, 0.4312697595578662),
#  (14325, 0.4310339260657704),
#  (4389, 0.43084430222743275),
#  (7288, 0.4306685908407499),
#  (2836, 0.4305694414005881),
#  (23752, 0.43056944140058806),
#  (23137, 0.4305580029870573),
#  (3562, 0.4303902241435419),
#  (23698, 0.43028363740235),
#  (3556, 0.4301705812488375),
#  (27856, 0.42985807079622),
#  (5892, 0.42958650687050237),
#  (11032, 0.4293356559545983),
#  (18880, 0.42928407118048023),
#  (14323, 0.4292278503062788),
#  (24108, 0.4291703493459907),
#  (23500, 0.42911234943365806),
#  (13872, 0.3930619080391812),
#  (24103, 0.3930476968607733),
#  (15797, 0.39304769686077323),
#  (907, 0.39297011148580424),
#  (2409, 0.3929701114858042),
#  (1709, 0.39288210203045615),
#  (19298, 0.39288210203045615),
#  (14905, 0.3928821020304561),
#  ...]

# %%
# it returns an array of index of movies and its score
# so we have to find what is the index represents the title of the movie
similar_movies_arr = []
score = []
def get_title(index):
    return df.loc[df.index == index]['title'].values[0]
for j in range(1, 6):
    similar_movies_arr.append(get_title(sorted_similar_movies[j][0]))
    score.append(sorted_similar_movies[j][1])

# %%
similar_movies_arr
# Out:
# ['Table No. 21',
#  'Are You Scared 2',
#  'Ashens and the Quest for the Gamechild',
#  'The Long and the Short and the Tall',
#  'Beta Test']

# %%
score
# Out:
# [0.5168943500406085,
#  0.46942943463037434,
#  0.4692769977260045,
#  0.46833182657973405,
#  0.45832959837804316]

# %%
for j in range(len(similar_movies_arr)):
    print(f'Movie name = {similar_movies_arr[j]} | Matching score = {(score[j])}')
# Out:
# Movie name = Table No. 21 | Matching score = 0.5168943500406085
# Movie name = Are You Scared 2 | Matching score = 0.46942943463037434
# Movie name = Ashens and the Quest for the Gamechild | Matching score = 0.4692769977260045
# Movie name = The Long and the Short and the Tall | Matching score = 0.46833182657973405
# Movie name = Beta Test | Matching score = 0.45832959837804316

# %% [markdown]
# # Pipeline
# ## Pre-Processing
#     - Remove rows which are null
#     - Remove rows which are duplicated
#     - Correcting genres (into string form)
#     - Mapping genres

# %%
movies_pipe_line = pd.read_csv('movies_metadata.csv')
# Out:
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/IPython/core/interactiveshell.py:3072: DtypeWarning: Columns (10) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
class PipeLine:
    def __init__(self, data):
        self.df = data.copy()
    def executeDataPrep(self):
        # drop columns
        self.df = self.df.drop(columns=['tagline', 'belongs_to_collection', 'homepage', 'imdb_id', 'id', 'poster_path', 'production_countries', 'revenue', 'release_date', 'status', 'title', 'video', 'budget'], axis=1)
        
        # drop null rows
        self.df.dropna(axis=0, inplace=True)

        # drop duplicated rows
        self.df.drop_duplicates(inplace=True)

        #drop none genres movies
        self.df.drop(self.df.loc[self.df['genres'] == '[]'].index, inplace=True)

        #correcting form of group columns
        regex = re.compile(r": '(.*?)'")
        self.df['genres'] = self.df['genres'].apply(lambda x: ",".join(regex.findall(x)))
        self.df['production_companies'] = self.df['production_companies'].apply(lambda x: ",".join(regex.findall(x)))
        self.df['spoken_languages'] = self.df['spoken_languages'].apply(lambda x: ",".join(regex.findall(x)))

        #grouping data
        self.df['runtime'] = pd.cut(self.df['runtime'], bins=5, labels=['Short', 'Med-Short', 'Med', "Med-Long", 'Long'])
        self.df['popularity'] = self.df['popularity'].astype('float64')
        self.df['popularity'] = pd.cut(self.df['popularity'], bins=3, labels=['Low', 'Medium', 'High'])
        self.df['vote_average'] = pd.cut(self.df['vote_average'], bins=3, labels=['Low', 'Medium', 'High'])
        self.df['vote_count'] = pd.cut(self.df['vote_count'], bins=3, labels=['Low', 'Medium', 'High'])

        #drop non-en languages
        self.df.drop(self.df.loc[self.df['original_language'] != 'en'].index, inplace=True)

        #reset indexes
        self.df = self.df.reset_index(drop=True)

        #mapping adult column
        self.df['adult'] = self.df['adult'].astype('string')
        self.df['adult'] = self.df['adult'].map({
            'False' : 'Non-Adult',
            'True' : 'Adult'
        })
        #combining_features
    def combined_features(self, row):
        return row['genres'] + " " + row['adult'] + " " + row['original_title'] + " " + row['production_companies'] + " " + row['original_language'] + " " + row['runtime'] + " " + row['overview'] + " " + row['popularity'] + " " + row['vote_average'] + ' ' + row['vote_count']
    def executeCombiningFeatures(self):
        self.df['combined_features'] = self.df.apply(self.combined_features, axis=1)
    def executeFeatureExtracting(self):
        model = CountVectorizer()
        vector = model.fit_transform(self.df['combined_features'])
        return vector
    def executeCS(self, vector):
        itemSimilarity = cosine_similarity(vector)
        return itemSimilarity
    def mainExecute(self):
        self.executeDataPrep()
        self.executeCombiningFeatures()
        vector = self.executeFeatureExtracting()
        itemSimilarity = self.executeCS(vector)
        return itemSimilarity

# %%
pipe = PipeLine(movies_pipe_line)
itemSimilarity = pipe.mainExecute()
pipe.df
# Out:
#            adult                    genres original_language  \
# 0      Non-Adult   Animation,Comedy,Family                en
# 1      Non-Adult  Adventure,Fantasy,Family                en
# 2      Non-Adult            Romance,Comedy                en
# 3      Non-Adult      Comedy,Drama,Romance                en
# 4      Non-Adult                    Comedy                en
# ...          ...                       ...               ...
# 30522  Non-Adult            Mystery,Horror                en
# 30523  Non-Adult                    Horror                en
# 30524  Non-Adult           Science Fiction                en
# 30525  Non-Adult      Drama,Action,Romance                en
# 30526  Non-Adult     Action,Drama,Thriller                en
#
#                     original_title  \
# 0                        Toy Story
# 1                          Jumanji
# 2                 Grumpier Old Men
# 3                Waiting to Exhale
# 4      Father of the Bride Part II
# ...                            ...
# 30522    Shadow of the Blair Witch
# 30523          The Burkittsville 7
# 30524              Caged Heat 3000
# 30525                   Robin Hood
# 30526                     Betrayal
#
#                                                 overview popularity  \
# 0      Led by Woody, Andy's toys live happily in his ...        Low
# 1      When siblings Judy and Peter discover an encha...        Low
# 2      A family wedding reignites the ancient feud be...        Low
# 3      Cheated on, mistreated and stepped on, the wom...        Low
# 4      Just when George Banks has recovered from his ...        Low
# ...                                                  ...        ...
# 30522  In this true-crime documentary, we delve into ...        Low
# 30523  A film archivist revisits the story of Rustin ...        Low
# 30524  It's the year 3000 AD. The world's most danger...        Low
# 30525  Yet another version of the classic epic, with ...        Low
# 30526  When one of her hits goes wrong, a professiona...        Low
#
#                                     production_companies runtime  \
# 0                                Pixar Animation Studios   Short
# 1      TriStar Pictures,Teitler Film,Interscope Commu...   Short
# 2                            Warner Bros.,Lancaster Gate   Short
# 3                 Twentieth Century Fox Film Corporation   Short
# 4              Sandollar Productions,Touchstone Pictures   Short
# ...                                                  ...     ...
# 30522                                                      Short
# 30523      Neptune Salad Entertainment,Pirie Productions   Short
# 30524                              Concorde-New Horizons   Short
# 30525  Westdeutscher Rundfunk (WDR),Working Title Fil...   Short
# 30526                            American World Pictures   Short
#
#              spoken_languages vote_average vote_count  \
# 0                  en,English         High     Medium
# 1      en,English,fr,Français         High        Low
# 2                  en,English       Medium        Low
# 3                  en,English       Medium        Low
# 4                  en,English       Medium        Low
# ...                       ...          ...        ...
# 30522              en,English         High        Low
# 30523              en,English         High        Low
# 30524              en,English       Medium        Low
# 30525              en,English       Medium        Low
# 30526              en,English       Medium        Low
#
#                                        combined_features
# 0      Animation,Comedy,Family Non-Adult Toy Story Pi...
# 1      Adventure,Fantasy,Family Non-Adult Jumanji Tri...
# 2      Romance,Comedy Non-Adult Grumpier Old Men Warn...
# 3      Comedy,Drama,Romance Non-Adult Waiting to Exha...
# 4      Comedy Non-Adult Father of the Bride Part II S...
# ...                                                  ...
# 30522  Mystery,Horror Non-Adult Shadow of the Blair W...
# 30523  Horror Non-Adult The Burkittsville 7 Neptune S...
# 30524  Science Fiction Non-Adult Caged Heat 3000 Conc...
# 30525  Drama,Action,Romance Non-Adult Robin Hood West...
# 30526  Action,Drama,Thriller Non-Adult Betrayal Ameri...
#
# [30527 rows x 12 columns]

# %% [markdown]
# # Recommendation Function
#     - Getting an input from users
#     - Finding index of movie name
#     - Getting similar movies as an array
#     - Sorting array
#     - Getting the first 5 positions which are similar to the input

# %%
class Recommender:
    def __init__(self, movieName, movieData, itemSimilarity) -> None:
        self.movieName = movieName
        self.df = movieData.copy()
        self.itemSimilarity = itemSimilarity
    def getIndex(self):
        return self.df.loc[self.df['original_title'] == self.movieName].index.values[0]
    def getTitle(self, index):
        return self.df.loc[self.df.index == index]['original_title'].values[0]
    def printResult(self, sortedSimilarMovie):
        moviesName = list()
        moviesScore = list()
        for j in range(1, 6):
            moviesName.append(self.getTitle(sortedSimilarMovie[j][0]))
            moviesScore.append(sortedSimilarMovie[j][1])
            print(f'Movie name = {self.getTitle(sortedSimilarMovie[j][0])}              |   Movie Score = {sortedSimilarMovie[j][1].round(2)}')
        return moviesName, moviesScore
    def recommend(self):
        movieIndex = self.getIndex()
        similarMovie = list(enumerate(self.itemSimilarity[movieIndex]))
        sortedSimilarMovie = sorted(similarMovie, key=lambda x:x[1], reverse=True)
        moviesName, moviesScore = self.printResult(sortedSimilarMovie)
        return moviesName, moviesScore

# %%
rcmder = Recommender('Jumanji', movieData=pipe.df, itemSimilarity=itemSimilarity)
moviesName, moviesScore = rcmder.recommend()
# Out:
# Movie name = Table No. 21              |   Movie Score = 0.52
# Movie name = Are You Scared 2              |   Movie Score = 0.47
# Movie name = Ashens and the Quest for the Gamechild              |   Movie Score = 0.47
# Movie name = The Long and the Short and the Tall              |   Movie Score = 0.47
# Movie name = Beta Test              |   Movie Score = 0.46

# %% [markdown]
# # Deployment
#     - Web app
#         - Getting an input in movie_name form
#         - Output as a set of movie names with its matching score

# %%
import gradio

# %%
iface = gradio.Interface(fn=rcmder.recommend,
                     inputs=[gradio.inputs.Textbox(label='Enter Movie Name')],
                     outputs=[gradio.outputs.Textbox(label="Movies Title"), gradio.outputs.Dataframe(label='Movie Score')])
iface.launch()
# Out:
# Running on local URL:  http://127.0.0.1:7865/
#
# To create a public link, set `share=True` in `launch()`.
#         <iframe
#             width="900"
#             height="500"
#             src="http://127.0.0.1:7865/"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>
# (<Flask 'gradio.networking'>, 'http://127.0.0.1:7865/', None)
# Traceback (most recent call last):
#   File "/Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/gradio/networking.py", line 195, in predict
#     prediction, durations = app.interface.process(raw_input)
#   File "/Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/gradio/interface.py", line 372, in process
#     processed_input, return_duration=True)
#   File "/Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/gradio/interface.py", line 337, in run_prediction
#     prediction = predict_fn(*processed_input)
# TypeError: recommend() takes 1 positional argument but 2 were given
# Traceback (most recent call last):
#   File "/Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/gradio/networking.py", line 195, in predict
#     prediction, durations = app.interface.process(raw_input)
#   File "/Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/gradio/interface.py", line 372, in process
#     processed_input, return_duration=True)
#   File "/Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/gradio/interface.py", line 337, in run_prediction
#     prediction = predict_fn(*processed_input)
# TypeError: recommend() takes 1 positional argument but 2 were given
# Traceback (most recent call last):
#   File "/Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/gradio/networking.py", line 195, in predict
#     prediction, durations = app.interface.process(raw_input)
#   File "/Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/gradio/interface.py", line 372, in process
#     processed_input, return_duration=True)
#   File "/Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/gradio/interface.py", line 337, in run_prediction
#     prediction = predict_fn(*processed_input)
# TypeError: recommend() takes 1 positional argument but 2 were given
# Traceback (most recent call last):
#   File "/Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/gradio/networking.py", line 195, in predict
#     prediction, durations = app.interface.process(raw_input)
#   File "/Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/gradio/interface.py", line 372, in process
#     processed_input, return_duration=True)
#   File "/Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/gradio/interface.py", line 337, in run_prediction
#     prediction = predict_fn(*processed_input)
# TypeError: recommend() takes 1 positional argument but 2 were given
# Traceback (most recent call last):
#   File "/Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/gradio/networking.py", line 195, in predict
#     prediction, durations = app.interface.process(raw_input)
#   File "/Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/gradio/interface.py", line 372, in process
#     processed_input, return_duration=True)
#   File "/Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/gradio/interface.py", line 337, in run_prediction
#     prediction = predict_fn(*processed_input)
# TypeError: recommend() takes 1 positional argument but 2 were given
# Traceback (most recent call last):
#   File "/Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/gradio/networking.py", line 195, in predict
#     prediction, durations = app.interface.process(raw_input)
#   File "/Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/gradio/interface.py", line 372, in process
#     processed_input, return_duration=True)
#   File "/Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/gradio/interface.py", line 337, in run_prediction
#     prediction = predict_fn(*processed_input)
# TypeError: recommend() takes 1 positional argument but 2 were given
